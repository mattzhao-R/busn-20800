# %% [markdown]
# # Assignment 6: Neural network
#
# ## BUS 20800: Big Data
# ## Due: 11:59 am on May 23, 2022

# %% [markdown]
# This assignment is a simplified exercise based on the simulations in this paper:
# [Empirical Asset Pricing via Machine Learning](https://dachxiu.chicagobooth.edu/download/ML.pdf).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot  as plt
import os

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
path = './Simu/SimuData_100/'

# %% [markdown]
# # Part I. DGP

# %% [markdown]
# You can check the data generating process in `DGP.py`. We have generated firm characteristics and returns as linear and nonlinear functions of these characteristics, respectively.
#
#
# It takes several minutues to run the simulation code and generate the data, if you want to run it yourself. We have provided the simulated data for you. You can check the simulated data in `Simu` folder. There are 100 Monte Carlo repetions.

# %% [markdown]
# # Part II. Two Layer NN

# %% [markdown]
# First, follow the instruction codes in lecture codes, finish this toy `TwoLayerNet` class for rergression.

# %%
class TwoLayerNet(object):
    """
    A two-layer fully-connected neural network. The net has an input dimension of
    N, a hidden layer dimension of H, and performs regression task.
    
    We train the network with square loss and L2 regularization on the
    weight matrices. The network uses a ReLU nonlinearity after the first fully
    connected layer.

    In other words, the network has the following architecture:

    input - fully connected layer - ReLU - fully connected layer - square loss

    The outputs of the second fully-connected layer are the predictions.
    """
    
    
    # Initialize the NN
    def __init__(self, input_size, hidden_size, output_size, std=1e-4):
        
        """
        Initialize the model. Weights are initialized to small random values and
        biases are initialized to zero. Weights and biases are stored in the
        variable self.params, which is a dictionary with the following keys:

        W1: First layer weights; Shape (D, H)
        b1: First layer biases; Shape (H,)
        W2: Second layer weights; Shape (H, 1)
        b2: Second layer biases; Shape (1,)

        Inputs:
        - input_size: The dimension D of the input data.
        - hidden_size: The number of neurons H in the hidden layer.
        - output_size: Output prediction.
        """
        
        self.params = {}
        self.params['W1'] = std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size)
        self.params['W2'] = std * np.random.randn(hidden_size, output_size)
        self.params['b2'] = np.zeros(output_size)

    def loss(self, X, y=None, reg=0.0):
        """
        Compute the loss and gradients for a two layer fully connected neural
        network.

        Inputs:
        - X: Shape (N, D). Each X[i] is a training sample.
        - y: Vector of training labels.
        - reg: Regularization strength.

        Returns:
        If y is None, return a matrix scores of shape (N, 1) where scores[i,0] is
        the prediction.

        If y is not None, instead return a tuple of:
        - loss: Loss (data loss and regularization penalty) 
        - grads: Dictionary mapping parameter names to gradients of those parameters
          with respect to the loss function; has the same keys as self.params.
        """
        
        # Unpack variables from the params dictionary
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']
        N, D = X.shape

        # Compute the forward pass
        # Use Relu as the non-linearity function
        scores = np.maximum(X.dot(W1) + b1, 0).dot(W2) + b2


        # If the targets are not given then jump out, we're done
        if y is None:
            return scores
        
##############################################################################
### TODO: Calculate the loss function (data + regularization)              ###
##############################################################################
        # Compute the loss
        
        loss = np.sum(np.square(scores-y))/N
        reg_term = np.sum(np.square(W1)) + np.sum(np.square(W2))
        # Add regularization loss
        loss += reg/2 * reg_term * W1.shape[1] * W2.shape[1] / N

##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################

        
        
        # Backward pass: compute gradients
        grads = {}            
##############################################################################
### TODO: Calculate the gradient of each parameter.                        ###
##############################################################################
        dlossdscores = -2/N*(y-scores)  # N
        
        grads['b2'] = np.sum(dlossdscores, axis = 0)
        grads['W2'] = np.maximum(X.dot(W1) + b1 ,0).T.dot(dlossdscores)+ 2*reg*W2          # H x C
        grads['b1'] = np.sum((dlossdscores).dot(W2.T)*(X.dot(W1) + b1 >0),axis = 0) # H x 1
        grads['W1'] = X.T.dot(dlossdscores.dot(W2.T)*(X.dot(W1) + b1 >0)) + 2*reg*W1   
       
##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
        
        return loss, grads

    def train(self, X, y, X_val, y_val,
              learning_rate=1e-3, learning_rate_decay=0.95,
              reg=5e-6, num_iters=100,
              batch_size=200, verbose=False):
        """
        Train this neural network using SGD.

        Inputs:
        - X: Shape (N, D) 
        - y: Shape (N, )
        - X_val: Shape (N_val, D) 
        - y_val: Shape (N_val, ) 
        - learning_rate: Scalar giving learning rate for optimization.
        - learning_rate_decay: Scalar giving factor used to decay the learning rate
          after each epoch.
        - reg: Scalar giving regularization strength.
        - num_iters: Number of steps to take when optimizing.
        - batch_size: Number of training examples to use per step.
        - verbose: boolean; if true print progress during optimization.
        """
        
        num_train = X.shape[0]
        iterations_per_epoch = max(num_train / batch_size, 1)

        # Use SGD to optimize the parameters in self.model
        loss_history = []
        train_acc_history = []
        val_acc_history = []

        for it in range(num_iters):
            X_batch = None
            y_batch = None

            mask  = np.random.choice(num_train, batch_size, replace=True)
            X_batch = X[mask]
            y_batch = y[mask]

            # Compute loss and gradients using the current minibatch
            loss, grads = self.loss(X_batch, y=y_batch, reg=reg)
            loss_history.append(loss)

            # Gradient descent 
##############################################################################
### TODO: Perform Gradient descent to update parameters                                    ###
##############################################################################
##############################################################################
            self.params['b1']  += -learning_rate * grads['b1']
            self.params['W1']  += -learning_rate * grads['W1']
            self.params['b2']  += -learning_rate * grads['b2']
            self.params['W2']  += -learning_rate * grads['W2']

##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################

            if verbose and it % 100 == 0:
                print('iteration %d / %d: loss %f' % (it, num_iters, loss))

            # Every epoch, check train and val accuracy and decay learning rate.
            if it % iterations_per_epoch == 0:
                # Check accuracy
                train_acc = (self.predict(X_batch) == y_batch).mean()
                val_acc = (self.predict(X_val) == y_val).mean()
                train_acc_history.append(train_acc)
                val_acc_history.append(val_acc)

                # Decay learning rate
                learning_rate *= learning_rate_decay

        return {
          'loss_history': loss_history,
          'train_acc_history': train_acc_history,
          'val_acc_history': val_acc_history,
        }

    def predict(self, X):
        """
        Use the trained weights of this two-layer network to predict return for
        data points.
        Inputs:
        - X: Shape (N, D)

        Returns:
        - y_pred: Shape (N,)
        """

        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']
        
##############################################################################
### Done: Calculate the prediction.                                        ###
##############################################################################

        y_pred = np.maximum(X.dot(W1) + b1, 0).dot(W2) + b2

##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
        
        return y_pred

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
output_size = 1
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, output_size, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1]).reshape(-1,1)
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# ## Forward pass: compute scores
# Open the file `neural_net.py` and look at the method `TwoLayerNet.loss`. It takes the data and weights and computes the class scores, the loss, and the gradients with respect to the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [0.38061523],
  [-0.55607245],
  [-0.59991751],
  [-0.61246639],
  [0.05788525]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[ 0.38061523]
#  [-0.55607245]
#  [-0.59991751]
#  [-0.61246639]
#  [ 0.05788525]]
#
# correct scores:
# [[ 0.38061523]
#  [-0.55607245]
#  [-0.59991751]
#  [-0.61246639]
#  [ 0.05788525]]
#
# Difference between your scores and correct scores:
# 1.4530232447795832e-08

# %% [markdown]
# ## Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y.reshape(-1,1), reg=0.05)
correct_loss = 3.439836236605

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 5.693223670277803e-13

# %%
from gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# The difference between the numeric and analytic gradients should be less than 
# 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)
# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    #print(param_grad_num)
    #print(grads[param_name])
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# b2 max relative error: 3.758574e-13
# W2 max relative error: 5.930725e-10
# b1 max relative error: 4.959295e-10
# W1 max relative error: 3.561318e-09

# %% [markdown]
# ## Combine the above: Training

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=4e-3, reg=1e-3,
            num_iters=100, verbose=False)
# Note: I Changed the learning rate and regularization size to get a good training.
print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration',size = 20)
plt.ylabel('training loss',size = 20)
plt.title('Training Loss history', size = 20)
plt.show()
# Out:
# Final training loss:  0.3378779236265238

# %% [markdown]
# #  Part III. Multi-layer NN
#
# Now we have finished the top layer, and we want to build networks using a more modular design so that we can implement different layer types in isolation and then snap them together into models with various architectures.

# %% [markdown]
# ## Affine layer: foward

# %%
def affine_forward(x, w, b):
    """
    Computes the forward pass for an affine (fully-connected) layer.

    The input x has shape (N, d_1, ..., d_k) and contains a minibatch of N
    examples, where each example x[i] has shape (d_1, ..., d_k). 
    Reshape each input into a vector of dimension D = d_1 * ... * d_k, and
    then transform it to an output vector of dimension M.

    Inputs:
    - x: A numpy array containing input data, of shape (N, d_1, ..., d_k)
    - w: A numpy array of weights, of shape (D, M)
    - b: A numpy array of biases, of shape (M,)

    Returns a tuple of:
    - out: output, of shape (N, M)
    - cache: (x, w, b)
    """

##############################################################################
### TODO: Perform affine transformation.                                   ###
##############################################################################,
    #reshaped_x = x.reshape(x.shape[0],-1)
  

    #out = (np.dot(w.T,reshaped_x.T).T+b.T)
    out = np.reshape(x,(x.shape[0],np.prod(x.shape[1:]))).dot(w) + b


##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
    cache = (x, w, b)
    
    return out, cache

# %%
# Test the affine_forward function

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 1

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.51506276],
                        [ 3.32259414]])

# Compare your output with ours. The error should be around e-9 or less.
print('Testing affine_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing affine_forward function:
# difference:  4.971001967190414e-10

# %% [markdown]
# ## Affine layer: backward

# %%
def affine_backward(dout, cache):
    """
    Computes the backward pass for an affine layer.

    Inputs:
    - dout: Upstream derivative, of shape (N, M)
    - cache: Tuple of:
      - x: Input data, of shape (N, d_1, ... d_k)
      - w: Weights, of shape (D, M)
      - b: Biases, of shape (M,)

    Returns a tuple of:
    - dx: Gradient with respect to x, of shape (N, d1, ..., d_k)
    - dw: Gradient with respect to w, of shape (D, M)
    - db: Gradient with respect to b, of shape (M,)
    """
    x, w, b = cache

##############################################################################
### TODO: Calculate the gradient of affine transformation                  ###
##############################################################################

    db = np.sum(dout,axis=0)
 
    dw = np.reshape(x,(x.shape[0],np.prod(x.shape[1:]))).T.dot(dout)
    dx = np.dot(dout,w.T)
    dx = dx.reshape(x.shape)
    

##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################


    return dx, dw, db

# %%
from gradient_check import eval_numerical_gradient, eval_numerical_gradient_array


# Test the affine_backward function
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 1)
b = np.random.randn(1)
dout = np.random.randn(10, 1)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around e-10 or less
print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_backward function:
# dx error:  6.87500492890902e-11
# dw error:  3.6091880748424353e-11
# db error:  2.4097482260876687e-12

# %% [markdown]
# ##  ReLU activation: forward

# %% [markdown]
# ### ReLU
# There are many potential choices for the nonlinear activation function (such
# as sigmoid, hyperbolic, softmax). We use the same activation function at all
# nodes, and choose a popular functional form in recent literature known as the
# rectified linear unit (ReLU), defined as:
#
# $$\text{ReLU}(x) = \begin{cases}0 \quad &\text{if}\; x < 0 \\
# x \quad &\text{otherwise} \end{cases} $$
#
# which encourages sparsity in the number of active neurons and allows for faster derivative evaluation.

# %% [markdown]
# Our neural network model has the following general formula. Let $K^{(l)}$ denote the number of neurons in each layer $l =1,...,L$. Define the output of neuron $k$ in layer $l$ as $x_{k}^{(l)}$. Next, define the vector of outputs for this layer (augmented to include a constant, $x_{0}^{(l)}$ ) as
# $x^{(l)} = (1,x_{1}^{(l)},...,x_{K^{l}}^{(l)})'$.
# To initialize the network, similarly define the input layer using the raw predictors, $x^{(0)} =(1,z_{1},...,z_{N})'$. The recursive output formula for the neural network at each neuron in layer $l>0$ is then
#
# $$x_{k}^{(l)} =  \text{ReLU} \left( x^{(l-1)'} \;\theta_{k}^{(l-1)}\; \right)$$
#
# with final output:
#
# $$g(z;\theta) = x^{(L-1)'} \;\theta^{L-1}$$
#
# The number of weight parameters in each hidden layer $l$ is $K^{(l)}\left(1+K^{(l−1)} \;\right)$, plus another $1+K^{(L−1)}$ weights for the output layer.
#
# We estimate the neural network weight parameters by minimizing the penalized $l_{2}$ objective function of prediction errors. Unlike tree-based algorithms that require “greedy” optimization, training a neural network, in principle, allows for joint updates of all model parameters at each step of the optimization—a substantial advantage of neural networks over trees.

# %%
def relu_forward(x):
    """
    Computes the forward pass for a layer of rectified linear units (ReLUs).
    """
##############################################################################
### TODO: Calculate the gradient of affine transformation                  ###
##############################################################################
    out = np.maximum(0,x)
##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
    cache = x
    return out, cache

# %%
# Test the relu_forward function

x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be on the order of e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# ## ReLU activation: backward

# %%
def relu_backward(dout, cache):
    """
    Computes the backward pass for a layer of ReLUs.

    Input:
    - dout: Upstream derivatives, of any shape
    - cache: Input x, of same shape as dout

    Returns:
    - dx: Gradient with respect to x
    """
    dx, x = None, cache
    
##############################################################################
### TODO: Calculate the gradient of affine transformation                  ###
##############################################################################
    dx = dout*(x>0)
##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
    cache = x

    return dx

# %%
np.random.seed(231)
x = np.random.randn(10, 5)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)
# The error should be on the order of e--12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2756219598992723e-12

# %% [markdown]
# ## Loss layers: MSE

# %%
def mean_square_loss(x, y):
    """
    Computes the loss and gradient for mean square loss.

    Inputs:
    - x: Shape (N, ) 
    - y: Shape (N,)
    
    Returns a tuple of:
    - loss: Scalar giving the loss
    - dx: Gradient of the loss with respect to x
    """
    
##############################################################################
### TODO: Calculate the loss and gradient for MSE.                         ###
##############################################################################
    N = x.shape[0]

    

    loss = 1/N*np.sum(np.square(y-x))
    dx = -2/N*(y-x)
    

##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################

    return loss, dx

# %%
np.random.seed(231)
num_output, num_inputs = 1, 50
x = 0.001 * np.random.randn(num_inputs, num_output)
y = np.random.randint(num_output, size=num_inputs).reshape(-1,1)

dx_num = eval_numerical_gradient(lambda x: mean_square_loss(x, y)[0], x, verbose=False)
loss, dx = mean_square_loss(x, y)
# Test mean_square_loss function. Loss should be close to 2.3 and dx error should be around e-8
print('\nTesting softmax_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing softmax_loss:
# loss:  7.717948769472713e-07
# dx error:  8.55397758197063e-13

# %% [markdown]
# ## Combine the above blocks and build a neural network

# %% [markdown]
# ## Initial loss and gradient check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. Do the initial losses seem reasonable?
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
class FullyConnectedNet(object):
    """
    A fully-connected neural network with an arbitrary number of hidden layers,
    ReLU nonlinearities, and a mean square loss function. For a network with L layers,
    the architecture will be

    {affine - [batch/layer norm] - relu - [dropout]} x (L - 1) - affine - mean_square

    where batch/layer normalization and dropout are optional, and the {...} block is
    repeated L - 1 times.

    Learnable parameters are stored in the
    self.params dictionary and will be learned using the Solver class.
    """

    def __init__(self, hidden_dims, input_dim=100, num_output=1,
                 reg=0.0,
                 weight_scale=1e-2, dtype=np.float32):
        """
        Initialize a new FullyConnectedNet.

        Inputs:
        - hidden_dims: A list of integers giving the size of each hidden layer.
        - input_dim: An integer giving the size of the input.
        - num_output: For regression, num_output = 1
        - reg: Scalar giving L2 regularization strength.
        - weight_scale: Scalar giving the standard deviation for random
          initialization of the weights.
        - dtype: A numpy datatype object; all computations will be performed using
          this datatype. float32 is faster but less accurate, so you should use
          float64 for numeric gradient checking.

        """
        self.reg = reg
        self.num_layers = 1 + len(hidden_dims)
        self.dtype = dtype
        self.params = {}

        if len(hidden_dims)>0:
            self.params['W1'] = weight_scale * np.random.randn(input_dim, hidden_dims[0])
            self.params['b1'] = np.zeros(hidden_dims[0])
        
        for idx, dim in enumerate(hidden_dims):
            if idx < len(hidden_dims)-1:
                self.params['W' + str(2 + idx)] = weight_scale * np.random.randn(dim, hidden_dims[idx + 1])
                self.params['b' + str(2 + idx)] = np.zeros(hidden_dims[idx + 1])
            else:
                self.params['W' + str(2 + idx)] = weight_scale * np.random.randn(hidden_dims[idx], num_output)
                self.params['b' + str(2 + idx)] = np.zeros(num_output)


        # Cast all parameters to the correct datatype
        for k, v in self.params.items():
            self.params[k] = v.astype(dtype)


    def loss(self, X, y=None):
        """
        Compute loss and gradient for the fully-connected net.

        Input / output: Same as TwoLayerNet above.
        """
        X = X.astype(self.dtype)
        mode = 'test' if y is None else 'train'

        out = X
        for la in range(self.num_layers-1):
            a, _      = affine_forward(out, self.params['W'+str(la+1)], self.params['b'+str(la+1)])
            out, _    = relu_forward(a)
            

            
        scores, _ = affine_forward(out,
                                   self.params['W'+str(self.num_layers)],self.params['b'+str(self.num_layers)])


        # If test mode return early
        if mode == 'test':
            return scores

        out = X
        a=[]
        affine_cache = []
        relu_cache   = []
       
        
        loss, grads = 0.0, {}
        
        for la in range(self.num_layers-1):
            a, a_cache    = affine_forward(out, self.params['W'+str(la+1)], self.params['b'+str(la+1)])
            affine_cache.append(a_cache)
                
            out, r_cache    = relu_forward(a)
            relu_cache.append(r_cache)
            
   
        scores, cache  = affine_forward(out, self.params['W'+str(self.num_layers)], self.params['b'+str(self.num_layers)])
        loss, dx       = mean_square_loss(scores, y)
        
        
    
        da, dW, db  = affine_backward(dx, cache)
        grads['W'+str(self.num_layers)] = dW
        grads['b'+str(self.num_layers)] = db
        
            
        for la in reversed(range(self.num_layers-1)):            
            
            dr = relu_backward(da, relu_cache[la])
            
            da, dW, db = affine_backward(dr, affine_cache[la])
            grads['W'+ str(la+1)] = dW
            grads['b'+ str(la+1)] = db
            
        for la in range(self.num_layers):
            loss += 1/2*self.reg * np.sum(self.params['W'+ str(la+1)] * self.params['W'+ str(la+1)])     
            grads['W'+ str(la+1)]  +=  self.reg*self.params['W'+ str(la+1)] 

        return loss, grads

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 1
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,)).reshape(-1,1)

for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_output=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)
  
  # Most of the errors should be on the order of e-7 or smaller.   
  # for the check when reg = 0.0
  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Running check with reg =  0
# Initial loss:  5.741767878577345e-05
# W1 relative error: 1.31e-09
# W2 relative error: 4.68e-10
# W3 relative error: 6.32e-11
# b1 relative error: 2.74e-10
# b2 relative error: 2.28e-12
# b3 relative error: 2.07e-14
# Running check with reg =  3.14
# Initial loss:  3.8788787972165957
# W1 relative error: 5.62e-09
# W2 relative error: 9.46e-09
# W3 relative error: 1.38e-09
# b1 relative error: 1.00e-04
# b2 relative error: 1.21e-05
# b3 relative error: 8.33e-09

# %% [markdown]
# # Part IV. Return prediction

# %% [markdown]
# The simulation result in `Simu` file. It contains 100 time Monte Carlo simulation experiment, each with firm characteristics, linear and non-linear return.

# %%
# Setup codes

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# Run the following cells to load the data. You can choose different i here.

# %%
i = str(1)

factor = np.array(pd.read_csv(path+'c'+i+'.csv'))
linear_ret = np.array(pd.read_csv(path+'r1_'+i+'_1.csv'))
nonlinear_ret = np.array(pd.read_csv(path+'r2_'+i+'_1.csv'))

# %% [markdown]
# With the above preparation, build a NN using linear and non-linear return. And compare the results with
# + OLS,
# + OLS + Regularization (L1,L2),
# + Tree model(CART+Random Forest).
#
# What conclusions can you make? (You can use some visualziation tools to help you illustrate your results)

# %% [markdown]
# ### Neural network

# %% [markdown]
# Here is a NN example with subsample dataset. Once you finish all the cells above. You can directly run the below cells to get the prediction result.You don't need to modify any codes here.

# %%
# NN with sample data

from solver import Solver

num_train = 2500
num_valid = 500
small_data = {
  'X_train': factor[:num_train],
  'y_train': nonlinear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': nonlinear_ret[num_train:num_train+num_valid]
}

learning_rate = 5e-2  # Experiment with this!
weight_scale = 1*1e-1   # Experiment with this!
model = FullyConnectedNet([100, 100, 100, 100],
                weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 2000) loss: 0.017017
# (Epoch 0 / 20) train acc: -0.000694; val_acc: -0.003124
# (Iteration 11 / 2000) loss: 0.008818
# (Iteration 21 / 2000) loss: 0.010459
# (Iteration 31 / 2000) loss: 0.010009
# (Iteration 41 / 2000) loss: 0.016796
# (Iteration 51 / 2000) loss: 0.005095
# (Iteration 61 / 2000) loss: 0.012158
# (Iteration 71 / 2000) loss: 0.006515
# (Iteration 81 / 2000) loss: 0.005443
# (Iteration 91 / 2000) loss: 0.006449
# (Epoch 1 / 20) train acc: -0.000130; val_acc: -0.003124
# (Iteration 101 / 2000) loss: 0.007280
# (Iteration 111 / 2000) loss: 0.009787
# (Iteration 121 / 2000) loss: 0.007164
# (Iteration 131 / 2000) loss: 0.009054
# (Iteration 141 / 2000) loss: 0.006271
# (Iteration 151 / 2000) loss: 0.004868
# (Iteration 161 / 2000) loss: 0.007177
# (Iteration 171 / 2000) loss: 0.007936
# (Iteration 181 / 2000) loss: 0.007051
# (Iteration 191 / 2000) loss: 0.004328
# (Epoch 2 / 20) train acc: -0.001758; val_acc: -0.003124
# (Iteration 201 / 2000) loss: 0.009747
# (Iteration 211 / 2000) loss: 0.006635
# (Iteration 221 / 2000) loss: 0.006315
# (Iteration 231 / 2000) loss: 0.005673
# (Iteration 241 / 2000) loss: 0.011740
# (Iteration 251 / 2000) loss: 0.009580
# (Iteration 261 / 2000) loss: 0.004895
# (Iteration 271 / 2000) loss: 0.008999
# (Iteration 281 / 2000) loss: 0.011029
# (Iteration 291 / 2000) loss: 0.007160
# (Epoch 3 / 20) train acc: -0.000005; val_acc: -0.003124
# (Iteration 301 / 2000) loss: 0.013084
# (Iteration 311 / 2000) loss: 0.007992
# (Iteration 321 / 2000) loss: 0.005958
# (Iteration 331 / 2000) loss: 0.005488
# (Iteration 341 / 2000) loss: 0.005463
# (Iteration 351 / 2000) loss: 0.008087
# (Iteration 361 / 2000) loss: 0.006961
# (Iteration 371 / 2000) loss: 0.011099
# (Iteration 381 / 2000) loss: 0.004014
# (Iteration 391 / 2000) loss: 0.008021
# (Epoch 4 / 20) train acc: -0.001830; val_acc: -0.003124
# (Iteration 401 / 2000) loss: 0.006890
# (Iteration 411 / 2000) loss: 0.009938
# (Iteration 421 / 2000) loss: 0.009352
# (Iteration 431 / 2000) loss: 0.007450
# (Iteration 441 / 2000) loss: 0.004739
# (Iteration 451 / 2000) loss: 0.010406
# (Iteration 461 / 2000) loss: 0.006555
# (Iteration 471 / 2000) loss: 0.008944
# (Iteration 481 / 2000) loss: 0.009151
# (Iteration 491 / 2000) loss: 0.004611
# (Epoch 5 / 20) train acc: -0.000072; val_acc: -0.003124
# (Iteration 501 / 2000) loss: 0.005053
# (Iteration 511 / 2000) loss: 0.009840
# (Iteration 521 / 2000) loss: 0.008836
# (Iteration 531 / 2000) loss: 0.003562
# (Iteration 541 / 2000) loss: 0.006020
# (Iteration 551 / 2000) loss: 0.005108
# (Iteration 561 / 2000) loss: 0.006662
# (Iteration 571 / 2000) loss: 0.005181
# (Iteration 581 / 2000) loss: 0.002574
# (Iteration 591 / 2000) loss: 0.011203
# (Epoch 6 / 20) train acc: -0.000062; val_acc: -0.003124
# (Iteration 601 / 2000) loss: 0.004592
# (Iteration 611 / 2000) loss: 0.007473
# (Iteration 621 / 2000) loss: 0.005036
# (Iteration 631 / 2000) loss: 0.004919
# (Iteration 641 / 2000) loss: 0.007543
# (Iteration 651 / 2000) loss: 0.005233
# (Iteration 661 / 2000) loss: 0.006221
# (Iteration 671 / 2000) loss: 0.005692
# (Iteration 681 / 2000) loss: 0.006574
# (Iteration 691 / 2000) loss: 0.007239
# (Epoch 7 / 20) train acc: -0.000511; val_acc: -0.003124
# (Iteration 701 / 2000) loss: 0.008674
# (Iteration 711 / 2000) loss: 0.006404
# (Iteration 721 / 2000) loss: 0.005119
# (Iteration 731 / 2000) loss: 0.004563
# (Iteration 741 / 2000) loss: 0.004964
# (Iteration 751 / 2000) loss: 0.005651
# (Iteration 761 / 2000) loss: 0.011248
# (Iteration 771 / 2000) loss: 0.008841
# (Iteration 781 / 2000) loss: 0.005379
# (Iteration 791 / 2000) loss: 0.009509
# (Epoch 8 / 20) train acc: -0.004165; val_acc: -0.003124
# (Iteration 801 / 2000) loss: 0.007959
# (Iteration 811 / 2000) loss: 0.004986
# (Iteration 821 / 2000) loss: 0.004032
# (Iteration 831 / 2000) loss: 0.006980
# (Iteration 841 / 2000) loss: 0.006224
# (Iteration 851 / 2000) loss: 0.007874
# (Iteration 861 / 2000) loss: 0.006236
# (Iteration 871 / 2000) loss: 0.006081
# (Iteration 881 / 2000) loss: 0.009413
# (Iteration 891 / 2000) loss: 0.010746
# (Epoch 9 / 20) train acc: -0.002096; val_acc: -0.003124
# (Iteration 901 / 2000) loss: 0.006896
# (Iteration 911 / 2000) loss: 0.008003
# (Iteration 921 / 2000) loss: 0.004268
# (Iteration 931 / 2000) loss: 0.011177
# (Iteration 941 / 2000) loss: 0.007847
# (Iteration 951 / 2000) loss: 0.004173
# (Iteration 961 / 2000) loss: 0.009050
# (Iteration 971 / 2000) loss: 0.005245
# (Iteration 981 / 2000) loss: 0.003997
# (Iteration 991 / 2000) loss: 0.009716
# (Epoch 10 / 20) train acc: -0.003350; val_acc: -0.003124
# (Iteration 1001 / 2000) loss: 0.005802
# (Iteration 1011 / 2000) loss: 0.006118
# (Iteration 1021 / 2000) loss: 0.008180
# (Iteration 1031 / 2000) loss: 0.009387
# (Iteration 1041 / 2000) loss: 0.004063
# (Iteration 1051 / 2000) loss: 0.006811
# (Iteration 1061 / 2000) loss: 0.007639
# (Iteration 1071 / 2000) loss: 0.004031
# (Iteration 1081 / 2000) loss: 0.010960
# (Iteration 1091 / 2000) loss: 0.005238
# (Epoch 11 / 20) train acc: -0.000056; val_acc: -0.003124
# (Iteration 1101 / 2000) loss: 0.002754
# (Iteration 1111 / 2000) loss: 0.002869
# (Iteration 1121 / 2000) loss: 0.006752
# (Iteration 1131 / 2000) loss: 0.004477
# (Iteration 1141 / 2000) loss: 0.006361
# (Iteration 1151 / 2000) loss: 0.002081
# (Iteration 1161 / 2000) loss: 0.003163
# (Iteration 1171 / 2000) loss: 0.002801
# (Iteration 1181 / 2000) loss: 0.004500
# (Iteration 1191 / 2000) loss: 0.004469
# (Epoch 12 / 20) train acc: -0.000067; val_acc: -0.003124
# (Iteration 1201 / 2000) loss: 0.006545
# (Iteration 1211 / 2000) loss: 0.003286
# (Iteration 1221 / 2000) loss: 0.006626
# (Iteration 1231 / 2000) loss: 0.005088
# (Iteration 1241 / 2000) loss: 0.007127
# (Iteration 1251 / 2000) loss: 0.007157
# (Iteration 1261 / 2000) loss: 0.006465
# (Iteration 1271 / 2000) loss: 0.007759
# (Iteration 1281 / 2000) loss: 0.003104
# (Iteration 1291 / 2000) loss: 0.007701
# (Epoch 13 / 20) train acc: -0.000169; val_acc: -0.003124
# (Iteration 1301 / 2000) loss: 0.006417
# (Iteration 1311 / 2000) loss: 0.004008
# (Iteration 1321 / 2000) loss: 0.004667
# (Iteration 1331 / 2000) loss: 0.006342
# (Iteration 1341 / 2000) loss: 0.007975
# (Iteration 1351 / 2000) loss: 0.003806
# (Iteration 1361 / 2000) loss: 0.005855
# (Iteration 1371 / 2000) loss: 0.004056
# (Iteration 1381 / 2000) loss: 0.006094
# (Iteration 1391 / 2000) loss: 0.006039
# (Epoch 14 / 20) train acc: -0.002923; val_acc: -0.003124
# (Iteration 1401 / 2000) loss: 0.006476
# (Iteration 1411 / 2000) loss: 0.004227
# (Iteration 1421 / 2000) loss: 0.004560
# (Iteration 1431 / 2000) loss: 0.002978
# (Iteration 1441 / 2000) loss: 0.006309
# (Iteration 1451 / 2000) loss: 0.003928
# (Iteration 1461 / 2000) loss: 0.006064
# (Iteration 1471 / 2000) loss: 0.005265
# (Iteration 1481 / 2000) loss: 0.007239
# (Iteration 1491 / 2000) loss: 0.004095
# (Epoch 15 / 20) train acc: -0.000032; val_acc: -0.003124
# (Iteration 1501 / 2000) loss: 0.004753
# (Iteration 1511 / 2000) loss: 0.004851
# (Iteration 1521 / 2000) loss: 0.010515
# (Iteration 1531 / 2000) loss: 0.005100
# (Iteration 1541 / 2000) loss: 0.007328
# (Iteration 1551 / 2000) loss: 0.003363
# (Iteration 1561 / 2000) loss: 0.009498
# (Iteration 1571 / 2000) loss: 0.003427
# (Iteration 1581 / 2000) loss: 0.006564
# (Iteration 1591 / 2000) loss: 0.004719
# (Epoch 16 / 20) train acc: -0.001181; val_acc: -0.003124
# (Iteration 1601 / 2000) loss: 0.006693
# (Iteration 1611 / 2000) loss: 0.002846
# (Iteration 1621 / 2000) loss: 0.004062
# (Iteration 1631 / 2000) loss: 0.007630
# (Iteration 1641 / 2000) loss: 0.004781
# (Iteration 1651 / 2000) loss: 0.006010
# (Iteration 1661 / 2000) loss: 0.004797
# (Iteration 1671 / 2000) loss: 0.007462
# (Iteration 1681 / 2000) loss: 0.003420
# (Iteration 1691 / 2000) loss: 0.003482
# (Epoch 17 / 20) train acc: -0.001074; val_acc: -0.003124
# (Iteration 1701 / 2000) loss: 0.007592
# (Iteration 1711 / 2000) loss: 0.004887
# (Iteration 1721 / 2000) loss: 0.004689
# (Iteration 1731 / 2000) loss: 0.007431
# (Iteration 1741 / 2000) loss: 0.002517
# (Iteration 1751 / 2000) loss: 0.008726
# (Iteration 1761 / 2000) loss: 0.004874
# (Iteration 1771 / 2000) loss: 0.007379
# (Iteration 1781 / 2000) loss: 0.006976
# (Iteration 1791 / 2000) loss: 0.005752
# (Epoch 18 / 20) train acc: -0.000066; val_acc: -0.003124
# (Iteration 1801 / 2000) loss: 0.006042
# (Iteration 1811 / 2000) loss: 0.005618
# (Iteration 1821 / 2000) loss: 0.003892
# (Iteration 1831 / 2000) loss: 0.004423
# (Iteration 1841 / 2000) loss: 0.010290
# (Iteration 1851 / 2000) loss: 0.005876
# (Iteration 1861 / 2000) loss: 0.005518
# (Iteration 1871 / 2000) loss: 0.004694
# (Iteration 1881 / 2000) loss: 0.007680
# (Iteration 1891 / 2000) loss: 0.003826
# (Epoch 19 / 20) train acc: -0.000303; val_acc: -0.003124
# (Iteration 1901 / 2000) loss: 0.003592
# (Iteration 1911 / 2000) loss: 0.006224
# (Iteration 1921 / 2000) loss: 0.004463
# (Iteration 1931 / 2000) loss: 0.004642
# (Iteration 1941 / 2000) loss: 0.007126
# (Iteration 1951 / 2000) loss: 0.004739
# (Iteration 1961 / 2000) loss: 0.004703
# (Iteration 1971 / 2000) loss: 0.005370
# (Iteration 1981 / 2000) loss: 0.004122
# (Iteration 1991 / 2000) loss: 0.003803
# (Epoch 20 / 20) train acc: -0.005524; val_acc: -0.003124

# %% [markdown]
# Now follow the same framework shown in the subsample data, train the NN with full sample data.Try to tune the parameters and construct the neural network with different numbers of layers. Compare their results.

# %%
# NN with full data


##############################################################################
### TODO: NN with full data.                                               ###
##############################################################################

# NN with sample data

from solver import Solver
split = 0.9

num_train = int(factor.shape[0]*0.9)
num_valid = int(factor.shape[0]*0.1)

full_data = {
  'X_train': factor[:num_train],
  'y_train': nonlinear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': nonlinear_ret[num_train:num_train+num_valid]
}

learning_rate = 5*1e-3  # Experiment with this!
weight_scale = 1*1e-2   # Experiment with this!
model = FullyConnectedNet([100, 100,100],reg=5*1e-2,
                weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, full_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()

plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.title('Training and Validation accuracy')
plt.xlabel('Epoch')

plt.show()


##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
# Out:
# (Iteration 1 / 25920) loss: 0.082383
# (Epoch 0 / 20) train acc: -0.001244; val_acc: -0.000390
# (Iteration 11 / 25920) loss: 0.079340
# (Iteration 21 / 25920) loss: 0.080638
# (Iteration 31 / 25920) loss: 0.083895
# (Iteration 41 / 25920) loss: 0.080462
# (Iteration 51 / 25920) loss: 0.082897
# (Iteration 61 / 25920) loss: 0.079366
# (Iteration 71 / 25920) loss: 0.081727
# (Iteration 81 / 25920) loss: 0.078486
# (Iteration 91 / 25920) loss: 0.078032
# (Iteration 101 / 25920) loss: 0.078081
# (Iteration 111 / 25920) loss: 0.076988
# (Iteration 121 / 25920) loss: 0.085864
# (Iteration 131 / 25920) loss: 0.077115
# (Iteration 141 / 25920) loss: 0.079165
# (Iteration 151 / 25920) loss: 0.075814
# (Iteration 161 / 25920) loss: 0.074178
# (Iteration 171 / 25920) loss: 0.078081
# (Iteration 181 / 25920) loss: 0.077200
# (Iteration 191 / 25920) loss: 0.074101
# (Iteration 201 / 25920) loss: 0.076467
# (Iteration 211 / 25920) loss: 0.074809
# (Iteration 221 / 25920) loss: 0.073694
# (Iteration 231 / 25920) loss: 0.072882
# (Iteration 241 / 25920) loss: 0.073237
# (Iteration 251 / 25920) loss: 0.070104
# (Iteration 261 / 25920) loss: 0.076398
# (Iteration 271 / 25920) loss: 0.072333
# (Iteration 281 / 25920) loss: 0.071804
# (Iteration 291 / 25920) loss: 0.075600
# (Iteration 301 / 25920) loss: 0.069572
# (Iteration 311 / 25920) loss: 0.071118
# (Iteration 321 / 25920) loss: 0.069527
# (Iteration 331 / 25920) loss: 0.069245
# (Iteration 341 / 25920) loss: 0.072958
# (Iteration 351 / 25920) loss: 0.067264
# (Iteration 361 / 25920) loss: 0.073174
# (Iteration 371 / 25920) loss: 0.072263
# (Iteration 381 / 25920) loss: 0.066763
# (Iteration 391 / 25920) loss: 0.069195
# (Iteration 401 / 25920) loss: 0.069951
# (Iteration 411 / 25920) loss: 0.069919
# (Iteration 421 / 25920) loss: 0.072682
# (Iteration 431 / 25920) loss: 0.070412
# (Iteration 441 / 25920) loss: 0.069656
# (Iteration 451 / 25920) loss: 0.067070
# (Iteration 461 / 25920) loss: 0.066264
# (Iteration 471 / 25920) loss: 0.066863
# (Iteration 481 / 25920) loss: 0.064781
# (Iteration 491 / 25920) loss: 0.062943
# (Iteration 501 / 25920) loss: 0.062688
# (Iteration 511 / 25920) loss: 0.066168
# (Iteration 521 / 25920) loss: 0.069776
# (Iteration 531 / 25920) loss: 0.061899
# (Iteration 541 / 25920) loss: 0.060702
# (Iteration 551 / 25920) loss: 0.064379
# (Iteration 561 / 25920) loss: 0.063732
# (Iteration 571 / 25920) loss: 0.062508
# (Iteration 581 / 25920) loss: 0.063300
# (Iteration 591 / 25920) loss: 0.061493
# (Iteration 601 / 25920) loss: 0.066211
# (Iteration 611 / 25920) loss: 0.062367
# (Iteration 621 / 25920) loss: 0.061900
# (Iteration 631 / 25920) loss: 0.060581
# (Iteration 641 / 25920) loss: 0.061547
# (Iteration 651 / 25920) loss: 0.059219
# (Iteration 661 / 25920) loss: 0.060241
# (Iteration 671 / 25920) loss: 0.063900
# (Iteration 681 / 25920) loss: 0.059032
# (Iteration 691 / 25920) loss: 0.059938
# (Iteration 701 / 25920) loss: 0.057614
# (Iteration 711 / 25920) loss: 0.064861
# (Iteration 721 / 25920) loss: 0.058372
# (Iteration 731 / 25920) loss: 0.056902
# (Iteration 741 / 25920) loss: 0.058856
# (Iteration 751 / 25920) loss: 0.057473
# (Iteration 761 / 25920) loss: 0.057192
# (Iteration 771 / 25920) loss: 0.060066
# (Iteration 781 / 25920) loss: 0.058650
# (Iteration 791 / 25920) loss: 0.059404
# (Iteration 801 / 25920) loss: 0.057800
# (Iteration 811 / 25920) loss: 0.055917
# (Iteration 821 / 25920) loss: 0.056774
# (Iteration 831 / 25920) loss: 0.059414
# (Iteration 841 / 25920) loss: 0.055738
# (Iteration 851 / 25920) loss: 0.053795
# (Iteration 861 / 25920) loss: 0.056271
# (Iteration 871 / 25920) loss: 0.054398
# (Iteration 881 / 25920) loss: 0.056317
# (Iteration 891 / 25920) loss: 0.053579
# (Iteration 901 / 25920) loss: 0.053815
# (Iteration 911 / 25920) loss: 0.054237
# (Iteration 921 / 25920) loss: 0.054928
# (Iteration 931 / 25920) loss: 0.054096
# (Iteration 941 / 25920) loss: 0.057601
# (Iteration 951 / 25920) loss: 0.053646
# (Iteration 961 / 25920) loss: 0.056624
# (Iteration 971 / 25920) loss: 0.052956
# (Iteration 981 / 25920) loss: 0.052009
# (Iteration 991 / 25920) loss: 0.055819
# (Iteration 1001 / 25920) loss: 0.048560
# (Iteration 1011 / 25920) loss: 0.049442
# (Iteration 1021 / 25920) loss: 0.049584
# (Iteration 1031 / 25920) loss: 0.058118
# (Iteration 1041 / 25920) loss: 0.051222
# (Iteration 1051 / 25920) loss: 0.051291
# (Iteration 1061 / 25920) loss: 0.047947
# (Iteration 1071 / 25920) loss: 0.050040
# (Iteration 1081 / 25920) loss: 0.050937
# (Iteration 1091 / 25920) loss: 0.058451
# (Iteration 1101 / 25920) loss: 0.053128
# (Iteration 1111 / 25920) loss: 0.047763
# (Iteration 1121 / 25920) loss: 0.048407
# (Iteration 1131 / 25920) loss: 0.050209
# (Iteration 1141 / 25920) loss: 0.049493
# (Iteration 1151 / 25920) loss: 0.050192
# (Iteration 1161 / 25920) loss: 0.047423
# (Iteration 1171 / 25920) loss: 0.049252
# (Iteration 1181 / 25920) loss: 0.047448
# (Iteration 1191 / 25920) loss: 0.046053
# (Iteration 1201 / 25920) loss: 0.046178
# (Iteration 1211 / 25920) loss: 0.046131
# (Iteration 1221 / 25920) loss: 0.044316
# (Iteration 1231 / 25920) loss: 0.044426
# (Iteration 1241 / 25920) loss: 0.047795
# (Iteration 1251 / 25920) loss: 0.045095
# (Iteration 1261 / 25920) loss: 0.046158
# (Iteration 1271 / 25920) loss: 0.044678
# (Iteration 1281 / 25920) loss: 0.045725
# (Iteration 1291 / 25920) loss: 0.051315
# (Epoch 1 / 20) train acc: -0.003473; val_acc: -0.000390
# (Iteration 1301 / 25920) loss: 0.049810
# (Iteration 1311 / 25920) loss: 0.049080
# (Iteration 1321 / 25920) loss: 0.047859
# (Iteration 1331 / 25920) loss: 0.044487
# (Iteration 1341 / 25920) loss: 0.046267
# (Iteration 1351 / 25920) loss: 0.043703
# (Iteration 1361 / 25920) loss: 0.044406
# (Iteration 1371 / 25920) loss: 0.045140
# (Iteration 1381 / 25920) loss: 0.043705
# (Iteration 1391 / 25920) loss: 0.045069
# (Iteration 1401 / 25920) loss: 0.119434
# (Iteration 1411 / 25920) loss: 0.043906
# (Iteration 1421 / 25920) loss: 0.042868
# (Iteration 1431 / 25920) loss: 0.040872
# (Iteration 1441 / 25920) loss: 0.043766
# (Iteration 1451 / 25920) loss: 0.043720
# (Iteration 1461 / 25920) loss: 0.043116
# (Iteration 1471 / 25920) loss: 0.041444
# (Iteration 1481 / 25920) loss: 0.040832
# (Iteration 1491 / 25920) loss: 0.042229
# (Iteration 1501 / 25920) loss: 0.046859
# (Iteration 1511 / 25920) loss: 0.039317
# (Iteration 1521 / 25920) loss: 0.046090
# (Iteration 1531 / 25920) loss: 0.041191
# (Iteration 1541 / 25920) loss: 0.046218
# (Iteration 1551 / 25920) loss: 0.045795
# (Iteration 1561 / 25920) loss: 0.041342
# (Iteration 1571 / 25920) loss: 0.041265
# (Iteration 1581 / 25920) loss: 0.041463
# (Iteration 1591 / 25920) loss: 0.039941
# (Iteration 1601 / 25920) loss: 0.039874
# (Iteration 1611 / 25920) loss: 0.037551
# (Iteration 1621 / 25920) loss: 0.040920
# (Iteration 1631 / 25920) loss: 0.041020
# (Iteration 1641 / 25920) loss: 0.044064
# (Iteration 1651 / 25920) loss: 0.039258
# (Iteration 1661 / 25920) loss: 0.041096
# (Iteration 1671 / 25920) loss: 0.037166
# (Iteration 1681 / 25920) loss: 0.039212
# (Iteration 1691 / 25920) loss: 0.036324
# (Iteration 1701 / 25920) loss: 0.038107
# (Iteration 1711 / 25920) loss: 0.038631
# (Iteration 1721 / 25920) loss: 0.037773
# (Iteration 1731 / 25920) loss: 0.044986
# (Iteration 1741 / 25920) loss: 0.042616
# (Iteration 1751 / 25920) loss: 0.039044
# (Iteration 1761 / 25920) loss: 0.036957
# (Iteration 1771 / 25920) loss: 0.036253
# (Iteration 1781 / 25920) loss: 0.041174
# (Iteration 1791 / 25920) loss: 0.038722
# (Iteration 1801 / 25920) loss: 0.039038
# (Iteration 1811 / 25920) loss: 0.036820
# (Iteration 1821 / 25920) loss: 0.034292
# (Iteration 1831 / 25920) loss: 0.036456
# (Iteration 1841 / 25920) loss: 0.038309
# (Iteration 1851 / 25920) loss: 0.037730
# (Iteration 1861 / 25920) loss: 0.044547
# (Iteration 1871 / 25920) loss: 0.034154
# (Iteration 1881 / 25920) loss: 0.035696
# (Iteration 1891 / 25920) loss: 0.040001
# (Iteration 1901 / 25920) loss: 0.034998
# (Iteration 1911 / 25920) loss: 0.039161
# (Iteration 1921 / 25920) loss: 0.034946
# (Iteration 1931 / 25920) loss: 0.034387
# (Iteration 1941 / 25920) loss: 0.032284
# (Iteration 1951 / 25920) loss: 0.036960
# (Iteration 1961 / 25920) loss: 0.033532
# (Iteration 1971 / 25920) loss: 0.031129
# (Iteration 1981 / 25920) loss: 0.034956
# (Iteration 1991 / 25920) loss: 0.035147
# (Iteration 2001 / 25920) loss: 0.039665
# (Iteration 2011 / 25920) loss: 0.032242
# (Iteration 2021 / 25920) loss: 0.039681
# (Iteration 2031 / 25920) loss: 0.033081
# (Iteration 2041 / 25920) loss: 0.030621
# (Iteration 2051 / 25920) loss: 0.031697
# (Iteration 2061 / 25920) loss: 0.034188
# (Iteration 2071 / 25920) loss: 0.037084
# (Iteration 2081 / 25920) loss: 0.037914
# (Iteration 2091 / 25920) loss: 0.032562
# (Iteration 2101 / 25920) loss: 0.031037
# (Iteration 2111 / 25920) loss: 0.035213
# (Iteration 2121 / 25920) loss: 0.033612
# (Iteration 2131 / 25920) loss: 0.030005
# (Iteration 2141 / 25920) loss: 0.030911
# (Iteration 2151 / 25920) loss: 0.035431
# (Iteration 2161 / 25920) loss: 0.029487
# (Iteration 2171 / 25920) loss: 0.031325
# (Iteration 2181 / 25920) loss: 0.032154
# (Iteration 2191 / 25920) loss: 0.032510
# (Iteration 2201 / 25920) loss: 0.032022
# (Iteration 2211 / 25920) loss: 0.028657
# (Iteration 2221 / 25920) loss: 0.030810
# (Iteration 2231 / 25920) loss: 0.036403
# (Iteration 2241 / 25920) loss: 0.032252
# (Iteration 2251 / 25920) loss: 0.029215
# (Iteration 2261 / 25920) loss: 0.031523
# (Iteration 2271 / 25920) loss: 0.028880
# (Iteration 2281 / 25920) loss: 0.030959
# (Iteration 2291 / 25920) loss: 0.027829
# (Iteration 2301 / 25920) loss: 0.031088
# (Iteration 2311 / 25920) loss: 0.036312
# (Iteration 2321 / 25920) loss: 0.030994
# (Iteration 2331 / 25920) loss: 0.029436
# (Iteration 2341 / 25920) loss: 0.028889
# (Iteration 2351 / 25920) loss: 0.033683
# (Iteration 2361 / 25920) loss: 0.031904
# (Iteration 2371 / 25920) loss: 0.030434
# (Iteration 2381 / 25920) loss: 0.027991
# (Iteration 2391 / 25920) loss: 0.026924
# (Iteration 2401 / 25920) loss: 0.032445
# (Iteration 2411 / 25920) loss: 0.028456
# (Iteration 2421 / 25920) loss: 0.034776
# (Iteration 2431 / 25920) loss: 0.032432
# (Iteration 2441 / 25920) loss: 0.027493
# (Iteration 2451 / 25920) loss: 0.103798
# (Iteration 2461 / 25920) loss: 0.034968
# (Iteration 2471 / 25920) loss: 0.029835
# (Iteration 2481 / 25920) loss: 0.030720
# (Iteration 2491 / 25920) loss: 0.029901
# (Iteration 2501 / 25920) loss: 0.025423
# (Iteration 2511 / 25920) loss: 0.031819
# (Iteration 2521 / 25920) loss: 0.027253
# (Iteration 2531 / 25920) loss: 0.028395
# (Iteration 2541 / 25920) loss: 0.026345
# (Iteration 2551 / 25920) loss: 0.025832
# (Iteration 2561 / 25920) loss: 0.027604
# (Iteration 2571 / 25920) loss: 0.025480
# (Iteration 2581 / 25920) loss: 0.030529
# (Iteration 2591 / 25920) loss: 0.035263
# (Epoch 2 / 20) train acc: -0.001332; val_acc: -0.000390
# (Iteration 2601 / 25920) loss: 0.025798
# (Iteration 2611 / 25920) loss: 0.024455
# (Iteration 2621 / 25920) loss: 0.025229
# (Iteration 2631 / 25920) loss: 0.027675
# (Iteration 2641 / 25920) loss: 0.032129
# (Iteration 2651 / 25920) loss: 0.026903
# (Iteration 2661 / 25920) loss: 0.029186
# (Iteration 2671 / 25920) loss: 0.032671
# (Iteration 2681 / 25920) loss: 0.026026
# (Iteration 2691 / 25920) loss: 0.024213
# (Iteration 2701 / 25920) loss: 0.026812
# (Iteration 2711 / 25920) loss: 0.026321
# (Iteration 2721 / 25920) loss: 0.025959
# (Iteration 2731 / 25920) loss: 0.022812
# (Iteration 2741 / 25920) loss: 0.026581
# (Iteration 2751 / 25920) loss: 0.027460
# (Iteration 2761 / 25920) loss: 0.025254
# (Iteration 2771 / 25920) loss: 0.023057
# (Iteration 2781 / 25920) loss: 0.023297
# (Iteration 2791 / 25920) loss: 0.023101
# (Iteration 2801 / 25920) loss: 0.025307
# (Iteration 2811 / 25920) loss: 0.023822
# (Iteration 2821 / 25920) loss: 0.023783
# (Iteration 2831 / 25920) loss: 0.023996
# (Iteration 2841 / 25920) loss: 0.024424
# (Iteration 2851 / 25920) loss: 0.025027
# (Iteration 2861 / 25920) loss: 0.027009
# (Iteration 2871 / 25920) loss: 0.023143
# (Iteration 2881 / 25920) loss: 0.024468
# (Iteration 2891 / 25920) loss: 0.027485
# (Iteration 2901 / 25920) loss: 0.026506
# (Iteration 2911 / 25920) loss: 0.021277
# (Iteration 2921 / 25920) loss: 0.021252
# (Iteration 2931 / 25920) loss: 0.024466
# (Iteration 2941 / 25920) loss: 0.023712
# (Iteration 2951 / 25920) loss: 0.023520
# (Iteration 2961 / 25920) loss: 0.025977
# (Iteration 2971 / 25920) loss: 0.027714
# (Iteration 2981 / 25920) loss: 0.023165
# (Iteration 2991 / 25920) loss: 0.029021
# (Iteration 3001 / 25920) loss: 0.024200
# (Iteration 3011 / 25920) loss: 0.022453
# (Iteration 3021 / 25920) loss: 0.023457
# (Iteration 3031 / 25920) loss: 0.022577
# (Iteration 3041 / 25920) loss: 0.022906
# (Iteration 3051 / 25920) loss: 0.020976
# (Iteration 3061 / 25920) loss: 0.022708
# (Iteration 3071 / 25920) loss: 0.019946
# (Iteration 3081 / 25920) loss: 0.025288
# (Iteration 3091 / 25920) loss: 0.020841
# (Iteration 3101 / 25920) loss: 0.020802
# (Iteration 3111 / 25920) loss: 0.025780
# (Iteration 3121 / 25920) loss: 0.023325
# (Iteration 3131 / 25920) loss: 0.022601
# (Iteration 3141 / 25920) loss: 0.023885
# (Iteration 3151 / 25920) loss: 0.022247
# (Iteration 3161 / 25920) loss: 0.021809
# (Iteration 3171 / 25920) loss: 0.019490
# (Iteration 3181 / 25920) loss: 0.018283
# (Iteration 3191 / 25920) loss: 0.021066
# (Iteration 3201 / 25920) loss: 0.026582
# (Iteration 3211 / 25920) loss: 0.022173
# (Iteration 3221 / 25920) loss: 0.021675
# (Iteration 3231 / 25920) loss: 0.025377
# (Iteration 3241 / 25920) loss: 0.026870
# (Iteration 3251 / 25920) loss: 0.020668
# (Iteration 3261 / 25920) loss: 0.026915
# (Iteration 3271 / 25920) loss: 0.019127
# (Iteration 3281 / 25920) loss: 0.020002
# (Iteration 3291 / 25920) loss: 0.020916
# (Iteration 3301 / 25920) loss: 0.020971
# (Iteration 3311 / 25920) loss: 0.021718
# (Iteration 3321 / 25920) loss: 0.018666
# (Iteration 3331 / 25920) loss: 0.021343
# (Iteration 3341 / 25920) loss: 0.022974
# (Iteration 3351 / 25920) loss: 0.017079
# (Iteration 3361 / 25920) loss: 0.019370
# (Iteration 3371 / 25920) loss: 0.022165
# (Iteration 3381 / 25920) loss: 0.019650
# (Iteration 3391 / 25920) loss: 0.020804
# (Iteration 3401 / 25920) loss: 0.018920
# (Iteration 3411 / 25920) loss: 0.024091
# (Iteration 3421 / 25920) loss: 0.018983
# (Iteration 3431 / 25920) loss: 0.019370
# (Iteration 3441 / 25920) loss: 0.021626
# (Iteration 3451 / 25920) loss: 0.018540
# (Iteration 3461 / 25920) loss: 0.020028
# (Iteration 3471 / 25920) loss: 0.016644
# (Iteration 3481 / 25920) loss: 0.019723
# (Iteration 3491 / 25920) loss: 0.019746
# (Iteration 3501 / 25920) loss: 0.018912
# (Iteration 3511 / 25920) loss: 0.017893
# (Iteration 3521 / 25920) loss: 0.020802
# (Iteration 3531 / 25920) loss: 0.018990
# (Iteration 3541 / 25920) loss: 0.016951
# (Iteration 3551 / 25920) loss: 0.017974
# (Iteration 3561 / 25920) loss: 0.022944
# (Iteration 3571 / 25920) loss: 0.019725
# (Iteration 3581 / 25920) loss: 0.023165
# (Iteration 3591 / 25920) loss: 0.020974
# (Iteration 3601 / 25920) loss: 0.019081
# (Iteration 3611 / 25920) loss: 0.019573
# (Iteration 3621 / 25920) loss: 0.020213
# (Iteration 3631 / 25920) loss: 0.019601
# (Iteration 3641 / 25920) loss: 0.016756
# (Iteration 3651 / 25920) loss: 0.022645
# (Iteration 3661 / 25920) loss: 0.017388
# (Iteration 3671 / 25920) loss: 0.017525
# (Iteration 3681 / 25920) loss: 0.022063
# (Iteration 3691 / 25920) loss: 0.017455
# (Iteration 3701 / 25920) loss: 0.019311
# (Iteration 3711 / 25920) loss: 0.017216
# (Iteration 3721 / 25920) loss: 0.022710
# (Iteration 3731 / 25920) loss: 0.017937
# (Iteration 3741 / 25920) loss: 0.020305
# (Iteration 3751 / 25920) loss: 0.014319
# (Iteration 3761 / 25920) loss: 0.018370
# (Iteration 3771 / 25920) loss: 0.020191
# (Iteration 3781 / 25920) loss: 0.019727
# (Iteration 3791 / 25920) loss: 0.017991
# (Iteration 3801 / 25920) loss: 0.013527
# (Iteration 3811 / 25920) loss: 0.017874
# (Iteration 3821 / 25920) loss: 0.016193
# (Iteration 3831 / 25920) loss: 0.019386
# (Iteration 3841 / 25920) loss: 0.018770
# (Iteration 3851 / 25920) loss: 0.018909
# (Iteration 3861 / 25920) loss: 0.016711
# (Iteration 3871 / 25920) loss: 0.015226
# (Iteration 3881 / 25920) loss: 0.020270
# (Epoch 3 / 20) train acc: -0.000036; val_acc: -0.000390
# (Iteration 3891 / 25920) loss: 0.016511
# (Iteration 3901 / 25920) loss: 0.020792
# (Iteration 3911 / 25920) loss: 0.015679
# (Iteration 3921 / 25920) loss: 0.015253
# (Iteration 3931 / 25920) loss: 0.017114
# (Iteration 3941 / 25920) loss: 0.015009
# (Iteration 3951 / 25920) loss: 0.013788
# (Iteration 3961 / 25920) loss: 0.016877
# (Iteration 3971 / 25920) loss: 0.016278
# (Iteration 3981 / 25920) loss: 0.019700
# (Iteration 3991 / 25920) loss: 0.016386
# (Iteration 4001 / 25920) loss: 0.017300
# (Iteration 4011 / 25920) loss: 0.014874
# (Iteration 4021 / 25920) loss: 0.022488
# (Iteration 4031 / 25920) loss: 0.014894
# (Iteration 4041 / 25920) loss: 0.016637
# (Iteration 4051 / 25920) loss: 0.024094
# (Iteration 4061 / 25920) loss: 0.017052
# (Iteration 4071 / 25920) loss: 0.016335
# (Iteration 4081 / 25920) loss: 0.019223
# (Iteration 4091 / 25920) loss: 0.017989
# (Iteration 4101 / 25920) loss: 0.015556
# (Iteration 4111 / 25920) loss: 0.018844
# (Iteration 4121 / 25920) loss: 0.015920
# (Iteration 4131 / 25920) loss: 0.017579
# (Iteration 4141 / 25920) loss: 0.019755
# (Iteration 4151 / 25920) loss: 0.014606
# (Iteration 4161 / 25920) loss: 0.013673
# (Iteration 4171 / 25920) loss: 0.014630
# (Iteration 4181 / 25920) loss: 0.014240
# (Iteration 4191 / 25920) loss: 0.015221
# (Iteration 4201 / 25920) loss: 0.016165
# (Iteration 4211 / 25920) loss: 0.020859
# (Iteration 4221 / 25920) loss: 0.011548
# (Iteration 4231 / 25920) loss: 0.018841
# (Iteration 4241 / 25920) loss: 0.013119
# (Iteration 4251 / 25920) loss: 0.015927
# (Iteration 4261 / 25920) loss: 0.014781
# (Iteration 4271 / 25920) loss: 0.015695
# (Iteration 4281 / 25920) loss: 0.016245
# (Iteration 4291 / 25920) loss: 0.014673
# (Iteration 4301 / 25920) loss: 0.015484
# (Iteration 4311 / 25920) loss: 0.014482
# (Iteration 4321 / 25920) loss: 0.016784
# (Iteration 4331 / 25920) loss: 0.016626
# (Iteration 4341 / 25920) loss: 0.016599
# (Iteration 4351 / 25920) loss: 0.012946
# (Iteration 4361 / 25920) loss: 0.013039
# (Iteration 4371 / 25920) loss: 0.012942
# (Iteration 4381 / 25920) loss: 0.014239
# (Iteration 4391 / 25920) loss: 0.028406
# (Iteration 4401 / 25920) loss: 0.015642
# (Iteration 4411 / 25920) loss: 0.013857
# (Iteration 4421 / 25920) loss: 0.017844
# (Iteration 4431 / 25920) loss: 0.015814
# (Iteration 4441 / 25920) loss: 0.014541
# (Iteration 4451 / 25920) loss: 0.014492
# (Iteration 4461 / 25920) loss: 0.014465
# (Iteration 4471 / 25920) loss: 0.012829
# (Iteration 4481 / 25920) loss: 0.018478
# (Iteration 4491 / 25920) loss: 0.014588
# (Iteration 4501 / 25920) loss: 0.014747
# (Iteration 4511 / 25920) loss: 0.012115
# (Iteration 4521 / 25920) loss: 0.016609
# (Iteration 4531 / 25920) loss: 0.015114
# (Iteration 4541 / 25920) loss: 0.017054
# (Iteration 4551 / 25920) loss: 0.014193
# (Iteration 4561 / 25920) loss: 0.018542
# (Iteration 4571 / 25920) loss: 0.014770
# (Iteration 4581 / 25920) loss: 0.015356
# (Iteration 4591 / 25920) loss: 0.014190
# (Iteration 4601 / 25920) loss: 0.014050
# (Iteration 4611 / 25920) loss: 0.013708
# (Iteration 4621 / 25920) loss: 0.009997
# (Iteration 4631 / 25920) loss: 0.011851
# (Iteration 4641 / 25920) loss: 0.012992
# (Iteration 4651 / 25920) loss: 0.011565
# (Iteration 4661 / 25920) loss: 0.018486
# (Iteration 4671 / 25920) loss: 0.011109
# (Iteration 4681 / 25920) loss: 0.017310
# (Iteration 4691 / 25920) loss: 0.015240
# (Iteration 4701 / 25920) loss: 0.014019
# (Iteration 4711 / 25920) loss: 0.013276
# (Iteration 4721 / 25920) loss: 0.012960
# (Iteration 4731 / 25920) loss: 0.012968
# (Iteration 4741 / 25920) loss: 0.015646
# (Iteration 4751 / 25920) loss: 0.011073
# (Iteration 4761 / 25920) loss: 0.017953
# (Iteration 4771 / 25920) loss: 0.013726
# (Iteration 4781 / 25920) loss: 0.011602
# (Iteration 4791 / 25920) loss: 0.016104
# (Iteration 4801 / 25920) loss: 0.014108
# (Iteration 4811 / 25920) loss: 0.016833
# (Iteration 4821 / 25920) loss: 0.014143
# (Iteration 4831 / 25920) loss: 0.015480
# (Iteration 4841 / 25920) loss: 0.015024
# (Iteration 4851 / 25920) loss: 0.015435
# (Iteration 4861 / 25920) loss: 0.016116
# (Iteration 4871 / 25920) loss: 0.012324
# (Iteration 4881 / 25920) loss: 0.011639
# (Iteration 4891 / 25920) loss: 0.015645
# (Iteration 4901 / 25920) loss: 0.012715
# (Iteration 4911 / 25920) loss: 0.018147
# (Iteration 4921 / 25920) loss: 0.014114
# (Iteration 4931 / 25920) loss: 0.009588
# (Iteration 4941 / 25920) loss: 0.010933
# (Iteration 4951 / 25920) loss: 0.014007
# (Iteration 4961 / 25920) loss: 0.010294
# (Iteration 4971 / 25920) loss: 0.012938
# (Iteration 4981 / 25920) loss: 0.011712
# (Iteration 4991 / 25920) loss: 0.015342
# (Iteration 5001 / 25920) loss: 0.010962
# (Iteration 5011 / 25920) loss: 0.009068
# (Iteration 5021 / 25920) loss: 0.013121
# (Iteration 5031 / 25920) loss: 0.013715
# (Iteration 5041 / 25920) loss: 0.013518
# (Iteration 5051 / 25920) loss: 0.012932
# (Iteration 5061 / 25920) loss: 0.011165
# (Iteration 5071 / 25920) loss: 0.012641
# (Iteration 5081 / 25920) loss: 0.010000
# (Iteration 5091 / 25920) loss: 0.010405
# (Iteration 5101 / 25920) loss: 0.013714
# (Iteration 5111 / 25920) loss: 0.011674
# (Iteration 5121 / 25920) loss: 0.011445
# (Iteration 5131 / 25920) loss: 0.013522
# (Iteration 5141 / 25920) loss: 0.009126
# (Iteration 5151 / 25920) loss: 0.011667
# (Iteration 5161 / 25920) loss: 0.016266
# (Iteration 5171 / 25920) loss: 0.010492
# (Iteration 5181 / 25920) loss: 0.011866
# (Epoch 4 / 20) train acc: -0.000075; val_acc: -0.000390
# (Iteration 5191 / 25920) loss: 0.011750
# (Iteration 5201 / 25920) loss: 0.009809
# (Iteration 5211 / 25920) loss: 0.011210
# (Iteration 5221 / 25920) loss: 0.014086
# (Iteration 5231 / 25920) loss: 0.015042
# (Iteration 5241 / 25920) loss: 0.011352
# (Iteration 5251 / 25920) loss: 0.013822
# (Iteration 5261 / 25920) loss: 0.009694
# (Iteration 5271 / 25920) loss: 0.012947
# (Iteration 5281 / 25920) loss: 0.012739
# (Iteration 5291 / 25920) loss: 0.012824
# (Iteration 5301 / 25920) loss: 0.009310
# (Iteration 5311 / 25920) loss: 0.013324
# (Iteration 5321 / 25920) loss: 0.010353
# (Iteration 5331 / 25920) loss: 0.021841
# (Iteration 5341 / 25920) loss: 0.009721
# (Iteration 5351 / 25920) loss: 0.011139
# (Iteration 5361 / 25920) loss: 0.013420
# (Iteration 5371 / 25920) loss: 0.009056
# (Iteration 5381 / 25920) loss: 0.008808
# (Iteration 5391 / 25920) loss: 0.013787
# (Iteration 5401 / 25920) loss: 0.017431
# (Iteration 5411 / 25920) loss: 0.013214
# (Iteration 5421 / 25920) loss: 0.008662
# (Iteration 5431 / 25920) loss: 0.013039
# (Iteration 5441 / 25920) loss: 0.012659
# (Iteration 5451 / 25920) loss: 0.009805
# (Iteration 5461 / 25920) loss: 0.014633
# (Iteration 5471 / 25920) loss: 0.009246
# (Iteration 5481 / 25920) loss: 0.013428
# (Iteration 5491 / 25920) loss: 0.009256
# (Iteration 5501 / 25920) loss: 0.012225
# (Iteration 5511 / 25920) loss: 0.009155
# (Iteration 5521 / 25920) loss: 0.008905
# (Iteration 5531 / 25920) loss: 0.008573
# (Iteration 5541 / 25920) loss: 0.011961
# (Iteration 5551 / 25920) loss: 0.011192
# (Iteration 5561 / 25920) loss: 0.011129
# (Iteration 5571 / 25920) loss: 0.009846
# (Iteration 5581 / 25920) loss: 0.012722
# (Iteration 5591 / 25920) loss: 0.011504
# (Iteration 5601 / 25920) loss: 0.009605
# (Iteration 5611 / 25920) loss: 0.009220
# (Iteration 5621 / 25920) loss: 0.010744
# (Iteration 5631 / 25920) loss: 0.014501
# (Iteration 5641 / 25920) loss: 0.013699
# (Iteration 5651 / 25920) loss: 0.013439
# (Iteration 5661 / 25920) loss: 0.018694
# (Iteration 5671 / 25920) loss: 0.011207
# (Iteration 5681 / 25920) loss: 0.014568
# (Iteration 5691 / 25920) loss: 0.013481
# (Iteration 5701 / 25920) loss: 0.011196
# (Iteration 5711 / 25920) loss: 0.015715
# (Iteration 5721 / 25920) loss: 0.009896
# (Iteration 5731 / 25920) loss: 0.006921
# (Iteration 5741 / 25920) loss: 0.008280
# (Iteration 5751 / 25920) loss: 0.009943
# (Iteration 5761 / 25920) loss: 0.011839
# (Iteration 5771 / 25920) loss: 0.010179
# (Iteration 5781 / 25920) loss: 0.019014
# (Iteration 5791 / 25920) loss: 0.010061
# (Iteration 5801 / 25920) loss: 0.009198
# (Iteration 5811 / 25920) loss: 0.018167
# (Iteration 5821 / 25920) loss: 0.008237
# (Iteration 5831 / 25920) loss: 0.011693
# (Iteration 5841 / 25920) loss: 0.010761
# (Iteration 5851 / 25920) loss: 0.012730
# (Iteration 5861 / 25920) loss: 0.012854
# (Iteration 5871 / 25920) loss: 0.007798
# (Iteration 5881 / 25920) loss: 0.009818
# (Iteration 5891 / 25920) loss: 0.009631
# (Iteration 5901 / 25920) loss: 0.011359
# (Iteration 5911 / 25920) loss: 0.010118
# (Iteration 5921 / 25920) loss: 0.008902
# (Iteration 5931 / 25920) loss: 0.012860
# (Iteration 5941 / 25920) loss: 0.008084
# (Iteration 5951 / 25920) loss: 0.008288
# (Iteration 5961 / 25920) loss: 0.008789
# (Iteration 5971 / 25920) loss: 0.012458
# (Iteration 5981 / 25920) loss: 0.011251
# (Iteration 5991 / 25920) loss: 0.008085
# (Iteration 6001 / 25920) loss: 0.011255
# (Iteration 6011 / 25920) loss: 0.014517
# (Iteration 6021 / 25920) loss: 0.009093
# (Iteration 6031 / 25920) loss: 0.008721
# (Iteration 6041 / 25920) loss: 0.007022
# (Iteration 6051 / 25920) loss: 0.009188
# (Iteration 6061 / 25920) loss: 0.010997
# (Iteration 6071 / 25920) loss: 0.013971
# (Iteration 6081 / 25920) loss: 0.011998
# (Iteration 6091 / 25920) loss: 0.013067
# (Iteration 6101 / 25920) loss: 0.013746
# (Iteration 6111 / 25920) loss: 0.008705
# (Iteration 6121 / 25920) loss: 0.016649
# (Iteration 6131 / 25920) loss: 0.008609
# (Iteration 6141 / 25920) loss: 0.013131
# (Iteration 6151 / 25920) loss: 0.009037
# (Iteration 6161 / 25920) loss: 0.008153
# (Iteration 6171 / 25920) loss: 0.014868
# (Iteration 6181 / 25920) loss: 0.010550
# (Iteration 6191 / 25920) loss: 0.016910
# (Iteration 6201 / 25920) loss: 0.008308
# (Iteration 6211 / 25920) loss: 0.009668
# (Iteration 6221 / 25920) loss: 0.009937
# (Iteration 6231 / 25920) loss: 0.007217
# (Iteration 6241 / 25920) loss: 0.010821
# (Iteration 6251 / 25920) loss: 0.016130
# (Iteration 6261 / 25920) loss: 0.010726
# (Iteration 6271 / 25920) loss: 0.010400
# (Iteration 6281 / 25920) loss: 0.009884
# (Iteration 6291 / 25920) loss: 0.009679
# (Iteration 6301 / 25920) loss: 0.008370
# (Iteration 6311 / 25920) loss: 0.009682
# (Iteration 6321 / 25920) loss: 0.012382
# (Iteration 6331 / 25920) loss: 0.013141
# (Iteration 6341 / 25920) loss: 0.013328
# (Iteration 6351 / 25920) loss: 0.013209
# (Iteration 6361 / 25920) loss: 0.008050
# (Iteration 6371 / 25920) loss: 0.009908
# (Iteration 6381 / 25920) loss: 0.010528
# (Iteration 6391 / 25920) loss: 0.010116
# (Iteration 6401 / 25920) loss: 0.009349
# (Iteration 6411 / 25920) loss: 0.008888
# (Iteration 6421 / 25920) loss: 0.006082
# (Iteration 6431 / 25920) loss: 0.012020
# (Iteration 6441 / 25920) loss: 0.012463
# (Iteration 6451 / 25920) loss: 0.012121
# (Iteration 6461 / 25920) loss: 0.013093
# (Iteration 6471 / 25920) loss: 0.010640
# (Epoch 5 / 20) train acc: -0.001540; val_acc: -0.000390
# (Iteration 6481 / 25920) loss: 0.013822
# (Iteration 6491 / 25920) loss: 0.009548
# (Iteration 6501 / 25920) loss: 0.014902
# (Iteration 6511 / 25920) loss: 0.008324
# (Iteration 6521 / 25920) loss: 0.009073
# (Iteration 6531 / 25920) loss: 0.007750
# (Iteration 6541 / 25920) loss: 0.012502
# (Iteration 6551 / 25920) loss: 0.007326
# (Iteration 6561 / 25920) loss: 0.013066
# (Iteration 6571 / 25920) loss: 0.008180
# (Iteration 6581 / 25920) loss: 0.007178
# (Iteration 6591 / 25920) loss: 0.007904
# (Iteration 6601 / 25920) loss: 0.009715
# (Iteration 6611 / 25920) loss: 0.008545
# (Iteration 6621 / 25920) loss: 0.008508
# (Iteration 6631 / 25920) loss: 0.010308
# (Iteration 6641 / 25920) loss: 0.011700
# (Iteration 6651 / 25920) loss: 0.011101
# (Iteration 6661 / 25920) loss: 0.005891
# (Iteration 6671 / 25920) loss: 0.006490
# (Iteration 6681 / 25920) loss: 0.018385
# (Iteration 6691 / 25920) loss: 0.010053
# (Iteration 6701 / 25920) loss: 0.008505
# (Iteration 6711 / 25920) loss: 0.012672
# (Iteration 6721 / 25920) loss: 0.011498
# (Iteration 6731 / 25920) loss: 0.009908
# (Iteration 6741 / 25920) loss: 0.010070
# (Iteration 6751 / 25920) loss: 0.007164
# (Iteration 6761 / 25920) loss: 0.007625
# (Iteration 6771 / 25920) loss: 0.006122
# (Iteration 6781 / 25920) loss: 0.013413
# (Iteration 6791 / 25920) loss: 0.011162
# (Iteration 6801 / 25920) loss: 0.008275
# (Iteration 6811 / 25920) loss: 0.006740
# (Iteration 6821 / 25920) loss: 0.005898
# (Iteration 6831 / 25920) loss: 0.009321
# (Iteration 6841 / 25920) loss: 0.013975
# (Iteration 6851 / 25920) loss: 0.009815
# (Iteration 6861 / 25920) loss: 0.008594
# (Iteration 6871 / 25920) loss: 0.006057
# (Iteration 6881 / 25920) loss: 0.019256
# (Iteration 6891 / 25920) loss: 0.008196
# (Iteration 6901 / 25920) loss: 0.015109
# (Iteration 6911 / 25920) loss: 0.008070
# (Iteration 6921 / 25920) loss: 0.009600
# (Iteration 6931 / 25920) loss: 0.007891
# (Iteration 6941 / 25920) loss: 0.008865
# (Iteration 6951 / 25920) loss: 0.008096
# (Iteration 6961 / 25920) loss: 0.008789
# (Iteration 6971 / 25920) loss: 0.009435
# (Iteration 6981 / 25920) loss: 0.012383
# (Iteration 6991 / 25920) loss: 0.007422
# (Iteration 7001 / 25920) loss: 0.011933
# (Iteration 7011 / 25920) loss: 0.006662
# (Iteration 7021 / 25920) loss: 0.007286
# (Iteration 7031 / 25920) loss: 0.008042
# (Iteration 7041 / 25920) loss: 0.008195
# (Iteration 7051 / 25920) loss: 0.010314
# (Iteration 7061 / 25920) loss: 0.008499
# (Iteration 7071 / 25920) loss: 0.005443
# (Iteration 7081 / 25920) loss: 0.011980
# (Iteration 7091 / 25920) loss: 0.009036
# (Iteration 7101 / 25920) loss: 0.007371
# (Iteration 7111 / 25920) loss: 0.008442
# (Iteration 7121 / 25920) loss: 0.005239
# (Iteration 7131 / 25920) loss: 0.005790
# (Iteration 7141 / 25920) loss: 0.010737
# (Iteration 7151 / 25920) loss: 0.011476
# (Iteration 7161 / 25920) loss: 0.007197
# (Iteration 7171 / 25920) loss: 0.007032
# (Iteration 7181 / 25920) loss: 0.009720
# (Iteration 7191 / 25920) loss: 0.009658
# (Iteration 7201 / 25920) loss: 0.007768
# (Iteration 7211 / 25920) loss: 0.007299
# (Iteration 7221 / 25920) loss: 0.005091
# (Iteration 7231 / 25920) loss: 0.009969
# (Iteration 7241 / 25920) loss: 0.010341
# (Iteration 7251 / 25920) loss: 0.008401
# (Iteration 7261 / 25920) loss: 0.008427
# (Iteration 7271 / 25920) loss: 0.009987
# (Iteration 7281 / 25920) loss: 0.010425
# (Iteration 7291 / 25920) loss: 0.008264
# (Iteration 7301 / 25920) loss: 0.011484
# (Iteration 7311 / 25920) loss: 0.007478
# (Iteration 7321 / 25920) loss: 0.006612
# (Iteration 7331 / 25920) loss: 0.012048
# (Iteration 7341 / 25920) loss: 0.006345
# (Iteration 7351 / 25920) loss: 0.007127
# (Iteration 7361 / 25920) loss: 0.006134
# (Iteration 7371 / 25920) loss: 0.007773
# (Iteration 7381 / 25920) loss: 0.005879
# (Iteration 7391 / 25920) loss: 0.012220
# (Iteration 7401 / 25920) loss: 0.010316
# (Iteration 7411 / 25920) loss: 0.007523
# (Iteration 7421 / 25920) loss: 0.010317
# (Iteration 7431 / 25920) loss: 0.011501
# (Iteration 7441 / 25920) loss: 0.007603
# (Iteration 7451 / 25920) loss: 0.011874
# (Iteration 7461 / 25920) loss: 0.005783
# (Iteration 7471 / 25920) loss: 0.008973
# (Iteration 7481 / 25920) loss: 0.006887
# (Iteration 7491 / 25920) loss: 0.007030
# (Iteration 7501 / 25920) loss: 0.008986
# (Iteration 7511 / 25920) loss: 0.008041
# (Iteration 7521 / 25920) loss: 0.009043
# (Iteration 7531 / 25920) loss: 0.011339
# (Iteration 7541 / 25920) loss: 0.007439
# (Iteration 7551 / 25920) loss: 0.010644
# (Iteration 7561 / 25920) loss: 0.009942
# (Iteration 7571 / 25920) loss: 0.004807
# (Iteration 7581 / 25920) loss: 0.009111
# (Iteration 7591 / 25920) loss: 0.010004
# (Iteration 7601 / 25920) loss: 0.005655
# (Iteration 7611 / 25920) loss: 0.007267
# (Iteration 7621 / 25920) loss: 0.007867
# (Iteration 7631 / 25920) loss: 0.010317
# (Iteration 7641 / 25920) loss: 0.005053
# (Iteration 7651 / 25920) loss: 0.015056
# (Iteration 7661 / 25920) loss: 0.009364
# (Iteration 7671 / 25920) loss: 0.007515
# (Iteration 7681 / 25920) loss: 0.009466
# (Iteration 7691 / 25920) loss: 0.013066
# (Iteration 7701 / 25920) loss: 0.006179
# (Iteration 7711 / 25920) loss: 0.007259
# (Iteration 7721 / 25920) loss: 0.009382
# (Iteration 7731 / 25920) loss: 0.009645
# (Iteration 7741 / 25920) loss: 0.010993
# (Iteration 7751 / 25920) loss: 0.008495
# (Iteration 7761 / 25920) loss: 0.007802
# (Iteration 7771 / 25920) loss: 0.007314
# (Epoch 6 / 20) train acc: -0.000378; val_acc: -0.000390
# (Iteration 7781 / 25920) loss: 0.011228
# (Iteration 7791 / 25920) loss: 0.008317
# (Iteration 7801 / 25920) loss: 0.006973
# (Iteration 7811 / 25920) loss: 0.013840
# (Iteration 7821 / 25920) loss: 0.006417
# (Iteration 7831 / 25920) loss: 0.009495
# (Iteration 7841 / 25920) loss: 0.005495
# (Iteration 7851 / 25920) loss: 0.007691
# (Iteration 7861 / 25920) loss: 0.011620
# (Iteration 7871 / 25920) loss: 0.010784
# (Iteration 7881 / 25920) loss: 0.004614
# (Iteration 7891 / 25920) loss: 0.010792
# (Iteration 7901 / 25920) loss: 0.005963
# (Iteration 7911 / 25920) loss: 0.005206
# (Iteration 7921 / 25920) loss: 0.005091
# (Iteration 7931 / 25920) loss: 0.006214
# (Iteration 7941 / 25920) loss: 0.007738
# (Iteration 7951 / 25920) loss: 0.008596
# (Iteration 7961 / 25920) loss: 0.010584
# (Iteration 7971 / 25920) loss: 0.012441
# (Iteration 7981 / 25920) loss: 0.008932
# (Iteration 7991 / 25920) loss: 0.010249
# (Iteration 8001 / 25920) loss: 0.007523
# (Iteration 8011 / 25920) loss: 0.008682
# (Iteration 8021 / 25920) loss: 0.010800
# (Iteration 8031 / 25920) loss: 0.034679
# (Iteration 8041 / 25920) loss: 0.006346
# (Iteration 8051 / 25920) loss: 0.005329
# (Iteration 8061 / 25920) loss: 0.004775
# (Iteration 8071 / 25920) loss: 0.007281
# (Iteration 8081 / 25920) loss: 0.004783
# (Iteration 8091 / 25920) loss: 0.005848
# (Iteration 8101 / 25920) loss: 0.005839
# (Iteration 8111 / 25920) loss: 0.010245
# (Iteration 8121 / 25920) loss: 0.018470
# (Iteration 8131 / 25920) loss: 0.011633
# (Iteration 8141 / 25920) loss: 0.012509
# (Iteration 8151 / 25920) loss: 0.005359
# (Iteration 8161 / 25920) loss: 0.005327
# (Iteration 8171 / 25920) loss: 0.011024
# (Iteration 8181 / 25920) loss: 0.007255
# (Iteration 8191 / 25920) loss: 0.007364
# (Iteration 8201 / 25920) loss: 0.009195
# (Iteration 8211 / 25920) loss: 0.009142
# (Iteration 8221 / 25920) loss: 0.008351
# (Iteration 8231 / 25920) loss: 0.010872
# (Iteration 8241 / 25920) loss: 0.007805
# (Iteration 8251 / 25920) loss: 0.004186
# (Iteration 8261 / 25920) loss: 0.007924
# (Iteration 8271 / 25920) loss: 0.006955
# (Iteration 8281 / 25920) loss: 0.006941
# (Iteration 8291 / 25920) loss: 0.005189
# (Iteration 8301 / 25920) loss: 0.008430
# (Iteration 8311 / 25920) loss: 0.011993
# (Iteration 8321 / 25920) loss: 0.008128
# (Iteration 8331 / 25920) loss: 0.008221
# (Iteration 8341 / 25920) loss: 0.012604
# (Iteration 8351 / 25920) loss: 0.009678
# (Iteration 8361 / 25920) loss: 0.007412
# (Iteration 8371 / 25920) loss: 0.008344
# (Iteration 8381 / 25920) loss: 0.008879
# (Iteration 8391 / 25920) loss: 0.007600
# (Iteration 8401 / 25920) loss: 0.007850
# (Iteration 8411 / 25920) loss: 0.006094
# (Iteration 8421 / 25920) loss: 0.005827
# (Iteration 8431 / 25920) loss: 0.010884
# (Iteration 8441 / 25920) loss: 0.008144
# (Iteration 8451 / 25920) loss: 0.008499
# (Iteration 8461 / 25920) loss: 0.005259
# (Iteration 8471 / 25920) loss: 0.005513
# (Iteration 8481 / 25920) loss: 0.010123
# (Iteration 8491 / 25920) loss: 0.007908
# (Iteration 8501 / 25920) loss: 0.007572
# (Iteration 8511 / 25920) loss: 0.008607
# (Iteration 8521 / 25920) loss: 0.011676
# (Iteration 8531 / 25920) loss: 0.008392
# (Iteration 8541 / 25920) loss: 0.006590
# (Iteration 8551 / 25920) loss: 0.009355
# (Iteration 8561 / 25920) loss: 0.007495
# (Iteration 8571 / 25920) loss: 0.006757
# (Iteration 8581 / 25920) loss: 0.009634
# (Iteration 8591 / 25920) loss: 0.005598
# (Iteration 8601 / 25920) loss: 0.009332
# (Iteration 8611 / 25920) loss: 0.006869
# (Iteration 8621 / 25920) loss: 0.004615
# (Iteration 8631 / 25920) loss: 0.007981
# (Iteration 8641 / 25920) loss: 0.008634
# (Iteration 8651 / 25920) loss: 0.005913
# (Iteration 8661 / 25920) loss: 0.011528
# (Iteration 8671 / 25920) loss: 0.011852
# (Iteration 8681 / 25920) loss: 0.009807
# (Iteration 8691 / 25920) loss: 0.009796
# (Iteration 8701 / 25920) loss: 0.006829
# (Iteration 8711 / 25920) loss: 0.009369
# (Iteration 8721 / 25920) loss: 0.008100
# (Iteration 8731 / 25920) loss: 0.010871
# (Iteration 8741 / 25920) loss: 0.011415
# (Iteration 8751 / 25920) loss: 0.005357
# (Iteration 8761 / 25920) loss: 0.014261
# (Iteration 8771 / 25920) loss: 0.006068
# (Iteration 8781 / 25920) loss: 0.006606
# (Iteration 8791 / 25920) loss: 0.007256
# (Iteration 8801 / 25920) loss: 0.005689
# (Iteration 8811 / 25920) loss: 0.006434
# (Iteration 8821 / 25920) loss: 0.006437
# (Iteration 8831 / 25920) loss: 0.013882
# (Iteration 8841 / 25920) loss: 0.010307
# (Iteration 8851 / 25920) loss: 0.006564
# (Iteration 8861 / 25920) loss: 0.007892
# (Iteration 8871 / 25920) loss: 0.005975
# (Iteration 8881 / 25920) loss: 0.007243
# (Iteration 8891 / 25920) loss: 0.008225
# (Iteration 8901 / 25920) loss: 0.005035
# (Iteration 8911 / 25920) loss: 0.006936
# (Iteration 8921 / 25920) loss: 0.007660
# (Iteration 8931 / 25920) loss: 0.008040
# (Iteration 8941 / 25920) loss: 0.006025
# (Iteration 8951 / 25920) loss: 0.004925
# (Iteration 8961 / 25920) loss: 0.007666
# (Iteration 8971 / 25920) loss: 0.005434
# (Iteration 8981 / 25920) loss: 0.008616
# (Iteration 8991 / 25920) loss: 0.004122
# (Iteration 9001 / 25920) loss: 0.006445
# (Iteration 9011 / 25920) loss: 0.006083
# (Iteration 9021 / 25920) loss: 0.008000
# (Iteration 9031 / 25920) loss: 0.008697
# (Iteration 9041 / 25920) loss: 0.008099
# (Iteration 9051 / 25920) loss: 0.005836
# (Iteration 9061 / 25920) loss: 0.006220
# (Iteration 9071 / 25920) loss: 0.006754
# (Epoch 7 / 20) train acc: -0.000563; val_acc: -0.000390
# (Iteration 9081 / 25920) loss: 0.005192
# (Iteration 9091 / 25920) loss: 0.013358
# (Iteration 9101 / 25920) loss: 0.007044
# (Iteration 9111 / 25920) loss: 0.007623
# (Iteration 9121 / 25920) loss: 0.007848
# (Iteration 9131 / 25920) loss: 0.009191
# (Iteration 9141 / 25920) loss: 0.009330
# (Iteration 9151 / 25920) loss: 0.009656
# (Iteration 9161 / 25920) loss: 0.010934
# (Iteration 9171 / 25920) loss: 0.005451
# (Iteration 9181 / 25920) loss: 0.006042
# (Iteration 9191 / 25920) loss: 0.010889
# (Iteration 9201 / 25920) loss: 0.005860
# (Iteration 9211 / 25920) loss: 0.005943
# (Iteration 9221 / 25920) loss: 0.010235
# (Iteration 9231 / 25920) loss: 0.007659
# (Iteration 9241 / 25920) loss: 0.009355
# (Iteration 9251 / 25920) loss: 0.009057
# (Iteration 9261 / 25920) loss: 0.005330
# (Iteration 9271 / 25920) loss: 0.005456
# (Iteration 9281 / 25920) loss: 0.007420
# (Iteration 9291 / 25920) loss: 0.011332
# (Iteration 9301 / 25920) loss: 0.011878
# (Iteration 9311 / 25920) loss: 0.007358
# (Iteration 9321 / 25920) loss: 0.010059
# (Iteration 9331 / 25920) loss: 0.005548
# (Iteration 9341 / 25920) loss: 0.006873
# (Iteration 9351 / 25920) loss: 0.005118
# (Iteration 9361 / 25920) loss: 0.004289
# (Iteration 9371 / 25920) loss: 0.008955
# (Iteration 9381 / 25920) loss: 0.005393
# (Iteration 9391 / 25920) loss: 0.005641
# (Iteration 9401 / 25920) loss: 0.011908
# (Iteration 9411 / 25920) loss: 0.007410
# (Iteration 9421 / 25920) loss: 0.011578
# (Iteration 9431 / 25920) loss: 0.005495
# (Iteration 9441 / 25920) loss: 0.006302
# (Iteration 9451 / 25920) loss: 0.010800
# (Iteration 9461 / 25920) loss: 0.004736
# (Iteration 9471 / 25920) loss: 0.007734
# (Iteration 9481 / 25920) loss: 0.007060
# (Iteration 9491 / 25920) loss: 0.007906
# (Iteration 9501 / 25920) loss: 0.006815
# (Iteration 9511 / 25920) loss: 0.009581
# (Iteration 9521 / 25920) loss: 0.013119
# (Iteration 9531 / 25920) loss: 0.008985
# (Iteration 9541 / 25920) loss: 0.003954
# (Iteration 9551 / 25920) loss: 0.005854
# (Iteration 9561 / 25920) loss: 0.004546
# (Iteration 9571 / 25920) loss: 0.014260
# (Iteration 9581 / 25920) loss: 0.007369
# (Iteration 9591 / 25920) loss: 0.005400
# (Iteration 9601 / 25920) loss: 0.009391
# (Iteration 9611 / 25920) loss: 0.007754
# (Iteration 9621 / 25920) loss: 0.007223
# (Iteration 9631 / 25920) loss: 0.005612
# (Iteration 9641 / 25920) loss: 0.006427
# (Iteration 9651 / 25920) loss: 0.002572
# (Iteration 9661 / 25920) loss: 0.007047
# (Iteration 9671 / 25920) loss: 0.011031
# (Iteration 9681 / 25920) loss: 0.004755
# (Iteration 9691 / 25920) loss: 0.009398
# (Iteration 9701 / 25920) loss: 0.008404
# (Iteration 9711 / 25920) loss: 0.009548
# (Iteration 9721 / 25920) loss: 0.006940
# (Iteration 9731 / 25920) loss: 0.006428
# (Iteration 9741 / 25920) loss: 0.011782
# (Iteration 9751 / 25920) loss: 0.005464
# (Iteration 9761 / 25920) loss: 0.008698
# (Iteration 9771 / 25920) loss: 0.006573
# (Iteration 9781 / 25920) loss: 0.003888
# (Iteration 9791 / 25920) loss: 0.004308
# (Iteration 9801 / 25920) loss: 0.008654
# (Iteration 9811 / 25920) loss: 0.007899
# (Iteration 9821 / 25920) loss: 0.005384
# (Iteration 9831 / 25920) loss: 0.011831
# (Iteration 9841 / 25920) loss: 0.006041
# (Iteration 9851 / 25920) loss: 0.014559
# (Iteration 9861 / 25920) loss: 0.006647
# (Iteration 9871 / 25920) loss: 0.006125
# (Iteration 9881 / 25920) loss: 0.007522
# (Iteration 9891 / 25920) loss: 0.008069
# (Iteration 9901 / 25920) loss: 0.008681
# (Iteration 9911 / 25920) loss: 0.006716
# (Iteration 9921 / 25920) loss: 0.008638
# (Iteration 9931 / 25920) loss: 0.007232
# (Iteration 9941 / 25920) loss: 0.007151
# (Iteration 9951 / 25920) loss: 0.008333
# (Iteration 9961 / 25920) loss: 0.007776
# (Iteration 9971 / 25920) loss: 0.011629
# (Iteration 9981 / 25920) loss: 0.012246
# (Iteration 9991 / 25920) loss: 0.005197
# (Iteration 10001 / 25920) loss: 0.005132
# (Iteration 10011 / 25920) loss: 0.007299
# (Iteration 10021 / 25920) loss: 0.005910
# (Iteration 10031 / 25920) loss: 0.010728
# (Iteration 10041 / 25920) loss: 0.009680
# (Iteration 10051 / 25920) loss: 0.003901
# (Iteration 10061 / 25920) loss: 0.006309
# (Iteration 10071 / 25920) loss: 0.007746
# (Iteration 10081 / 25920) loss: 0.008831
# (Iteration 10091 / 25920) loss: 0.007085
# (Iteration 10101 / 25920) loss: 0.012692
# (Iteration 10111 / 25920) loss: 0.011350
# (Iteration 10121 / 25920) loss: 0.009813
# (Iteration 10131 / 25920) loss: 0.009694
# (Iteration 10141 / 25920) loss: 0.006343
# (Iteration 10151 / 25920) loss: 0.002537
# (Iteration 10161 / 25920) loss: 0.009149
# (Iteration 10171 / 25920) loss: 0.004203
# (Iteration 10181 / 25920) loss: 0.004378
# (Iteration 10191 / 25920) loss: 0.012641
# (Iteration 10201 / 25920) loss: 0.006296
# (Iteration 10211 / 25920) loss: 0.004163
# (Iteration 10221 / 25920) loss: 0.007756
# (Iteration 10231 / 25920) loss: 0.007455
# (Iteration 10241 / 25920) loss: 0.007521
# (Iteration 10251 / 25920) loss: 0.008208
# (Iteration 10261 / 25920) loss: 0.006439
# (Iteration 10271 / 25920) loss: 0.008211
# (Iteration 10281 / 25920) loss: 0.006978
# (Iteration 10291 / 25920) loss: 0.007422
# (Iteration 10301 / 25920) loss: 0.013280
# (Iteration 10311 / 25920) loss: 0.010984
# (Iteration 10321 / 25920) loss: 0.007282
# (Iteration 10331 / 25920) loss: 0.004928
# (Iteration 10341 / 25920) loss: 0.008585
# (Iteration 10351 / 25920) loss: 0.006896
# (Iteration 10361 / 25920) loss: 0.008289
# (Epoch 8 / 20) train acc: -0.000574; val_acc: -0.000390
# (Iteration 10371 / 25920) loss: 0.004863
# (Iteration 10381 / 25920) loss: 0.008105
# (Iteration 10391 / 25920) loss: 0.006036
# (Iteration 10401 / 25920) loss: 0.007875
# (Iteration 10411 / 25920) loss: 0.007091
# (Iteration 10421 / 25920) loss: 0.004719
# (Iteration 10431 / 25920) loss: 0.008210
# (Iteration 10441 / 25920) loss: 0.011526
# (Iteration 10451 / 25920) loss: 0.009926
# (Iteration 10461 / 25920) loss: 0.004924
# (Iteration 10471 / 25920) loss: 0.009424
# (Iteration 10481 / 25920) loss: 0.009398
# (Iteration 10491 / 25920) loss: 0.014270
# (Iteration 10501 / 25920) loss: 0.040362
# (Iteration 10511 / 25920) loss: 0.009250
# (Iteration 10521 / 25920) loss: 0.010643
# (Iteration 10531 / 25920) loss: 0.009319
# (Iteration 10541 / 25920) loss: 0.012260
# (Iteration 10551 / 25920) loss: 0.004805
# (Iteration 10561 / 25920) loss: 0.005904
# (Iteration 10571 / 25920) loss: 0.006476
# (Iteration 10581 / 25920) loss: 0.005791
# (Iteration 10591 / 25920) loss: 0.006428
# (Iteration 10601 / 25920) loss: 0.008203
# (Iteration 10611 / 25920) loss: 0.010828
# (Iteration 10621 / 25920) loss: 0.008020
# (Iteration 10631 / 25920) loss: 0.007570
# (Iteration 10641 / 25920) loss: 0.007269
# (Iteration 10651 / 25920) loss: 0.010899
# (Iteration 10661 / 25920) loss: 0.009769
# (Iteration 10671 / 25920) loss: 0.004608
# (Iteration 10681 / 25920) loss: 0.006254
# (Iteration 10691 / 25920) loss: 0.008495
# (Iteration 10701 / 25920) loss: 0.010925
# (Iteration 10711 / 25920) loss: 0.009525
# (Iteration 10721 / 25920) loss: 0.009737
# (Iteration 10731 / 25920) loss: 0.007505
# (Iteration 10741 / 25920) loss: 0.006949
# (Iteration 10751 / 25920) loss: 0.008859
# (Iteration 10761 / 25920) loss: 0.006109
# (Iteration 10771 / 25920) loss: 0.004126
# (Iteration 10781 / 25920) loss: 0.006561
# (Iteration 10791 / 25920) loss: 0.006460
# (Iteration 10801 / 25920) loss: 0.007613
# (Iteration 10811 / 25920) loss: 0.007052
# (Iteration 10821 / 25920) loss: 0.009430
# (Iteration 10831 / 25920) loss: 0.009626
# (Iteration 10841 / 25920) loss: 0.008444
# (Iteration 10851 / 25920) loss: 0.005977
# (Iteration 10861 / 25920) loss: 0.007016
# (Iteration 10871 / 25920) loss: 0.009300
# (Iteration 10881 / 25920) loss: 0.007528
# (Iteration 10891 / 25920) loss: 0.012974
# (Iteration 10901 / 25920) loss: 0.006836
# (Iteration 10911 / 25920) loss: 0.008890
# (Iteration 10921 / 25920) loss: 0.006824
# (Iteration 10931 / 25920) loss: 0.010577
# (Iteration 10941 / 25920) loss: 0.015183
# (Iteration 10951 / 25920) loss: 0.007904
# (Iteration 10961 / 25920) loss: 0.007948
# (Iteration 10971 / 25920) loss: 0.009632
# (Iteration 10981 / 25920) loss: 0.005583
# (Iteration 10991 / 25920) loss: 0.005238
# (Iteration 11001 / 25920) loss: 0.004559
# (Iteration 11011 / 25920) loss: 0.005540
# (Iteration 11021 / 25920) loss: 0.019184
# (Iteration 11031 / 25920) loss: 0.006351
# (Iteration 11041 / 25920) loss: 0.005978
# (Iteration 11051 / 25920) loss: 0.010350
# (Iteration 11061 / 25920) loss: 0.006635
# (Iteration 11071 / 25920) loss: 0.005418
# (Iteration 11081 / 25920) loss: 0.005302
# (Iteration 11091 / 25920) loss: 0.004681
# (Iteration 11101 / 25920) loss: 0.015376
# (Iteration 11111 / 25920) loss: 0.006885
# (Iteration 11121 / 25920) loss: 0.010903
# (Iteration 11131 / 25920) loss: 0.006085
# (Iteration 11141 / 25920) loss: 0.006406
# (Iteration 11151 / 25920) loss: 0.006907
# (Iteration 11161 / 25920) loss: 0.005191
# (Iteration 11171 / 25920) loss: 0.005497
# (Iteration 11181 / 25920) loss: 0.003672
# (Iteration 11191 / 25920) loss: 0.005963
# (Iteration 11201 / 25920) loss: 0.005302
# (Iteration 11211 / 25920) loss: 0.003976
# (Iteration 11221 / 25920) loss: 0.004918
# (Iteration 11231 / 25920) loss: 0.008009
# (Iteration 11241 / 25920) loss: 0.012597
# (Iteration 11251 / 25920) loss: 0.007793
# (Iteration 11261 / 25920) loss: 0.003896
# (Iteration 11271 / 25920) loss: 0.007519
# (Iteration 11281 / 25920) loss: 0.007822
# (Iteration 11291 / 25920) loss: 0.005516
# (Iteration 11301 / 25920) loss: 0.004621
# (Iteration 11311 / 25920) loss: 0.007469
# (Iteration 11321 / 25920) loss: 0.007126
# (Iteration 11331 / 25920) loss: 0.005329
# (Iteration 11341 / 25920) loss: 0.014296
# (Iteration 11351 / 25920) loss: 0.009405
# (Iteration 11361 / 25920) loss: 0.006359
# (Iteration 11371 / 25920) loss: 0.012147
# (Iteration 11381 / 25920) loss: 0.003938
# (Iteration 11391 / 25920) loss: 0.005806
# (Iteration 11401 / 25920) loss: 0.004884
# (Iteration 11411 / 25920) loss: 0.009865
# (Iteration 11421 / 25920) loss: 0.006497
# (Iteration 11431 / 25920) loss: 0.005045
# (Iteration 11441 / 25920) loss: 0.006264
# (Iteration 11451 / 25920) loss: 0.004109
# (Iteration 11461 / 25920) loss: 0.004580
# (Iteration 11471 / 25920) loss: 0.009041
# (Iteration 11481 / 25920) loss: 0.007578
# (Iteration 11491 / 25920) loss: 0.004714
# (Iteration 11501 / 25920) loss: 0.006028
# (Iteration 11511 / 25920) loss: 0.006088
# (Iteration 11521 / 25920) loss: 0.004669
# (Iteration 11531 / 25920) loss: 0.003772
# (Iteration 11541 / 25920) loss: 0.005346
# (Iteration 11551 / 25920) loss: 0.004381
# (Iteration 11561 / 25920) loss: 0.006558
# (Iteration 11571 / 25920) loss: 0.005292
# (Iteration 11581 / 25920) loss: 0.024218
# (Iteration 11591 / 25920) loss: 0.005254
# (Iteration 11601 / 25920) loss: 0.005422
# (Iteration 11611 / 25920) loss: 0.007609
# (Iteration 11621 / 25920) loss: 0.007355
# (Iteration 11631 / 25920) loss: 0.009611
# (Iteration 11641 / 25920) loss: 0.009268
# (Iteration 11651 / 25920) loss: 0.010453
# (Iteration 11661 / 25920) loss: 0.007606
# (Epoch 9 / 20) train acc: -0.000072; val_acc: -0.000390
# (Iteration 11671 / 25920) loss: 0.007551
# (Iteration 11681 / 25920) loss: 0.007094
# (Iteration 11691 / 25920) loss: 0.006565
# (Iteration 11701 / 25920) loss: 0.011131
# (Iteration 11711 / 25920) loss: 0.009245
# (Iteration 11721 / 25920) loss: 0.005371
# (Iteration 11731 / 25920) loss: 0.003828
# (Iteration 11741 / 25920) loss: 0.012520
# (Iteration 11751 / 25920) loss: 0.006330
# (Iteration 11761 / 25920) loss: 0.003432
# (Iteration 11771 / 25920) loss: 0.005814
# (Iteration 11781 / 25920) loss: 0.009294
# (Iteration 11791 / 25920) loss: 0.005672
# (Iteration 11801 / 25920) loss: 0.003799
# (Iteration 11811 / 25920) loss: 0.006728
# (Iteration 11821 / 25920) loss: 0.008617
# (Iteration 11831 / 25920) loss: 0.006072
# ...
# (Iteration 22061 / 25920) loss: 0.008297
# (Iteration 22071 / 25920) loss: 0.009332
# (Iteration 22081 / 25920) loss: 0.006333
# (Iteration 22091 / 25920) loss: 0.007564
# (Iteration 22101 / 25920) loss: 0.004975
# (Iteration 22111 / 25920) loss: 0.004452
# (Iteration 22121 / 25920) loss: 0.007035
# (Iteration 22131 / 25920) loss: 0.007778
# (Iteration 22141 / 25920) loss: 0.009628
# (Iteration 22151 / 25920) loss: 0.010796
# (Iteration 22161 / 25920) loss: 0.006950
# (Iteration 22171 / 25920) loss: 0.010696
# (Iteration 22181 / 25920) loss: 0.006154
# (Iteration 22191 / 25920) loss: 0.004911
# (Iteration 22201 / 25920) loss: 0.008693
# (Iteration 22211 / 25920) loss: 0.010119
# (Iteration 22221 / 25920) loss: 0.006915
# (Iteration 22231 / 25920) loss: 0.003919
# (Iteration 22241 / 25920) loss: 0.008317
# (Iteration 22251 / 25920) loss: 0.004327
# (Iteration 22261 / 25920) loss: 0.009397
# (Iteration 22271 / 25920) loss: 0.007308
# (Iteration 22281 / 25920) loss: 0.011856
# (Iteration 22291 / 25920) loss: 0.007278
# (Iteration 22301 / 25920) loss: 0.008490
# (Iteration 22311 / 25920) loss: 0.007226
# (Iteration 22321 / 25920) loss: 0.003834
# (Iteration 22331 / 25920) loss: 0.005183
# (Iteration 22341 / 25920) loss: 0.007066
# (Iteration 22351 / 25920) loss: 0.005507
# (Iteration 22361 / 25920) loss: 0.003896
# (Iteration 22371 / 25920) loss: 0.003409
# (Iteration 22381 / 25920) loss: 0.003489
# (Iteration 22391 / 25920) loss: 0.004246
# (Iteration 22401 / 25920) loss: 0.006533
# (Iteration 22411 / 25920) loss: 0.006293
# (Iteration 22421 / 25920) loss: 0.012306
# (Iteration 22431 / 25920) loss: 0.006225
# (Iteration 22441 / 25920) loss: 0.009732
# (Iteration 22451 / 25920) loss: 0.003686
# (Iteration 22461 / 25920) loss: 0.005878
# (Iteration 22471 / 25920) loss: 0.004990
# (Iteration 22481 / 25920) loss: 0.010789
# (Iteration 22491 / 25920) loss: 0.007241
# (Iteration 22501 / 25920) loss: 0.006773
# (Iteration 22511 / 25920) loss: 0.003647
# (Iteration 22521 / 25920) loss: 0.005088
# (Iteration 22531 / 25920) loss: 0.011821
# (Iteration 22541 / 25920) loss: 0.009408
# (Iteration 22551 / 25920) loss: 0.004131
# (Iteration 22561 / 25920) loss: 0.005057
# (Iteration 22571 / 25920) loss: 0.005824
# (Iteration 22581 / 25920) loss: 0.006524
# (Iteration 22591 / 25920) loss: 0.007231
# (Iteration 22601 / 25920) loss: 0.004325
# (Iteration 22611 / 25920) loss: 0.005720
# (Iteration 22621 / 25920) loss: 0.011118
# (Iteration 22631 / 25920) loss: 0.007556
# (Iteration 22641 / 25920) loss: 0.006383
# (Iteration 22651 / 25920) loss: 0.005887
# (Iteration 22661 / 25920) loss: 0.007281
# (Iteration 22671 / 25920) loss: 0.005005
# (Iteration 22681 / 25920) loss: 0.003348
# (Iteration 22691 / 25920) loss: 0.002742
# (Iteration 22701 / 25920) loss: 0.008164
# (Iteration 22711 / 25920) loss: 0.004660
# (Iteration 22721 / 25920) loss: 0.006782
# (Iteration 22731 / 25920) loss: 0.006793
# (Iteration 22741 / 25920) loss: 0.006609
# (Iteration 22751 / 25920) loss: 0.007321
# (Iteration 22761 / 25920) loss: 0.008743
# (Iteration 22771 / 25920) loss: 0.008867
# (Iteration 22781 / 25920) loss: 0.005543
# (Iteration 22791 / 25920) loss: 0.004567
# (Iteration 22801 / 25920) loss: 0.006881
# (Iteration 22811 / 25920) loss: 0.008512
# (Iteration 22821 / 25920) loss: 0.004928
# (Iteration 22831 / 25920) loss: 0.007351
# (Iteration 22841 / 25920) loss: 0.006214
# (Iteration 22851 / 25920) loss: 0.006541
# (Iteration 22861 / 25920) loss: 0.010362
# (Iteration 22871 / 25920) loss: 0.006424
# (Iteration 22881 / 25920) loss: 0.007695
# (Iteration 22891 / 25920) loss: 0.003328
# (Iteration 22901 / 25920) loss: 0.006617
# (Iteration 22911 / 25920) loss: 0.005449
# (Iteration 22921 / 25920) loss: 0.004136
# (Iteration 22931 / 25920) loss: 0.006610
# (Iteration 22941 / 25920) loss: 0.008400
# (Iteration 22951 / 25920) loss: 0.003677
# (Iteration 22961 / 25920) loss: 0.005427
# (Iteration 22971 / 25920) loss: 0.007891
# (Iteration 22981 / 25920) loss: 0.008356
# (Iteration 22991 / 25920) loss: 0.008800
# (Iteration 23001 / 25920) loss: 0.010451
# (Iteration 23011 / 25920) loss: 0.006788
# (Iteration 23021 / 25920) loss: 0.008793
# (Iteration 23031 / 25920) loss: 0.005894
# (Iteration 23041 / 25920) loss: 0.005668
# (Iteration 23051 / 25920) loss: 0.005572
# (Iteration 23061 / 25920) loss: 0.004590
# (Iteration 23071 / 25920) loss: 0.006810
# (Iteration 23081 / 25920) loss: 0.005811
# (Iteration 23091 / 25920) loss: 0.005777
# (Iteration 23101 / 25920) loss: 0.006315
# (Iteration 23111 / 25920) loss: 0.008536
# (Iteration 23121 / 25920) loss: 0.010859
# (Iteration 23131 / 25920) loss: 0.008019
# (Iteration 23141 / 25920) loss: 0.011368
# (Iteration 23151 / 25920) loss: 0.009028
# (Iteration 23161 / 25920) loss: 0.007244
# (Iteration 23171 / 25920) loss: 0.005120
# (Iteration 23181 / 25920) loss: 0.008923
# (Iteration 23191 / 25920) loss: 0.004852
# (Iteration 23201 / 25920) loss: 0.007071
# (Iteration 23211 / 25920) loss: 0.007773
# (Iteration 23221 / 25920) loss: 0.005437
# (Iteration 23231 / 25920) loss: 0.012075
# (Iteration 23241 / 25920) loss: 0.005439
# (Iteration 23251 / 25920) loss: 0.006597
# (Iteration 23261 / 25920) loss: 0.006215
# (Iteration 23271 / 25920) loss: 0.008842
# (Iteration 23281 / 25920) loss: 0.006542
# (Iteration 23291 / 25920) loss: 0.006330
# (Iteration 23301 / 25920) loss: 0.007919
# (Iteration 23311 / 25920) loss: 0.015802
# (Iteration 23321 / 25920) loss: 0.006807
# (Epoch 18 / 20) train acc: -0.000164; val_acc: -0.000390
# (Iteration 23331 / 25920) loss: 0.010636
# (Iteration 23341 / 25920) loss: 0.010223
# (Iteration 23351 / 25920) loss: 0.007274
# (Iteration 23361 / 25920) loss: 0.006595
# (Iteration 23371 / 25920) loss: 0.009025
# (Iteration 23381 / 25920) loss: 0.004775
# (Iteration 23391 / 25920) loss: 0.005342
# (Iteration 23401 / 25920) loss: 0.006288
# (Iteration 23411 / 25920) loss: 0.002877
# (Iteration 23421 / 25920) loss: 0.006785
# (Iteration 23431 / 25920) loss: 0.007555
# (Iteration 23441 / 25920) loss: 0.004497
# (Iteration 23451 / 25920) loss: 0.003977
# (Iteration 23461 / 25920) loss: 0.004125
# (Iteration 23471 / 25920) loss: 0.006015
# (Iteration 23481 / 25920) loss: 0.006904
# (Iteration 23491 / 25920) loss: 0.004730
# (Iteration 23501 / 25920) loss: 0.007654
# (Iteration 23511 / 25920) loss: 0.012143
# (Iteration 23521 / 25920) loss: 0.007763
# (Iteration 23531 / 25920) loss: 0.007095
# (Iteration 23541 / 25920) loss: 0.004799
# (Iteration 23551 / 25920) loss: 0.003860
# (Iteration 23561 / 25920) loss: 0.004184
# (Iteration 23571 / 25920) loss: 0.006323
# (Iteration 23581 / 25920) loss: 0.005213
# (Iteration 23591 / 25920) loss: 0.080071
# (Iteration 23601 / 25920) loss: 0.004861
# (Iteration 23611 / 25920) loss: 0.008544
# (Iteration 23621 / 25920) loss: 0.007039
# (Iteration 23631 / 25920) loss: 0.004999
# (Iteration 23641 / 25920) loss: 0.006792
# (Iteration 23651 / 25920) loss: 0.005048
# (Iteration 23661 / 25920) loss: 0.007850
# (Iteration 23671 / 25920) loss: 0.008321
# (Iteration 23681 / 25920) loss: 0.007580
# (Iteration 23691 / 25920) loss: 0.007626
# (Iteration 23701 / 25920) loss: 0.009208
# (Iteration 23711 / 25920) loss: 0.007237
# (Iteration 23721 / 25920) loss: 0.007806
# (Iteration 23731 / 25920) loss: 0.007815
# (Iteration 23741 / 25920) loss: 0.005328
# (Iteration 23751 / 25920) loss: 0.007842
# (Iteration 23761 / 25920) loss: 0.008314
# (Iteration 23771 / 25920) loss: 0.005202
# (Iteration 23781 / 25920) loss: 0.004893
# (Iteration 23791 / 25920) loss: 0.009784
# (Iteration 23801 / 25920) loss: 0.008550
# (Iteration 23811 / 25920) loss: 0.004497
# (Iteration 23821 / 25920) loss: 0.005987
# (Iteration 23831 / 25920) loss: 0.005780
# (Iteration 23841 / 25920) loss: 0.008892
# (Iteration 23851 / 25920) loss: 0.006607
# (Iteration 23861 / 25920) loss: 0.007396
# (Iteration 23871 / 25920) loss: 0.006342
# (Iteration 23881 / 25920) loss: 0.006628
# (Iteration 23891 / 25920) loss: 0.006553
# (Iteration 23901 / 25920) loss: 0.008159
# (Iteration 23911 / 25920) loss: 0.009689
# (Iteration 23921 / 25920) loss: 0.004472
# (Iteration 23931 / 25920) loss: 0.006238
# (Iteration 23941 / 25920) loss: 0.008912
# (Iteration 23951 / 25920) loss: 0.007166
# (Iteration 23961 / 25920) loss: 0.010679
# (Iteration 23971 / 25920) loss: 0.010595
# (Iteration 23981 / 25920) loss: 0.006758
# (Iteration 23991 / 25920) loss: 0.007748
# (Iteration 24001 / 25920) loss: 0.005684
# (Iteration 24011 / 25920) loss: 0.007688
# (Iteration 24021 / 25920) loss: 0.006947
# (Iteration 24031 / 25920) loss: 0.007245
# (Iteration 24041 / 25920) loss: 0.012173
# (Iteration 24051 / 25920) loss: 0.006431
# (Iteration 24061 / 25920) loss: 0.007347
# (Iteration 24071 / 25920) loss: 0.007361
# (Iteration 24081 / 25920) loss: 0.008814
# (Iteration 24091 / 25920) loss: 0.005298
# (Iteration 24101 / 25920) loss: 0.007847
# (Iteration 24111 / 25920) loss: 0.004600
# (Iteration 24121 / 25920) loss: 0.004276
# (Iteration 24131 / 25920) loss: 0.005373
# (Iteration 24141 / 25920) loss: 0.010466
# (Iteration 24151 / 25920) loss: 0.005666
# (Iteration 24161 / 25920) loss: 0.004444
# (Iteration 24171 / 25920) loss: 0.010362
# (Iteration 24181 / 25920) loss: 0.007109
# (Iteration 24191 / 25920) loss: 0.006704
# (Iteration 24201 / 25920) loss: 0.010447
# (Iteration 24211 / 25920) loss: 0.007316
# (Iteration 24221 / 25920) loss: 0.005859
# (Iteration 24231 / 25920) loss: 0.004776
# (Iteration 24241 / 25920) loss: 0.004709
# (Iteration 24251 / 25920) loss: 0.010661
# (Iteration 24261 / 25920) loss: 0.005710
# (Iteration 24271 / 25920) loss: 0.003935
# (Iteration 24281 / 25920) loss: 0.008289
# (Iteration 24291 / 25920) loss: 0.007977
# (Iteration 24301 / 25920) loss: 0.008131
# (Iteration 24311 / 25920) loss: 0.006987
# (Iteration 24321 / 25920) loss: 0.006893
# (Iteration 24331 / 25920) loss: 0.011195
# (Iteration 24341 / 25920) loss: 0.008607
# (Iteration 24351 / 25920) loss: 0.013218
# (Iteration 24361 / 25920) loss: 0.003918
# (Iteration 24371 / 25920) loss: 0.010481
# (Iteration 24381 / 25920) loss: 0.003378
# (Iteration 24391 / 25920) loss: 0.005567
# (Iteration 24401 / 25920) loss: 0.006305
# (Iteration 24411 / 25920) loss: 0.003105
# (Iteration 24421 / 25920) loss: 0.006370
# (Iteration 24431 / 25920) loss: 0.006942
# (Iteration 24441 / 25920) loss: 0.008578
# (Iteration 24451 / 25920) loss: 0.007854
# (Iteration 24461 / 25920) loss: 0.002755
# (Iteration 24471 / 25920) loss: 0.005325
# (Iteration 24481 / 25920) loss: 0.004864
# (Iteration 24491 / 25920) loss: 0.011997
# (Iteration 24501 / 25920) loss: 0.006035
# (Iteration 24511 / 25920) loss: 0.003782
# (Iteration 24521 / 25920) loss: 0.009434
# (Iteration 24531 / 25920) loss: 0.007314
# (Iteration 24541 / 25920) loss: 0.006155
# (Iteration 24551 / 25920) loss: 0.011175
# (Iteration 24561 / 25920) loss: 0.006679
# (Iteration 24571 / 25920) loss: 0.005575
# (Iteration 24581 / 25920) loss: 0.009414
# (Iteration 24591 / 25920) loss: 0.009015
# (Iteration 24601 / 25920) loss: 0.006302
# (Iteration 24611 / 25920) loss: 0.005241
# (Iteration 24621 / 25920) loss: 0.005763
# (Epoch 19 / 20) train acc: -0.002753; val_acc: -0.000390
# (Iteration 24631 / 25920) loss: 0.010280
# (Iteration 24641 / 25920) loss: 0.006897
# (Iteration 24651 / 25920) loss: 0.004081
# (Iteration 24661 / 25920) loss: 0.005115
# (Iteration 24671 / 25920) loss: 0.006775
# (Iteration 24681 / 25920) loss: 0.007175
# (Iteration 24691 / 25920) loss: 0.006065
# (Iteration 24701 / 25920) loss: 0.003299
# (Iteration 24711 / 25920) loss: 0.009356
# (Iteration 24721 / 25920) loss: 0.006701
# (Iteration 24731 / 25920) loss: 0.006621
# (Iteration 24741 / 25920) loss: 0.006887
# (Iteration 24751 / 25920) loss: 0.004693
# (Iteration 24761 / 25920) loss: 0.006570
# (Iteration 24771 / 25920) loss: 0.009100
# (Iteration 24781 / 25920) loss: 0.019527
# (Iteration 24791 / 25920) loss: 0.012689
# (Iteration 24801 / 25920) loss: 0.004773
# (Iteration 24811 / 25920) loss: 0.005173
# (Iteration 24821 / 25920) loss: 0.006949
# (Iteration 24831 / 25920) loss: 0.006745
# (Iteration 24841 / 25920) loss: 0.006056
# (Iteration 24851 / 25920) loss: 0.005340
# (Iteration 24861 / 25920) loss: 0.008040
# (Iteration 24871 / 25920) loss: 0.004745
# (Iteration 24881 / 25920) loss: 0.005971
# (Iteration 24891 / 25920) loss: 0.004126
# (Iteration 24901 / 25920) loss: 0.010531
# (Iteration 24911 / 25920) loss: 0.006237
# (Iteration 24921 / 25920) loss: 0.006074
# (Iteration 24931 / 25920) loss: 0.005700
# (Iteration 24941 / 25920) loss: 0.011496
# (Iteration 24951 / 25920) loss: 0.005687
# (Iteration 24961 / 25920) loss: 0.007583
# (Iteration 24971 / 25920) loss: 0.014980
# (Iteration 24981 / 25920) loss: 0.012145
# (Iteration 24991 / 25920) loss: 0.006366
# (Iteration 25001 / 25920) loss: 0.006778
# (Iteration 25011 / 25920) loss: 0.007873
# (Iteration 25021 / 25920) loss: 0.009190
# (Iteration 25031 / 25920) loss: 0.009785
# (Iteration 25041 / 25920) loss: 0.007847
# (Iteration 25051 / 25920) loss: 0.005676
# (Iteration 25061 / 25920) loss: 0.008477
# (Iteration 25071 / 25920) loss: 0.006930
# (Iteration 25081 / 25920) loss: 0.006172
# (Iteration 25091 / 25920) loss: 0.008410
# (Iteration 25101 / 25920) loss: 0.006766
# (Iteration 25111 / 25920) loss: 0.005495
# (Iteration 25121 / 25920) loss: 0.005796
# (Iteration 25131 / 25920) loss: 0.005850
# (Iteration 25141 / 25920) loss: 0.006663
# (Iteration 25151 / 25920) loss: 0.007847
# (Iteration 25161 / 25920) loss: 0.004472
# (Iteration 25171 / 25920) loss: 0.005623
# (Iteration 25181 / 25920) loss: 0.003634
# (Iteration 25191 / 25920) loss: 0.011270
# (Iteration 25201 / 25920) loss: 0.005291
# (Iteration 25211 / 25920) loss: 0.004101
# (Iteration 25221 / 25920) loss: 0.008585
# (Iteration 25231 / 25920) loss: 0.003909
# (Iteration 25241 / 25920) loss: 0.006412
# (Iteration 25251 / 25920) loss: 0.006492
# (Iteration 25261 / 25920) loss: 0.004095
# (Iteration 25271 / 25920) loss: 0.008262
# (Iteration 25281 / 25920) loss: 0.005220
# (Iteration 25291 / 25920) loss: 0.009118
# (Iteration 25301 / 25920) loss: 0.006376
# (Iteration 25311 / 25920) loss: 0.009816
# (Iteration 25321 / 25920) loss: 0.004771
# (Iteration 25331 / 25920) loss: 0.005920
# (Iteration 25341 / 25920) loss: 0.006231
# (Iteration 25351 / 25920) loss: 0.013431
# (Iteration 25361 / 25920) loss: 0.006810
# (Iteration 25371 / 25920) loss: 0.006219
# (Iteration 25381 / 25920) loss: 0.007557
# (Iteration 25391 / 25920) loss: 0.005783
# (Iteration 25401 / 25920) loss: 0.005090
# (Iteration 25411 / 25920) loss: 0.006690
# (Iteration 25421 / 25920) loss: 0.005544
# (Iteration 25431 / 25920) loss: 0.006183
# (Iteration 25441 / 25920) loss: 0.007855
# (Iteration 25451 / 25920) loss: 0.004679
# (Iteration 25461 / 25920) loss: 0.005512
# (Iteration 25471 / 25920) loss: 0.006703
# (Iteration 25481 / 25920) loss: 0.005157
# (Iteration 25491 / 25920) loss: 0.007303
# (Iteration 25501 / 25920) loss: 0.007656
# (Iteration 25511 / 25920) loss: 0.004939
# (Iteration 25521 / 25920) loss: 0.014011
# (Iteration 25531 / 25920) loss: 0.006346
# (Iteration 25541 / 25920) loss: 0.005470
# (Iteration 25551 / 25920) loss: 0.006203
# (Iteration 25561 / 25920) loss: 0.005272
# (Iteration 25571 / 25920) loss: 0.005761
# (Iteration 25581 / 25920) loss: 0.006774
# (Iteration 25591 / 25920) loss: 0.007290
# (Iteration 25601 / 25920) loss: 0.005120
# (Iteration 25611 / 25920) loss: 0.010045
# (Iteration 25621 / 25920) loss: 0.004704
# (Iteration 25631 / 25920) loss: 0.012268
# (Iteration 25641 / 25920) loss: 0.004509
# (Iteration 25651 / 25920) loss: 0.003742
# (Iteration 25661 / 25920) loss: 0.004844
# (Iteration 25671 / 25920) loss: 0.007907
# (Iteration 25681 / 25920) loss: 0.005770
# (Iteration 25691 / 25920) loss: 0.006131
# (Iteration 25701 / 25920) loss: 0.007780
# (Iteration 25711 / 25920) loss: 0.005546
# (Iteration 25721 / 25920) loss: 0.005345
# (Iteration 25731 / 25920) loss: 0.006698
# (Iteration 25741 / 25920) loss: 0.008968
# (Iteration 25751 / 25920) loss: 0.003169
# (Iteration 25761 / 25920) loss: 0.004147
# (Iteration 25771 / 25920) loss: 0.005485
# (Iteration 25781 / 25920) loss: 0.007156
# (Iteration 25791 / 25920) loss: 0.007482
# (Iteration 25801 / 25920) loss: 0.005777
# (Iteration 25811 / 25920) loss: 0.005077
# (Iteration 25821 / 25920) loss: 0.008888
# (Iteration 25831 / 25920) loss: 0.009618
# (Iteration 25841 / 25920) loss: 0.013246
# (Iteration 25851 / 25920) loss: 0.006186
# (Iteration 25861 / 25920) loss: 0.008506
# (Iteration 25871 / 25920) loss: 0.007225
# (Iteration 25881 / 25920) loss: 0.008261
# (Iteration 25891 / 25920) loss: 0.008382
# (Iteration 25901 / 25920) loss: 0.004515
# (Iteration 25911 / 25920) loss: 0.010110
# (Epoch 20 / 20) train acc: -0.000727; val_acc: -0.000390

# %% [markdown]
# ### Linear model and its variants

# %% [markdown]
# Construct the linear regression model, with different regularization method, perform the above prediction task. Compare their results.

# %%
##############################################################################
### TODO: Linear model and its variants.                                   ###
##############################################################################

from sklearn.linear_model import LinearRegression, ElasticNet, Lasso

## For no regularization
print("No regularization")
split = 0.9

num_train = int(factor.shape[0]*0.9)
num_valid = int(factor.shape[0]*0.1)
full_data_nonlin = {
  'X_train': factor[:num_train],
  'y_train': nonlinear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': nonlinear_ret[num_train:num_train+num_valid]
}

lin_reg_model = LinearRegression()
lin_reg_model.fit(full_data_nonlin['X_train'],full_data_nonlin['y_train'])
score = lin_reg_model.score(full_data_nonlin['X_val'],full_data_nonlin['y_val'])
print(f"Score : {score}")
lin_reg_pred = lin_reg_model.predict(full_data_nonlin['X_val'])
print(f"MSE : {mean_squared_error(lin_reg_pred,full_data_nonlin['y_val'])}")

split = 0.9

num_train = int(factor.shape[0]*0.9)
num_valid = int(factor.shape[0]*0.1)
full_data = {
  'X_train': factor[:num_train],
  'y_train': linear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': linear_ret[num_train:num_train+num_valid]
}

lin_reg_model = LinearRegression()
lin_reg_model.fit(full_data['X_train'],full_data['y_train'])
score = lin_reg_model.score(full_data['X_val'],full_data['y_val'])
print(f"Score : {score}")
lin_reg_pred = lin_reg_model.predict(full_data['X_val'])
print(f"MSE : {mean_squared_error(lin_reg_pred,full_data['y_val'])}")

# L1 regularization
print("L1 regularization linear regression")
split = 0.9

num_train = int(factor.shape[0]*0.9)
num_valid = int(factor.shape[0]*0.1)
full_data_nonlin = {
  'X_train': factor[:num_train],
  'y_train': nonlinear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': nonlinear_ret[num_train:num_train+num_valid]
}

lin_reg_model = Lasso(alpha=0.01)
lin_reg_model.fit(full_data_nonlin['X_train'],full_data_nonlin['y_train'])
score = lin_reg_model.score(full_data_nonlin['X_val'],full_data_nonlin['y_val'])
print(f"Score : {score}")
lin_reg_pred = lin_reg_model.predict(full_data_nonlin['X_val'])
print(f"MSE : {mean_squared_error(lin_reg_pred,full_data_nonlin['y_val'])}")

split = 0.9

num_train = int(factor.shape[0]*0.9)
num_valid = int(factor.shape[0]*0.1)
full_data = {
  'X_train': factor[:num_train],
  'y_train': linear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': linear_ret[num_train:num_train+num_valid]
}

lin_reg_model = Lasso(alpha=0.01)
lin_reg_model.fit(full_data['X_train'],full_data['y_train'])
score = lin_reg_model.score(full_data['X_val'],full_data['y_val'])
print(f"Score : {score}")
lin_reg_pred = lin_reg_model.predict(full_data['X_val'])
print(f"MSE : {mean_squared_error(lin_reg_pred,full_data['y_val'])}")

# L2 regularization
print("L2 regularization linear regression")
split = 0.9

num_train = int(factor.shape[0]*0.9)
num_valid = int(factor.shape[0]*0.1)
full_data_nonlin = {
  'X_train': factor[:num_train],
  'y_train': nonlinear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': nonlinear_ret[num_train:num_train+num_valid]
}

lin_reg_model = ElasticNet(alpha=0.01, l1_ratio=0)
lin_reg_model.fit(full_data_nonlin['X_train'],full_data_nonlin['y_train'])
score = lin_reg_model.score(full_data_nonlin['X_val'],full_data_nonlin['y_val'])
print(f"Score : {score}")
lin_reg_pred = lin_reg_model.predict(full_data_nonlin['X_val'])
print(f"MSE : {mean_squared_error(lin_reg_pred,full_data_nonlin['y_val'])}")

split = 0.9

num_train = int(factor.shape[0]*0.9)
num_valid = int(factor.shape[0]*0.1)
full_data = {
  'X_train': factor[:num_train],
  'y_train': linear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': linear_ret[num_train:num_train+num_valid]
}

lin_reg_model = ElasticNet(alpha=0.01,l1_ratio=0)
lin_reg_model.fit(full_data['X_train'],full_data['y_train'])
score = lin_reg_model.score(full_data['X_val'],full_data['y_val'])
print(f"Score : {score}")
lin_reg_pred = lin_reg_model.predict(full_data['X_val'])
print(f"MSE : {mean_squared_error(lin_reg_pred,full_data['y_val'])}")
##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
# Out:
# No regularization
# Score : -0.001962969703915407
# MSE : 0.0063675169946780606
# Score : -0.001962969703915407
# MSE : 0.0063675169946780606
# L1 regularization linear regression
# Score : -0.0001444747811436553
# MSE : 0.006355960382631903
# Score : -0.0001444747811436553
# MSE : 0.006355960382631903
# L2 regularization linear regression
# /Users/chloetan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110.84756605110293, tolerance: 0.023309084126780195
#   model = cd_fast.enet_coordinate_descent(
# Score : -0.00046692772258527526
# MSE : 0.006358009584694949
# Score : -0.00046692772258527526
# MSE : 0.006358009584694949
# /Users/chloetan/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110.84756605110293, tolerance: 0.023309084126780195
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# ### Tree based model

# %% [markdown]
# Now construct the tree model (CART, Random Forest) and redo the above exercise. Compare their results.

# %%
##############################################################################
### TODO: Tree based models.                                               ###
##############################################################################
# For the nonlinear ret

from sklearn import tree
from sklearn.ensemble import RandomForestRegressor

# CART using tree
split = 0.9

num_train = int(factor.shape[0]*0.9)
num_valid = int(factor.shape[0]*0.1)
full_data = {
  'X_train': factor[:num_train],
  'y_train': nonlinear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': nonlinear_ret[num_train:num_train+num_valid]
}

clf_nonlin = tree.DecisionTreeRegressor()
clf_nonlin = clf_nonlin.fit(full_data['X_train'],full_data['y_train'])

prediction = clf_nonlin.predict(full_data['X_val'])
print(f" R2 score: {r2_score(prediction,full_data['y_val'])}")
print(f"MSE : {mean_squared_error(prediction,full_data['y_val'])}")


split = 0.9

num_train = int(factor.shape[0]*0.9)
num_valid = int(factor.shape[0]*0.1)
full_data_lin = {
  'X_train': factor[:num_train],
  'y_train': linear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': linear_ret[num_train:num_train+num_valid]
}

clf_lin = tree.DecisionTreeRegressor()
clf_lin = clf_lin.fit(full_data_lin['X_train'],full_data_lin['y_train'])

prediction = clf_lin.predict(full_data_lin['X_val'])
print(f" R2 score: {r2_score(prediction,full_data_lin['y_val'])}")
print(f"MSE : {mean_squared_error(prediction,full_data_lin['y_val'])}")

# Random forest regressor


split = 0.9

num_train = int(factor.shape[0]*0.9)
num_valid = int(factor.shape[0]*0.1)
full_data = {
  'X_train': factor[:num_train],
  'y_train': nonlinear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': nonlinear_ret[num_train:num_train+num_valid]
}

rfr = RandomForestRegressor()
rfr = rfr.fit(full_data['X_train'],full_data['y_train'])

prediction = rfr.predict(full_data['X_val'])
print(f" R2 score: {r2_score(prediction,full_data['y_val'])}")
print(f"MSE : {mean_squared_error(prediction,full_data['y_val'])}")


split = 0.9

num_train = int(factor.shape[0]*0.9)
num_valid = int(factor.shape[0]*0.1)
full_data_lin = {
  'X_train': factor[:num_train],
  'y_train': linear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': linear_ret[num_train:num_train+num_valid]
}

rfr2 = RandomForestRegressor()
rfr2 = rfr2.fit(full_data_lin['X_train'],full_data_lin['y_train'])

prediction = rfr2.predict(full_data_lin['X_val'])
print(f" R2 score: {r2_score(prediction,full_data_lin['y_val'])}")
print(f"MSE : {mean_squared_error(prediction,full_data_lin['y_val'])}")


##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
# Out:
#  R2 score: -0.69494164056636
# MSE : 0.0149080932560778
#  R2 score: -0.6969613051247039
# MSE : 0.015555308755282899
# /var/folders/t8/qrphqz7x5b12zmkdpv0mcrth0000gn/T/ipykernel_2613/4089397025.py:62: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfr = rfr.fit(full_data['X_train'],full_data['y_train'])
#  R2 score: -9.647221958140388
# MSE : 0.006676338985340906
# /var/folders/t8/qrphqz7x5b12zmkdpv0mcrth0000gn/T/ipykernel_2613/4089397025.py:81: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfr2 = rfr2.fit(full_data_lin['X_train'],full_data_lin['y_train'])

# %% [markdown]
# ## Results
#
# Compare the above findings and write your results here.

# %%
# First of all, using more data gives better results for the neural network. The validation loss goes down a lot.

# Next, the linear model is estimated.

# Finally the Tree/cart models give worse results. They are only able to fit the linearities.

# %% [markdown]
# ### Linear models
# #### No regularization
# Score : 0.08245393743156171
#
# MSE : 0.007547930464905104
#
#
#
# #### L1 regularization linear regression
# Score : 0.048988194175359934
#
# MSE : 0.007823226837870942
#
#
# #### L2 regularization linear regression
# Score : 0.08274967654389453
#
# MSE : 0.007545497651614627
#
#
#
# ### Tree model (CART)
#
#  R2 score: -0.8114676415484181
#
# MSE : 0.014553577891223416
#
#
#
# ### Random forest regressor
# Random Forest is better.  The result is a better prediction model. The cause is lower variance. Training it takes a lot more time however.
# MSE : 0.007535582646855499 (Run1)
# MSE : 0.007562312449456411 (Run2)
#
# ## Conclusion
#
# The nonlinearity that can be captured by the neural network is a real benefit and allows to fit the model way better.

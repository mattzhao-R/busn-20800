# %% [markdown]
# # Assignment 6: Neural network
#
# ## BUS 20800: Big Data
# ## Due: 11:59 am on May 23, 2022

# %% [markdown]
# This assignment is a simplified exercise based on the simulations in this paper:
# [Empirical Asset Pricing via Machine Learning](https://dachxiu.chicagobooth.edu/download/ML.pdf).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot  as plt
import os

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
path = './Simu/SimuData_100/'

# %% [markdown]
# # Part I. DGP

# %% [markdown]
# You can check the data generating process in `DGP.py`. We have generated firm characteristics and returns as linear and nonlinear functions of these characteristics, respectively.
#
#
# It takes several minutues to run the simulation code and generate the data, if you want to run it yourself. We have provided the simulated data for you. You can check the simulated data in `Simu` folder. There are 100 Monte Carlo repetions.

# %% [markdown]
# # Part II. Two Layer NN

# %% [markdown]
# First, follow the instruction codes in lecture codes, finish this toy `TwoLayerNet` class for rergression.

# %%
class TwoLayerNet(object):
    """
    A two-layer fully-connected neural network. The net has an input dimension of
    N, a hidden layer dimension of H, and performs regression task.
    
    We train the network with square loss and L2 regularization on the
    weight matrices. The network uses a ReLU nonlinearity after the first fully
    connected layer.

    In other words, the network has the following architecture:

    input - fully connected layer - ReLU - fully connected layer - square loss

    The outputs of the second fully-connected layer are the predictions.
    """
    
    
    # Initialize the NN
    def __init__(self, input_size, hidden_size, output_size, std=1e-4):
        
        """
        Initialize the model. Weights are initialized to small random values and
        biases are initialized to zero. Weights and biases are stored in the
        variable self.params, which is a dictionary with the following keys:

        W1: First layer weights; Shape (D, H)
        b1: First layer biases; Shape (H,)
        W2: Second layer weights; Shape (H, 1)
        b2: Second layer biases; Shape (1,)

        Inputs:
        - input_size: The dimension D of the input data.
        - hidden_size: The number of neurons H in the hidden layer.
        - output_size: Output prediction.
        """
        
        self.params = {}
        self.params['W1'] = std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size)
        self.params['W2'] = std * np.random.randn(hidden_size, output_size)
        self.params['b2'] = np.zeros(output_size)

    def loss(self, X, y=None, reg=0.0):
        """
        Compute the loss and gradients for a two layer fully connected neural
        network.

        Inputs:
        - X: Shape (N, D). Each X[i] is a training sample.
        - y: Vector of training labels.
        - reg: Regularization strength.

        Returns:
        If y is None, return a matrix scores of shape (N, 1) where scores[i,0] is
        the prediction.

        If y is not None, instead return a tuple of:
        - loss: Loss (data loss and regularization penalty) 
        - grads: Dictionary mapping parameter names to gradients of those parameters
          with respect to the loss function; has the same keys as self.params.
        """
        
        # Unpack variables from the params dictionary
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']
        N, D = X.shape

        # Compute the forward pass
        # Use Relu as the non-linearity function
        scores = np.maximum(X.dot(W1) + b1, 0).dot(W2) + b2


        # If the targets are not given then jump out, we're done
        if y is None:
            return scores
        
##############################################################################
### TODO: Calculate the loss function (data + regularization)              ###
##############################################################################
        # Compute the loss
        
        loss = np.sum(np.square(scores-y))/N
        reg_term = np.sum(np.square(W1)) + np.sum(np.square(W2))
        # Add regularization loss
        loss += reg/2 * reg_term * W1.shape[1] * W2.shape[1] / N

##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################

        
        
        # Backward pass: compute gradients
        grads = {}            
##############################################################################
### TODO: Calculate the gradient of each parameter.                        ###
##############################################################################
        dlossdscores = -2/N*(y-scores)  # N
        
        grads['b2'] = np.sum(dlossdscores, axis = 0)
        grads['W2'] = np.maximum(X.dot(W1) + b1 ,0).T.dot(dlossdscores)+ 2*reg*W2          # H x C
        grads['b1'] = np.sum((dlossdscores).dot(W2.T)*(X.dot(W1) + b1 >0),axis = 0) # H x 1
        grads['W1'] = X.T.dot(dlossdscores.dot(W2.T)*(X.dot(W1) + b1 >0)) + 2*reg*W1   
       
##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
        
        return loss, grads

    def train(self, X, y, X_val, y_val,
              learning_rate=1e-3, learning_rate_decay=0.95,
              reg=5e-6, num_iters=100,
              batch_size=200, verbose=False):
        """
        Train this neural network using SGD.

        Inputs:
        - X: Shape (N, D) 
        - y: Shape (N, )
        - X_val: Shape (N_val, D) 
        - y_val: Shape (N_val, ) 
        - learning_rate: Scalar giving learning rate for optimization.
        - learning_rate_decay: Scalar giving factor used to decay the learning rate
          after each epoch.
        - reg: Scalar giving regularization strength.
        - num_iters: Number of steps to take when optimizing.
        - batch_size: Number of training examples to use per step.
        - verbose: boolean; if true print progress during optimization.
        """
        
        num_train = X.shape[0]
        iterations_per_epoch = max(num_train / batch_size, 1)

        # Use SGD to optimize the parameters in self.model
        loss_history = []
        train_acc_history = []
        val_acc_history = []

        for it in range(num_iters):
            X_batch = None
            y_batch = None

            mask  = np.random.choice(num_train, batch_size, replace=True)
            X_batch = X[mask]
            y_batch = y[mask]

            # Compute loss and gradients using the current minibatch
            loss, grads = self.loss(X_batch, y=y_batch, reg=reg)
            loss_history.append(loss)

            # Gradient descent 
##############################################################################
### TODO: Perform Gradient descent to update parameters                                    ###
##############################################################################
##############################################################################
            self.params['b1']  += -learning_rate * grads['b1']
            self.params['W1']  += -learning_rate * grads['W1']
            self.params['b2']  += -learning_rate * grads['b2']
            self.params['W2']  += -learning_rate * grads['W2']

##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################

            if verbose and it % 100 == 0:
                print('iteration %d / %d: loss %f' % (it, num_iters, loss))

            # Every epoch, check train and val accuracy and decay learning rate.
            if it % iterations_per_epoch == 0:
                # Check accuracy
                train_acc = (self.predict(X_batch) == y_batch).mean()
                val_acc = (self.predict(X_val) == y_val).mean()
                train_acc_history.append(train_acc)
                val_acc_history.append(val_acc)

                # Decay learning rate
                learning_rate *= learning_rate_decay

        return {
          'loss_history': loss_history,
          'train_acc_history': train_acc_history,
          'val_acc_history': val_acc_history,
        }

    def predict(self, X):
        """
        Use the trained weights of this two-layer network to predict return for
        data points.
        Inputs:
        - X: Shape (N, D)

        Returns:
        - y_pred: Shape (N,)
        """

        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']
        
##############################################################################
### Done: Calculate the prediction.                                        ###
##############################################################################
        
        scores = np.maximum(X.dot(W1) + b1, 0).dot(W2) + b2
        y_pred = np.argmax(scores,axis = 1)

##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
        
        return y_pred

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
output_size = 1
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, output_size, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1]).reshape(-1,1)
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# ## Forward pass: compute scores
# Open the file `neural_net.py` and look at the method `TwoLayerNet.loss`. It takes the data and weights and computes the class scores, the loss, and the gradients with respect to the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [0.38061523],
  [-0.55607245],
  [-0.59991751],
  [-0.61246639],
  [0.05788525]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[ 0.38061523]
#  [-0.55607245]
#  [-0.59991751]
#  [-0.61246639]
#  [ 0.05788525]]
#
# correct scores:
# [[ 0.38061523]
#  [-0.55607245]
#  [-0.59991751]
#  [-0.61246639]
#  [ 0.05788525]]
#
# Difference between your scores and correct scores:
# 1.4530232225751227e-08

# %% [markdown]
# ## Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y.reshape(-1,1), reg=0.05)
correct_loss = 3.439836236605

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 5.693223670277803e-13

# %%
from gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# The difference between the numeric and analytic gradients should be less than 
# 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)
# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    #print(param_grad_num)
    #print(grads[param_name])
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# b2 max relative error: 3.758574e-13
# W2 max relative error: 5.930725e-10
# b1 max relative error: 4.959296e-10
# W1 max relative error: 3.561318e-09

# %% [markdown]
# ## Combine the above: Training

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=4e-3, reg=1e-3,
            num_iters=100, verbose=False)
# Note: I Changed the learning rate and regularization size to get a good training.
print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration',size = 20)
plt.ylabel('training loss',size = 20)
plt.title('Training Loss history', size = 20)
plt.show()
# Out:
# Final training loss:  0.337877923626524

# %% [markdown]
# #  Part III. Multi-layer NN
#
# Now we have finished the top layer, and we want to build networks using a more modular design so that we can implement different layer types in isolation and then snap them together into models with various architectures.

# %% [markdown]
# ## Affine layer: foward

# %%
def affine_forward(x, w, b):
    """
    Computes the forward pass for an affine (fully-connected) layer.

    The input x has shape (N, d_1, ..., d_k) and contains a minibatch of N
    examples, where each example x[i] has shape (d_1, ..., d_k). 
    Reshape each input into a vector of dimension D = d_1 * ... * d_k, and
    then transform it to an output vector of dimension M.

    Inputs:
    - x: A numpy array containing input data, of shape (N, d_1, ..., d_k)
    - w: A numpy array of weights, of shape (D, M)
    - b: A numpy array of biases, of shape (M,)

    Returns a tuple of:
    - out: output, of shape (N, M)
    - cache: (x, w, b)
    """

##############################################################################
### TODO: Perform affine transformation.                                   ###
##############################################################################,
    #reshaped_x = x.reshape(x.shape[0],-1)
  

    #out = (np.dot(w.T,reshaped_x.T).T+b.T)
    out = np.reshape(x,(x.shape[0],np.prod(x.shape[1:]))).dot(w) + b


##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
    cache = (x, w, b)
    
    return out, cache

# %%
# Test the affine_forward function

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 1

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.51506276],
                        [ 3.32259414]])

# Compare your output with ours. The error should be around e-9 or less.
print('Testing affine_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing affine_forward function:
# difference:  4.971001967190414e-10

# %% [markdown]
# ## Affine layer: backward

# %%
def affine_backward(dout, cache):
    """
    Computes the backward pass for an affine layer.

    Inputs:
    - dout: Upstream derivative, of shape (N, M)
    - cache: Tuple of:
      - x: Input data, of shape (N, d_1, ... d_k)
      - w: Weights, of shape (D, M)
      - b: Biases, of shape (M,)

    Returns a tuple of:
    - dx: Gradient with respect to x, of shape (N, d1, ..., d_k)
    - dw: Gradient with respect to w, of shape (D, M)
    - db: Gradient with respect to b, of shape (M,)
    """
    x, w, b = cache

##############################################################################
### TODO: Calculate the gradient of affine transformation                  ###
##############################################################################

    db = np.sum(dout,axis=0)
 
    dw = np.reshape(x,(x.shape[0],np.prod(x.shape[1:]))).T.dot(dout)
    dx = np.dot(dout,w.T)
    dx = dx.reshape(x.shape)
    

##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################


    return dx, dw, db

# %%
from gradient_check import eval_numerical_gradient, eval_numerical_gradient_array


# Test the affine_backward function
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 1)
b = np.random.randn(1)
dout = np.random.randn(10, 1)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around e-10 or less
print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_backward function:
# dx error:  6.87499785805733e-11
# dw error:  5.93473398572531e-11
# db error:  2.4097482260876687e-12

# %% [markdown]
# ##  ReLU activation: forward

# %% [markdown]
# ### ReLU
# There are many potential choices for the nonlinear activation function (such
# as sigmoid, hyperbolic, softmax). We use the same activation function at all
# nodes, and choose a popular functional form in recent literature known as the
# rectified linear unit (ReLU), defined as:
#
# $$\text{ReLU}(x) = \begin{cases}0 \quad &\text{if}\; x < 0 \\
# x \quad &\text{otherwise} \end{cases} $$
#
# which encourages sparsity in the number of active neurons and allows for faster derivative evaluation.

# %% [markdown]
# Our neural network model has the following general formula. Let $K^{(l)}$ denote the number of neurons in each layer $l =1,...,L$. Define the output of neuron $k$ in layer $l$ as $x_{k}^{(l)}$. Next, define the vector of outputs for this layer (augmented to include a constant, $x_{0}^{(l)}$ ) as
# $x^{(l)} = (1,x_{1}^{(l)},...,x_{K^{l}}^{(l)})'$.
# To initialize the network, similarly define the input layer using the raw predictors, $x^{(0)} =(1,z_{1},...,z_{N})'$. The recursive output formula for the neural network at each neuron in layer $l>0$ is then
#
# $$x_{k}^{(l)} =  \text{ReLU} \left( x^{(l-1)'} \;\theta_{k}^{(l-1)}\; \right)$$
#
# with final output:
#
# $$g(z;\theta) = x^{(L-1)'} \;\theta^{L-1}$$
#
# The number of weight parameters in each hidden layer $l$ is $K^{(l)}\left(1+K^{(l−1)} \;\right)$, plus another $1+K^{(L−1)}$ weights for the output layer.
#
# We estimate the neural network weight parameters by minimizing the penalized $l_{2}$ objective function of prediction errors. Unlike tree-based algorithms that require “greedy” optimization, training a neural network, in principle, allows for joint updates of all model parameters at each step of the optimization—a substantial advantage of neural networks over trees.

# %%
def relu_forward(x):
    """
    Computes the forward pass for a layer of rectified linear units (ReLUs).
    """
##############################################################################
### TODO: Calculate the gradient of affine transformation                  ###
##############################################################################
    out = np.maximum(0,x)
##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
    cache = x
    return out, cache

# %%
# Test the relu_forward function

x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be on the order of e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# ## ReLU activation: backward

# %%
def relu_backward(dout, cache):
    """
    Computes the backward pass for a layer of ReLUs.

    Input:
    - dout: Upstream derivatives, of any shape
    - cache: Input x, of same shape as dout

    Returns:
    - dx: Gradient with respect to x
    """
    dx, x = None, cache
    
##############################################################################
### TODO: Calculate the gradient of affine transformation                  ###
##############################################################################
    dx = dout*(x>0)
##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
    cache = x

    return dx

# %%
np.random.seed(231)
x = np.random.randn(10, 5)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)
# The error should be on the order of e--12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2756219598992723e-12

# %% [markdown]
# ## Loss layers: MSE

# %%
def mean_square_loss(x, y):
    """
    Computes the loss and gradient for mean square loss.

    Inputs:
    - x: Shape (N, ) 
    - y: Shape (N,)
    
    Returns a tuple of:
    - loss: Scalar giving the loss
    - dx: Gradient of the loss with respect to x
    """
    
##############################################################################
### TODO: Calculate the loss and gradient for MSE.                         ###
##############################################################################
    N = x.shape[0]

    

    loss = 1/N*np.sum(np.square(y-x))
    dx = -2/N*(y-x)
    

##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################

    return loss, dx

# %%
np.random.seed(231)
num_output, num_inputs = 1, 50
x = 0.001 * np.random.randn(num_inputs, num_output)
y = np.random.randint(num_output, size=num_inputs).reshape(-1,1)

dx_num = eval_numerical_gradient(lambda x: mean_square_loss(x, y)[0], x, verbose=False)
loss, dx = mean_square_loss(x, y)
# Test mean_square_loss function. Loss should be close to 2.3 and dx error should be around e-8
print('\nTesting mean_square_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing mean_square_loss:
# loss:  7.717948769472713e-07
# dx error:  8.55397758197063e-13

# %% [markdown]
# ## Combine the above blocks and build a neural network

# %% [markdown]
# ## Initial loss and gradient check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. Do the initial losses seem reasonable?
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
class FullyConnectedNet(object):
    """
    A fully-connected neural network with an arbitrary number of hidden layers,
    ReLU nonlinearities, and a mean square loss function. For a network with L layers,
    the architecture will be

    {affine - [batch/layer norm] - relu - [dropout]} x (L - 1) - affine - mean_square

    where batch/layer normalization and dropout are optional, and the {...} block is
    repeated L - 1 times.

    Learnable parameters are stored in the
    self.params dictionary and will be learned using the Solver class.
    """

    def __init__(self, hidden_dims, input_dim=100, num_output=1,
                 reg=0.0,
                 weight_scale=1e-2, dtype=np.float32):
        """
        Initialize a new FullyConnectedNet.

        Inputs:
        - hidden_dims: A list of integers giving the size of each hidden layer.
        - input_dim: An integer giving the size of the input.
        - num_output: For regression, num_output = 1
        - reg: Scalar giving L2 regularization strength.
        - weight_scale: Scalar giving the standard deviation for random
          initialization of the weights.
        - dtype: A numpy datatype object; all computations will be performed using
          this datatype. float32 is faster but less accurate, so you should use
          float64 for numeric gradient checking.

        """
        self.reg = reg
        self.num_layers = 1 + len(hidden_dims)
        self.dtype = dtype
        self.params = {}

        if len(hidden_dims)>0:
            self.params['W1'] = weight_scale * np.random.randn(input_dim, hidden_dims[0])
            self.params['b1'] = np.zeros(hidden_dims[0])
        
        for idx, dim in enumerate(hidden_dims):
            if idx < len(hidden_dims)-1:
                self.params['W' + str(2 + idx)] = weight_scale * np.random.randn(dim, hidden_dims[idx + 1])
                self.params['b' + str(2 + idx)] = np.zeros(hidden_dims[idx + 1])
            else:
                self.params['W' + str(2 + idx)] = weight_scale * np.random.randn(hidden_dims[idx], num_output)
                self.params['b' + str(2 + idx)] = np.zeros(num_output)


        # Cast all parameters to the correct datatype
        for k, v in self.params.items():
            self.params[k] = v.astype(dtype)


    def loss(self, X, y=None):
        """
        Compute loss and gradient for the fully-connected net.

        Input / output: Same as TwoLayerNet above.
        """
        X = X.astype(self.dtype)
        mode = 'test' if y is None else 'train'

        out = X
        for la in range(self.num_layers-1):
            a, _      = affine_forward(out, self.params['W'+str(la+1)], self.params['b'+str(la+1)])
            out, _    = relu_forward(a)
            

            
        scores, _ = affine_forward(out,
                                   self.params['W'+str(self.num_layers)],self.params['b'+str(self.num_layers)])


        # If test mode return early
        if mode == 'test':
            return scores

        out = X
        a=[]
        affine_cache = []
        relu_cache   = []
       
        
        loss, grads = 0.0, {}
        
        for la in range(self.num_layers-1):
            a, a_cache    = affine_forward(out, self.params['W'+str(la+1)], self.params['b'+str(la+1)])
            affine_cache.append(a_cache)
                
            out, r_cache    = relu_forward(a)
            relu_cache.append(r_cache)
            
   
        scores, cache  = affine_forward(out, self.params['W'+str(self.num_layers)], self.params['b'+str(self.num_layers)])
        loss, dx       = mean_square_loss(scores, y)
        
        
    
        da, dW, db  = affine_backward(dx, cache)
        grads['W'+str(self.num_layers)] = dW
        grads['b'+str(self.num_layers)] = db
        
            
        for la in reversed(range(self.num_layers-1)):            
            
            dr = relu_backward(da, relu_cache[la])
            
            da, dW, db = affine_backward(dr, affine_cache[la])
            grads['W'+ str(la+1)] = dW
            grads['b'+ str(la+1)] = db
            
        for la in range(self.num_layers):
            loss += 1/2*self.reg * np.sum(self.params['W'+ str(la+1)] * self.params['W'+ str(la+1)])     
            grads['W'+ str(la+1)]  +=  self.reg*self.params['W'+ str(la+1)] 

        return loss, grads

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 1
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,)).reshape(-1,1)

for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_output=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)
  
  # Most of the errors should be on the order of e-7 or smaller.   
  # for the check when reg = 0.0
  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Running check with reg =  0
# Initial loss:  5.741767878577345e-05
# W1 relative error: 1.83e-09
# W2 relative error: 8.98e-10
# W3 relative error: 6.32e-11
# b1 relative error: 1.87e-10
# b2 relative error: 2.28e-12
# b3 relative error: 3.47e-14
# Running check with reg =  3.14
# Initial loss:  3.8788787972165957
# W1 relative error: 5.62e-09
# W2 relative error: 9.46e-09
# W3 relative error: 1.38e-09
# b1 relative error: 1.00e-04
# b2 relative error: 1.21e-05
# b3 relative error: 8.33e-09

# %% [markdown]
# # Part IV. Return prediction

# %% [markdown]
# The simulation result in `Simu` file. It contains 100 time Monte Carlo simulation experiment, each with firm characteristics, linear and non-linear return.

# %%
# Setup codes

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# Run the following cells to load the data. You can choose different i here.

# %%
i = str(1)

factor = np.array(pd.read_csv(path+'c'+i+'.csv'))
linear_ret = np.array(pd.read_csv(path+'r1_'+i+'_1.csv'))
nonlinear_ret = np.array(pd.read_csv(path+'r2_'+i+'_1.csv'))

# %% [markdown]
# With the above preparation, build a NN using linear and non-linear return. And compare the results with
# + OLS,
# + OLS + Regularization (L1,L2),
# + Tree model(CART+Random Forest).
#
# What conclusions can you make? (You can use some visualziation tools to help you illustrate your results)

# %% [markdown]
# ### Neural network

# %% [markdown]
# Here is a NN example with subsample dataset. Once you finish all the cells above. You can directly run the below cells to get the prediction result.You don't need to modify any codes here.

# %%
# NN with sample data

from solver import Solver

num_train = 2500
num_valid = 500
small_data = {
  'X_train': factor[:num_train],
  'y_train': nonlinear_ret[:num_train],
  'X_val': factor[num_train:num_train+num_valid],
  'y_val': nonlinear_ret[num_train:num_train+num_valid]
}

learning_rate = 5e-2  # Experiment with this!
weight_scale = 1*1e-1   # Experiment with this!
model = FullyConnectedNet([100, 100, 100, 100],
                weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 2000) loss: 0.017017
# (Epoch 0 / 20) train acc: -0.000694; val_acc: -0.003124
# (Iteration 11 / 2000) loss: 0.008818
# (Iteration 21 / 2000) loss: 0.010459
# (Iteration 31 / 2000) loss: 0.010009
# (Iteration 41 / 2000) loss: 0.016796
# (Iteration 51 / 2000) loss: 0.005095
# (Iteration 61 / 2000) loss: 0.012158
# (Iteration 71 / 2000) loss: 0.006515
# (Iteration 81 / 2000) loss: 0.005443
# (Iteration 91 / 2000) loss: 0.006449
# (Epoch 1 / 20) train acc: -0.000130; val_acc: -0.003124
# (Iteration 101 / 2000) loss: 0.007280
# (Iteration 111 / 2000) loss: 0.009787
# (Iteration 121 / 2000) loss: 0.007164
# (Iteration 131 / 2000) loss: 0.009054
# (Iteration 141 / 2000) loss: 0.006271
# (Iteration 151 / 2000) loss: 0.004868
# (Iteration 161 / 2000) loss: 0.007177
# (Iteration 171 / 2000) loss: 0.007936
# (Iteration 181 / 2000) loss: 0.007051
# (Iteration 191 / 2000) loss: 0.004328
# (Epoch 2 / 20) train acc: -0.001758; val_acc: -0.003124
# (Iteration 201 / 2000) loss: 0.009747
# (Iteration 211 / 2000) loss: 0.006635
# (Iteration 221 / 2000) loss: 0.006315
# (Iteration 231 / 2000) loss: 0.005673
# (Iteration 241 / 2000) loss: 0.011740
# (Iteration 251 / 2000) loss: 0.009580
# (Iteration 261 / 2000) loss: 0.004895
# (Iteration 271 / 2000) loss: 0.008999
# (Iteration 281 / 2000) loss: 0.011029
# (Iteration 291 / 2000) loss: 0.007160
# (Epoch 3 / 20) train acc: -0.000005; val_acc: -0.003124
# (Iteration 301 / 2000) loss: 0.013084
# (Iteration 311 / 2000) loss: 0.007992
# (Iteration 321 / 2000) loss: 0.005958
# (Iteration 331 / 2000) loss: 0.005488
# (Iteration 341 / 2000) loss: 0.005463
# (Iteration 351 / 2000) loss: 0.008087
# (Iteration 361 / 2000) loss: 0.006961
# (Iteration 371 / 2000) loss: 0.011099
# (Iteration 381 / 2000) loss: 0.004014
# (Iteration 391 / 2000) loss: 0.008021
# (Epoch 4 / 20) train acc: -0.001830; val_acc: -0.003124
# (Iteration 401 / 2000) loss: 0.006890
# (Iteration 411 / 2000) loss: 0.009938
# (Iteration 421 / 2000) loss: 0.009352
# (Iteration 431 / 2000) loss: 0.007450
# (Iteration 441 / 2000) loss: 0.004739
# (Iteration 451 / 2000) loss: 0.010406
# (Iteration 461 / 2000) loss: 0.006555
# (Iteration 471 / 2000) loss: 0.008944
# (Iteration 481 / 2000) loss: 0.009151
# (Iteration 491 / 2000) loss: 0.004611
# (Epoch 5 / 20) train acc: -0.000072; val_acc: -0.003124
# (Iteration 501 / 2000) loss: 0.005053
# (Iteration 511 / 2000) loss: 0.009840
# (Iteration 521 / 2000) loss: 0.008836
# (Iteration 531 / 2000) loss: 0.003562
# (Iteration 541 / 2000) loss: 0.006020
# (Iteration 551 / 2000) loss: 0.005108
# (Iteration 561 / 2000) loss: 0.006662
# (Iteration 571 / 2000) loss: 0.005181
# (Iteration 581 / 2000) loss: 0.002574
# (Iteration 591 / 2000) loss: 0.011203
# (Epoch 6 / 20) train acc: -0.000062; val_acc: -0.003124
# (Iteration 601 / 2000) loss: 0.004592
# (Iteration 611 / 2000) loss: 0.007473
# (Iteration 621 / 2000) loss: 0.005036
# (Iteration 631 / 2000) loss: 0.004919
# (Iteration 641 / 2000) loss: 0.007543
# (Iteration 651 / 2000) loss: 0.005233
# (Iteration 661 / 2000) loss: 0.006221
# (Iteration 671 / 2000) loss: 0.005692
# (Iteration 681 / 2000) loss: 0.006574
# (Iteration 691 / 2000) loss: 0.007239
# (Epoch 7 / 20) train acc: -0.000511; val_acc: -0.003124
# (Iteration 701 / 2000) loss: 0.008674
# (Iteration 711 / 2000) loss: 0.006404
# (Iteration 721 / 2000) loss: 0.005119
# (Iteration 731 / 2000) loss: 0.004563
# (Iteration 741 / 2000) loss: 0.004964
# (Iteration 751 / 2000) loss: 0.005651
# (Iteration 761 / 2000) loss: 0.011248
# (Iteration 771 / 2000) loss: 0.008841
# (Iteration 781 / 2000) loss: 0.005379
# (Iteration 791 / 2000) loss: 0.009509
# (Epoch 8 / 20) train acc: -0.004165; val_acc: -0.003124
# (Iteration 801 / 2000) loss: 0.007959
# (Iteration 811 / 2000) loss: 0.004986
# (Iteration 821 / 2000) loss: 0.004032
# (Iteration 831 / 2000) loss: 0.006980
# (Iteration 841 / 2000) loss: 0.006224
# (Iteration 851 / 2000) loss: 0.007874
# (Iteration 861 / 2000) loss: 0.006236
# (Iteration 871 / 2000) loss: 0.006081
# (Iteration 881 / 2000) loss: 0.009413
# (Iteration 891 / 2000) loss: 0.010746
# (Epoch 9 / 20) train acc: -0.002096; val_acc: -0.003124
# (Iteration 901 / 2000) loss: 0.006896
# (Iteration 911 / 2000) loss: 0.008003
# (Iteration 921 / 2000) loss: 0.004268
# (Iteration 931 / 2000) loss: 0.011177
# (Iteration 941 / 2000) loss: 0.007847
# (Iteration 951 / 2000) loss: 0.004173
# (Iteration 961 / 2000) loss: 0.009050
# (Iteration 971 / 2000) loss: 0.005245
# (Iteration 981 / 2000) loss: 0.003997
# (Iteration 991 / 2000) loss: 0.009716
# (Epoch 10 / 20) train acc: -0.003350; val_acc: -0.003124
# (Iteration 1001 / 2000) loss: 0.005802
# (Iteration 1011 / 2000) loss: 0.006118
# (Iteration 1021 / 2000) loss: 0.008180
# (Iteration 1031 / 2000) loss: 0.009387
# (Iteration 1041 / 2000) loss: 0.004063
# (Iteration 1051 / 2000) loss: 0.006811
# (Iteration 1061 / 2000) loss: 0.007639
# (Iteration 1071 / 2000) loss: 0.004031
# (Iteration 1081 / 2000) loss: 0.010960
# (Iteration 1091 / 2000) loss: 0.005238
# (Epoch 11 / 20) train acc: -0.000056; val_acc: -0.003124
# (Iteration 1101 / 2000) loss: 0.002754
# (Iteration 1111 / 2000) loss: 0.002869
# (Iteration 1121 / 2000) loss: 0.006752
# (Iteration 1131 / 2000) loss: 0.004477
# (Iteration 1141 / 2000) loss: 0.006361
# (Iteration 1151 / 2000) loss: 0.002081
# (Iteration 1161 / 2000) loss: 0.003163
# (Iteration 1171 / 2000) loss: 0.002801
# (Iteration 1181 / 2000) loss: 0.004500
# (Iteration 1191 / 2000) loss: 0.004469
# (Epoch 12 / 20) train acc: -0.000067; val_acc: -0.003124
# (Iteration 1201 / 2000) loss: 0.006545
# (Iteration 1211 / 2000) loss: 0.003286
# (Iteration 1221 / 2000) loss: 0.006626
# (Iteration 1231 / 2000) loss: 0.005088
# (Iteration 1241 / 2000) loss: 0.007127
# (Iteration 1251 / 2000) loss: 0.007157
# (Iteration 1261 / 2000) loss: 0.006465
# (Iteration 1271 / 2000) loss: 0.007759
# (Iteration 1281 / 2000) loss: 0.003104
# (Iteration 1291 / 2000) loss: 0.007701
# (Epoch 13 / 20) train acc: -0.000169; val_acc: -0.003124
# (Iteration 1301 / 2000) loss: 0.006417
# (Iteration 1311 / 2000) loss: 0.004008
# (Iteration 1321 / 2000) loss: 0.004667
# (Iteration 1331 / 2000) loss: 0.006342
# (Iteration 1341 / 2000) loss: 0.007975
# (Iteration 1351 / 2000) loss: 0.003806
# (Iteration 1361 / 2000) loss: 0.005855
# (Iteration 1371 / 2000) loss: 0.004056
# (Iteration 1381 / 2000) loss: 0.006094
# (Iteration 1391 / 2000) loss: 0.006039
# (Epoch 14 / 20) train acc: -0.002923; val_acc: -0.003124
# (Iteration 1401 / 2000) loss: 0.006476
# (Iteration 1411 / 2000) loss: 0.004227
# (Iteration 1421 / 2000) loss: 0.004560
# (Iteration 1431 / 2000) loss: 0.002978
# (Iteration 1441 / 2000) loss: 0.006309
# (Iteration 1451 / 2000) loss: 0.003928
# (Iteration 1461 / 2000) loss: 0.006064
# (Iteration 1471 / 2000) loss: 0.005265
# (Iteration 1481 / 2000) loss: 0.007239
# (Iteration 1491 / 2000) loss: 0.004095
# (Epoch 15 / 20) train acc: -0.000032; val_acc: -0.003124
# (Iteration 1501 / 2000) loss: 0.004753
# (Iteration 1511 / 2000) loss: 0.004851
# (Iteration 1521 / 2000) loss: 0.010515
# (Iteration 1531 / 2000) loss: 0.005100
# (Iteration 1541 / 2000) loss: 0.007328
# (Iteration 1551 / 2000) loss: 0.003363
# (Iteration 1561 / 2000) loss: 0.009498
# (Iteration 1571 / 2000) loss: 0.003427
# (Iteration 1581 / 2000) loss: 0.006564
# (Iteration 1591 / 2000) loss: 0.004719
# (Epoch 16 / 20) train acc: -0.001181; val_acc: -0.003124
# (Iteration 1601 / 2000) loss: 0.006693
# (Iteration 1611 / 2000) loss: 0.002846
# (Iteration 1621 / 2000) loss: 0.004062
# (Iteration 1631 / 2000) loss: 0.007630
# (Iteration 1641 / 2000) loss: 0.004781
# (Iteration 1651 / 2000) loss: 0.006010
# (Iteration 1661 / 2000) loss: 0.004797
# (Iteration 1671 / 2000) loss: 0.007462
# (Iteration 1681 / 2000) loss: 0.003420
# (Iteration 1691 / 2000) loss: 0.003482
# (Epoch 17 / 20) train acc: -0.001074; val_acc: -0.003124
# (Iteration 1701 / 2000) loss: 0.007592
# (Iteration 1711 / 2000) loss: 0.004887
# (Iteration 1721 / 2000) loss: 0.004689
# (Iteration 1731 / 2000) loss: 0.007431
# (Iteration 1741 / 2000) loss: 0.002517
# (Iteration 1751 / 2000) loss: 0.008726
# (Iteration 1761 / 2000) loss: 0.004874
# (Iteration 1771 / 2000) loss: 0.007379
# (Iteration 1781 / 2000) loss: 0.006976
# (Iteration 1791 / 2000) loss: 0.005752
# (Epoch 18 / 20) train acc: -0.000066; val_acc: -0.003124
# (Iteration 1801 / 2000) loss: 0.006042
# (Iteration 1811 / 2000) loss: 0.005618
# (Iteration 1821 / 2000) loss: 0.003892
# (Iteration 1831 / 2000) loss: 0.004423
# (Iteration 1841 / 2000) loss: 0.010290
# (Iteration 1851 / 2000) loss: 0.005876
# (Iteration 1861 / 2000) loss: 0.005518
# (Iteration 1871 / 2000) loss: 0.004694
# (Iteration 1881 / 2000) loss: 0.007680
# (Iteration 1891 / 2000) loss: 0.003826
# (Epoch 19 / 20) train acc: -0.000303; val_acc: -0.003124
# (Iteration 1901 / 2000) loss: 0.003592
# (Iteration 1911 / 2000) loss: 0.006224
# (Iteration 1921 / 2000) loss: 0.004463
# (Iteration 1931 / 2000) loss: 0.004642
# (Iteration 1941 / 2000) loss: 0.007126
# (Iteration 1951 / 2000) loss: 0.004739
# (Iteration 1961 / 2000) loss: 0.004703
# (Iteration 1971 / 2000) loss: 0.005370
# (Iteration 1981 / 2000) loss: 0.004122
# (Iteration 1991 / 2000) loss: 0.003803
# (Epoch 20 / 20) train acc: -0.005524; val_acc: -0.003124

# %% [markdown]
# Now follow the same framework shown in the subsample data, train the NN with full sample data.Try to tune the parameters and construct the neural network with different numbers of layers. Compare their results.

# %%
# NN with full data


##############################################################################
### TODO: NN with full data.                                               ###
##############################################################################

from solver import Solver
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

#factor = StandardScaler().fit_transform(factor)
#nonlinear_ret = StandardScaler().fit_transform(nonlinear_ret)


nonlin_X_train,nonlin_X_test,nonlin_y_train,nonlin_y_test = train_test_split(factor, nonlinear_ret, test_size = 0.3)


full_data_nonlin = {
  'X_train': nonlin_X_train,
  'y_train': nonlin_y_train,
  'X_val': nonlin_X_test,
  'y_val': nonlin_y_test
}

learning_rate = 5*1e-3  # Experiment with this!
weight_scale = 1*1e-2   # Experiment with this!
model = FullyConnectedNet([500, 200,100],reg=5*1e-2,
                weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, full_data_nonlin,
                print_every=20, num_epochs=20, batch_size=50,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()

plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.title('Training and Validation accuracy')
plt.xlabel('Epoch')

plt.show()


##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
# Out:
# (Iteration 1 / 10080) loss: 0.430768
# (Epoch 0 / 20) train acc: -0.000018; val_acc: -0.000026
# (Iteration 21 / 10080) loss: 0.427337
# (Iteration 41 / 10080) loss: 0.423589
# (Iteration 61 / 10080) loss: 0.419519
# (Iteration 81 / 10080) loss: 0.414327
# (Iteration 101 / 10080) loss: 0.414215
# (Iteration 121 / 10080) loss: 0.407072
# (Iteration 141 / 10080) loss: 0.413209
# (Iteration 161 / 10080) loss: 0.398673
# (Iteration 181 / 10080) loss: 0.394229
# (Iteration 201 / 10080) loss: 0.390662
# (Iteration 221 / 10080) loss: 0.385729
# (Iteration 241 / 10080) loss: 0.381703
# (Iteration 261 / 10080) loss: 0.380167
# (Iteration 281 / 10080) loss: 0.376589
# (Iteration 301 / 10080) loss: 0.375643
# (Iteration 321 / 10080) loss: 0.369101
# (Iteration 341 / 10080) loss: 0.365039
# (Iteration 361 / 10080) loss: 0.362698
# (Iteration 381 / 10080) loss: 0.359439
# (Iteration 401 / 10080) loss: 0.353115
# (Iteration 421 / 10080) loss: 0.353641
# (Iteration 441 / 10080) loss: 0.348750
# (Iteration 461 / 10080) loss: 0.344991
# (Iteration 481 / 10080) loss: 0.339740
# (Iteration 501 / 10080) loss: 0.337635
# (Epoch 1 / 20) train acc: -0.001846; val_acc: -0.000026
# (Iteration 521 / 10080) loss: 0.336245
# (Iteration 541 / 10080) loss: 0.330076
# (Iteration 561 / 10080) loss: 0.324099
# (Iteration 581 / 10080) loss: 0.323083
# (Iteration 601 / 10080) loss: 0.319541
# (Iteration 621 / 10080) loss: 0.315842
# (Iteration 641 / 10080) loss: 0.316013
# (Iteration 661 / 10080) loss: 0.312066
# (Iteration 681 / 10080) loss: 0.309726
# (Iteration 701 / 10080) loss: 0.308385
# (Iteration 721 / 10080) loss: 0.302239
# (Iteration 741 / 10080) loss: 0.298429
# (Iteration 761 / 10080) loss: 0.295807
# (Iteration 781 / 10080) loss: 0.295110
# (Iteration 801 / 10080) loss: 0.290383
# (Iteration 821 / 10080) loss: 0.288010
# (Iteration 841 / 10080) loss: 0.287055
# (Iteration 861 / 10080) loss: 0.283151
# (Iteration 881 / 10080) loss: 0.281592
# (Iteration 901 / 10080) loss: 0.273656
# (Iteration 921 / 10080) loss: 0.275521
# (Iteration 941 / 10080) loss: 0.270843
# (Iteration 961 / 10080) loss: 0.268438
# (Iteration 981 / 10080) loss: 0.266523
# (Iteration 1001 / 10080) loss: 0.263442
# (Epoch 2 / 20) train acc: -0.000289; val_acc: -0.000026
# (Iteration 1021 / 10080) loss: 0.261702
# (Iteration 1041 / 10080) loss: 0.258564
# (Iteration 1061 / 10080) loss: 0.255833
# (Iteration 1081 / 10080) loss: 0.254440
# (Iteration 1101 / 10080) loss: 0.252557
# (Iteration 1121 / 10080) loss: 0.249660
# (Iteration 1141 / 10080) loss: 0.244280
# (Iteration 1161 / 10080) loss: 0.243642
# (Iteration 1181 / 10080) loss: 0.241949
# (Iteration 1201 / 10080) loss: 0.237998
# (Iteration 1221 / 10080) loss: 0.238683
# (Iteration 1241 / 10080) loss: 0.235295
# (Iteration 1261 / 10080) loss: 0.232320
# (Iteration 1281 / 10080) loss: 0.229164
# (Iteration 1301 / 10080) loss: 0.226910
# (Iteration 1321 / 10080) loss: 0.227229
# (Iteration 1341 / 10080) loss: 0.225383
# (Iteration 1361 / 10080) loss: 0.220173
# (Iteration 1381 / 10080) loss: 0.219340
# (Iteration 1401 / 10080) loss: 0.219687
# (Iteration 1421 / 10080) loss: 0.214982
# (Iteration 1441 / 10080) loss: 0.213435
# (Iteration 1461 / 10080) loss: 0.211957
# (Iteration 1481 / 10080) loss: 0.207993
# (Iteration 1501 / 10080) loss: 0.204936
# (Epoch 3 / 20) train acc: -0.001903; val_acc: -0.000026
# (Iteration 1521 / 10080) loss: 0.205334
# (Iteration 1541 / 10080) loss: 0.204884
# (Iteration 1561 / 10080) loss: 0.200770
# (Iteration 1581 / 10080) loss: 0.202290
# (Iteration 1601 / 10080) loss: 0.198038
# (Iteration 1621 / 10080) loss: 0.197447
# (Iteration 1641 / 10080) loss: 0.194596
# (Iteration 1661 / 10080) loss: 0.191357
# (Iteration 1681 / 10080) loss: 0.188774
# (Iteration 1701 / 10080) loss: 0.189330
# (Iteration 1721 / 10080) loss: 0.186168
# (Iteration 1741 / 10080) loss: 0.184697
# (Iteration 1761 / 10080) loss: 0.182953
# (Iteration 1781 / 10080) loss: 0.183925
# (Iteration 1801 / 10080) loss: 0.177446
# (Iteration 1821 / 10080) loss: 0.177902
# (Iteration 1841 / 10080) loss: 0.179620
# (Iteration 1861 / 10080) loss: 0.175687
# (Iteration 1881 / 10080) loss: 0.171906
# (Iteration 1901 / 10080) loss: 0.171008
# (Iteration 1921 / 10080) loss: 0.168667
# (Iteration 1941 / 10080) loss: 0.164229
# (Iteration 1961 / 10080) loss: 0.169131
# (Iteration 1981 / 10080) loss: 0.163749
# (Iteration 2001 / 10080) loss: 0.162207
# (Epoch 4 / 20) train acc: -0.000939; val_acc: -0.000026
# (Iteration 2021 / 10080) loss: 0.164357
# (Iteration 2041 / 10080) loss: 0.162086
# (Iteration 2061 / 10080) loss: 0.156717
# (Iteration 2081 / 10080) loss: 0.157775
# (Iteration 2101 / 10080) loss: 0.153715
# (Iteration 2121 / 10080) loss: 0.151783
# (Iteration 2141 / 10080) loss: 0.151388
# (Iteration 2161 / 10080) loss: 0.148702
# (Iteration 2181 / 10080) loss: 0.150531
# (Iteration 2201 / 10080) loss: 0.146354
# (Iteration 2221 / 10080) loss: 0.145762
# (Iteration 2241 / 10080) loss: 0.146614
# (Iteration 2261 / 10080) loss: 0.145927
# (Iteration 2281 / 10080) loss: 0.145705
# (Iteration 2301 / 10080) loss: 0.142558
# (Iteration 2321 / 10080) loss: 0.141685
# (Iteration 2341 / 10080) loss: 0.138663
# (Iteration 2361 / 10080) loss: 0.135884
# (Iteration 2381 / 10080) loss: 0.133718
# (Iteration 2401 / 10080) loss: 0.132973
# (Iteration 2421 / 10080) loss: 0.137238
# (Iteration 2441 / 10080) loss: 0.133984
# (Iteration 2461 / 10080) loss: 0.131459
# (Iteration 2481 / 10080) loss: 0.132064
# (Iteration 2501 / 10080) loss: 0.129240
# (Epoch 5 / 20) train acc: -0.000058; val_acc: -0.000026
# (Iteration 2521 / 10080) loss: 0.127788
# (Iteration 2541 / 10080) loss: 0.130558
# (Iteration 2561 / 10080) loss: 0.123476
# (Iteration 2581 / 10080) loss: 0.123605
# (Iteration 2601 / 10080) loss: 0.122909
# (Iteration 2621 / 10080) loss: 0.123497
# (Iteration 2641 / 10080) loss: 0.121257
# (Iteration 2661 / 10080) loss: 0.118039
# (Iteration 2681 / 10080) loss: 0.117205
# (Iteration 2701 / 10080) loss: 0.116950
# (Iteration 2721 / 10080) loss: 0.112499
# (Iteration 2741 / 10080) loss: 0.113915
# (Iteration 2761 / 10080) loss: 0.114784
# (Iteration 2781 / 10080) loss: 0.116519
# (Iteration 2801 / 10080) loss: 0.110556
# (Iteration 2821 / 10080) loss: 0.108445
# (Iteration 2841 / 10080) loss: 0.108972
# (Iteration 2861 / 10080) loss: 0.107590
# (Iteration 2881 / 10080) loss: 0.108933
# (Iteration 2901 / 10080) loss: 0.105835
# (Iteration 2921 / 10080) loss: 0.103590
# (Iteration 2941 / 10080) loss: 0.105450
# (Iteration 2961 / 10080) loss: 0.105806
# (Iteration 2981 / 10080) loss: 0.101376
# (Iteration 3001 / 10080) loss: 0.101494
# (Iteration 3021 / 10080) loss: 0.101432
# (Epoch 6 / 20) train acc: -0.000375; val_acc: -0.000026
# (Iteration 3041 / 10080) loss: 0.101250
# (Iteration 3061 / 10080) loss: 0.096819
# (Iteration 3081 / 10080) loss: 0.097246
# (Iteration 3101 / 10080) loss: 0.093890
# (Iteration 3121 / 10080) loss: 0.096793
# (Iteration 3141 / 10080) loss: 0.093398
# (Iteration 3161 / 10080) loss: 0.095489
# (Iteration 3181 / 10080) loss: 0.092769
# (Iteration 3201 / 10080) loss: 0.090979
# (Iteration 3221 / 10080) loss: 0.090471
# (Iteration 3241 / 10080) loss: 0.088937
# (Iteration 3261 / 10080) loss: 0.089371
# (Iteration 3281 / 10080) loss: 0.086583
# (Iteration 3301 / 10080) loss: 0.090332
# (Iteration 3321 / 10080) loss: 0.086818
# (Iteration 3341 / 10080) loss: 0.085304
# (Iteration 3361 / 10080) loss: 0.084576
# (Iteration 3381 / 10080) loss: 0.084996
# (Iteration 3401 / 10080) loss: 0.084041
# (Iteration 3421 / 10080) loss: 0.085602
# (Iteration 3441 / 10080) loss: 0.082367
# (Iteration 3461 / 10080) loss: 0.082459
# (Iteration 3481 / 10080) loss: 0.079108
# (Iteration 3501 / 10080) loss: 0.078492
# (Iteration 3521 / 10080) loss: 0.082334
# (Epoch 7 / 20) train acc: -0.000988; val_acc: -0.000026
# (Iteration 3541 / 10080) loss: 0.080747
# (Iteration 3561 / 10080) loss: 0.075496
# (Iteration 3581 / 10080) loss: 0.078562
# (Iteration 3601 / 10080) loss: 0.077364
# (Iteration 3621 / 10080) loss: 0.076409
# (Iteration 3641 / 10080) loss: 0.075136
# (Iteration 3661 / 10080) loss: 0.073480
# (Iteration 3681 / 10080) loss: 0.072584
# (Iteration 3701 / 10080) loss: 0.072941
# (Iteration 3721 / 10080) loss: 0.071957
# (Iteration 3741 / 10080) loss: 0.071201
# (Iteration 3761 / 10080) loss: 0.073237
# (Iteration 3781 / 10080) loss: 0.072956
# (Iteration 3801 / 10080) loss: 0.070400
# (Iteration 3821 / 10080) loss: 0.071349
# (Iteration 3841 / 10080) loss: 0.068707
# (Iteration 3861 / 10080) loss: 0.067041
# (Iteration 3881 / 10080) loss: 0.066872
# (Iteration 3901 / 10080) loss: 0.065509
# (Iteration 3921 / 10080) loss: 0.068162
# (Iteration 3941 / 10080) loss: 0.073294
# (Iteration 3961 / 10080) loss: 0.065722
# (Iteration 3981 / 10080) loss: 0.062462
# (Iteration 4001 / 10080) loss: 0.064740
# (Iteration 4021 / 10080) loss: 0.062932
# (Epoch 8 / 20) train acc: -0.002035; val_acc: -0.000026
# (Iteration 4041 / 10080) loss: 0.062164
# (Iteration 4061 / 10080) loss: 0.061186
# (Iteration 4081 / 10080) loss: 0.062879
# (Iteration 4101 / 10080) loss: 0.062719
# (Iteration 4121 / 10080) loss: 0.060837
# (Iteration 4141 / 10080) loss: 0.060866
# (Iteration 4161 / 10080) loss: 0.060227
# (Iteration 4181 / 10080) loss: 0.058030
# (Iteration 4201 / 10080) loss: 0.061760
# (Iteration 4221 / 10080) loss: 0.058931
# (Iteration 4241 / 10080) loss: 0.059232
# (Iteration 4261 / 10080) loss: 0.055585
# (Iteration 4281 / 10080) loss: 0.057082
# (Iteration 4301 / 10080) loss: 0.057397
# (Iteration 4321 / 10080) loss: 0.054445
# (Iteration 4341 / 10080) loss: 0.053849
# (Iteration 4361 / 10080) loss: 0.057357
# (Iteration 4381 / 10080) loss: 0.057011
# (Iteration 4401 / 10080) loss: 0.055352
# (Iteration 4421 / 10080) loss: 0.052336
# (Iteration 4441 / 10080) loss: 0.054838
# (Iteration 4461 / 10080) loss: 0.052956
# (Iteration 4481 / 10080) loss: 0.056461
# (Iteration 4501 / 10080) loss: 0.050932
# (Iteration 4521 / 10080) loss: 0.051158
# (Epoch 9 / 20) train acc: -0.000068; val_acc: -0.000026
# (Iteration 4541 / 10080) loss: 0.049860
# (Iteration 4561 / 10080) loss: 0.048819
# (Iteration 4581 / 10080) loss: 0.049806
# (Iteration 4601 / 10080) loss: 0.050201
# (Iteration 4621 / 10080) loss: 0.049812
# (Iteration 4641 / 10080) loss: 0.048769
# (Iteration 4661 / 10080) loss: 0.055017
# (Iteration 4681 / 10080) loss: 0.045500
# (Iteration 4701 / 10080) loss: 0.046490
# (Iteration 4721 / 10080) loss: 0.047291
# (Iteration 4741 / 10080) loss: 0.044402
# (Iteration 4761 / 10080) loss: 0.048612
# (Iteration 4781 / 10080) loss: 0.050729
# (Iteration 4801 / 10080) loss: 0.044982
# (Iteration 4821 / 10080) loss: 0.043243
# (Iteration 4841 / 10080) loss: 0.045039
# (Iteration 4861 / 10080) loss: 0.044059
# (Iteration 4881 / 10080) loss: 0.046267
# (Iteration 4901 / 10080) loss: 0.042227
# (Iteration 4921 / 10080) loss: 0.044001
# (Iteration 4941 / 10080) loss: 0.043401
# (Iteration 4961 / 10080) loss: 0.044649
# (Iteration 4981 / 10080) loss: 0.044779
# (Iteration 5001 / 10080) loss: 0.041761
# (Iteration 5021 / 10080) loss: 0.041356
# (Epoch 10 / 20) train acc: -0.001166; val_acc: -0.000026
# (Iteration 5041 / 10080) loss: 0.040071
# (Iteration 5061 / 10080) loss: 0.040570
# (Iteration 5081 / 10080) loss: 0.039506
# (Iteration 5101 / 10080) loss: 0.040879
# (Iteration 5121 / 10080) loss: 0.039347
# (Iteration 5141 / 10080) loss: 0.037667
# (Iteration 5161 / 10080) loss: 0.038836
# (Iteration 5181 / 10080) loss: 0.041103
# (Iteration 5201 / 10080) loss: 0.035800
# (Iteration 5221 / 10080) loss: 0.036904
# (Iteration 5241 / 10080) loss: 0.036895
# (Iteration 5261 / 10080) loss: 0.037869
# (Iteration 5281 / 10080) loss: 0.037901
# (Iteration 5301 / 10080) loss: 0.038426
# (Iteration 5321 / 10080) loss: 0.035089
# (Iteration 5341 / 10080) loss: 0.036419
# (Iteration 5361 / 10080) loss: 0.034807
# (Iteration 5381 / 10080) loss: 0.039034
# (Iteration 5401 / 10080) loss: 0.034442
# (Iteration 5421 / 10080) loss: 0.034289
# (Iteration 5441 / 10080) loss: 0.035146
# (Iteration 5461 / 10080) loss: 0.033860
# (Iteration 5481 / 10080) loss: 0.033255
# (Iteration 5501 / 10080) loss: 0.035534
# (Iteration 5521 / 10080) loss: 0.030647
# (Iteration 5541 / 10080) loss: 0.036050
# (Epoch 11 / 20) train acc: -0.001619; val_acc: -0.000026
# (Iteration 5561 / 10080) loss: 0.033290
# (Iteration 5581 / 10080) loss: 0.031780
# (Iteration 5601 / 10080) loss: 0.033614
# (Iteration 5621 / 10080) loss: 0.034509
# (Iteration 5641 / 10080) loss: 0.034314
# (Iteration 5661 / 10080) loss: 0.032483
# (Iteration 5681 / 10080) loss: 0.029678
# (Iteration 5701 / 10080) loss: 0.031972
# (Iteration 5721 / 10080) loss: 0.029615
# (Iteration 5741 / 10080) loss: 0.031448
# (Iteration 5761 / 10080) loss: 0.037356
# (Iteration 5781 / 10080) loss: 0.028568
# (Iteration 5801 / 10080) loss: 0.027385
# (Iteration 5821 / 10080) loss: 0.031190
# (Iteration 5841 / 10080) loss: 0.027006
# (Iteration 5861 / 10080) loss: 0.030250
# (Iteration 5881 / 10080) loss: 0.032297
# (Iteration 5901 / 10080) loss: 0.027327
# (Iteration 5921 / 10080) loss: 0.029202
# (Iteration 5941 / 10080) loss: 0.028394
# (Iteration 5961 / 10080) loss: 0.027539
# (Iteration 5981 / 10080) loss: 0.030051
# (Iteration 6001 / 10080) loss: 0.026443
# (Iteration 6021 / 10080) loss: 0.029911
# (Iteration 6041 / 10080) loss: 0.024720
# (Epoch 12 / 20) train acc: -0.002151; val_acc: -0.000026
# (Iteration 6061 / 10080) loss: 0.028197
# (Iteration 6081 / 10080) loss: 0.025819
# (Iteration 6101 / 10080) loss: 0.027401
# (Iteration 6121 / 10080) loss: 0.029513
# (Iteration 6141 / 10080) loss: 0.026231
# (Iteration 6161 / 10080) loss: 0.025793
# (Iteration 6181 / 10080) loss: 0.023566
# (Iteration 6201 / 10080) loss: 0.024638
# (Iteration 6221 / 10080) loss: 0.026818
# (Iteration 6241 / 10080) loss: 0.026287
# (Iteration 6261 / 10080) loss: 0.024853
# (Iteration 6281 / 10080) loss: 0.027082
# (Iteration 6301 / 10080) loss: 0.025106
# (Iteration 6321 / 10080) loss: 0.023697
# (Iteration 6341 / 10080) loss: 0.025287
# (Iteration 6361 / 10080) loss: 0.023332
# (Iteration 6381 / 10080) loss: 0.022647
# (Iteration 6401 / 10080) loss: 0.025402
# (Iteration 6421 / 10080) loss: 0.025674
# (Iteration 6441 / 10080) loss: 0.025199
# (Iteration 6461 / 10080) loss: 0.023276
# (Iteration 6481 / 10080) loss: 0.023092
# (Iteration 6501 / 10080) loss: 0.022033
# (Iteration 6521 / 10080) loss: 0.020937
# (Iteration 6541 / 10080) loss: 0.026342
# (Epoch 13 / 20) train acc: -0.001130; val_acc: -0.000026
# (Iteration 6561 / 10080) loss: 0.025066
# (Iteration 6581 / 10080) loss: 0.024558
# (Iteration 6601 / 10080) loss: 0.022639
# (Iteration 6621 / 10080) loss: 0.025305
# (Iteration 6641 / 10080) loss: 0.021240
# (Iteration 6661 / 10080) loss: 0.022394
# (Iteration 6681 / 10080) loss: 0.022673
# (Iteration 6701 / 10080) loss: 0.021722
# (Iteration 6721 / 10080) loss: 0.020279
# (Iteration 6741 / 10080) loss: 0.019565
# (Iteration 6761 / 10080) loss: 0.020663
# (Iteration 6781 / 10080) loss: 0.021909
# (Iteration 6801 / 10080) loss: 0.021239
# (Iteration 6821 / 10080) loss: 0.020266
# (Iteration 6841 / 10080) loss: 0.021171
# (Iteration 6861 / 10080) loss: 0.021236
# (Iteration 6881 / 10080) loss: 0.023026
# (Iteration 6901 / 10080) loss: 0.020101
# (Iteration 6921 / 10080) loss: 0.020340
# (Iteration 6941 / 10080) loss: 0.020501
# (Iteration 6961 / 10080) loss: 0.019434
# (Iteration 6981 / 10080) loss: 0.019954
# (Iteration 7001 / 10080) loss: 0.017863
# (Iteration 7021 / 10080) loss: 0.017224
# (Iteration 7041 / 10080) loss: 0.019449
# (Epoch 14 / 20) train acc: -0.000598; val_acc: -0.000026
# (Iteration 7061 / 10080) loss: 0.017287
# (Iteration 7081 / 10080) loss: 0.018478
# (Iteration 7101 / 10080) loss: 0.017212
# (Iteration 7121 / 10080) loss: 0.015746
# (Iteration 7141 / 10080) loss: 0.019220
# (Iteration 7161 / 10080) loss: 0.023645
# (Iteration 7181 / 10080) loss: 0.018585
# (Iteration 7201 / 10080) loss: 0.019358
# (Iteration 7221 / 10080) loss: 0.015034
# (Iteration 7241 / 10080) loss: 0.020518
# (Iteration 7261 / 10080) loss: 0.017491
# (Iteration 7281 / 10080) loss: 0.018446
# (Iteration 7301 / 10080) loss: 0.020546
# (Iteration 7321 / 10080) loss: 0.017868
# (Iteration 7341 / 10080) loss: 0.015341
# (Iteration 7361 / 10080) loss: 0.015956
# (Iteration 7381 / 10080) loss: 0.016794
# (Iteration 7401 / 10080) loss: 0.015301
# (Iteration 7421 / 10080) loss: 0.017407
# (Iteration 7441 / 10080) loss: 0.016391
# (Iteration 7461 / 10080) loss: 0.018835
# (Iteration 7481 / 10080) loss: 0.015178
# (Iteration 7501 / 10080) loss: 0.014580
# (Iteration 7521 / 10080) loss: 0.015678
# (Iteration 7541 / 10080) loss: 0.016342
# (Epoch 15 / 20) train acc: -0.000549; val_acc: -0.000026
# (Iteration 7561 / 10080) loss: 0.019791
# (Iteration 7581 / 10080) loss: 0.015982
# (Iteration 7601 / 10080) loss: 0.017974
# (Iteration 7621 / 10080) loss: 0.016559
# (Iteration 7641 / 10080) loss: 0.016087
# (Iteration 7661 / 10080) loss: 0.017130
# (Iteration 7681 / 10080) loss: 0.017261
# (Iteration 7701 / 10080) loss: 0.013246
# (Iteration 7721 / 10080) loss: 0.017284
# (Iteration 7741 / 10080) loss: 0.015132
# (Iteration 7761 / 10080) loss: 0.015276
# (Iteration 7781 / 10080) loss: 0.015448
# (Iteration 7801 / 10080) loss: 0.016199
# (Iteration 7821 / 10080) loss: 0.015431
# (Iteration 7841 / 10080) loss: 0.017580
# (Iteration 7861 / 10080) loss: 0.015295
# (Iteration 7881 / 10080) loss: 0.016235
# (Iteration 7901 / 10080) loss: 0.014662
# (Iteration 7921 / 10080) loss: 0.014405
# (Iteration 7941 / 10080) loss: 0.016575
# (Iteration 7961 / 10080) loss: 0.012416
# (Iteration 7981 / 10080) loss: 0.014634
# (Iteration 8001 / 10080) loss: 0.017264
# (Iteration 8021 / 10080) loss: 0.011915
# (Iteration 8041 / 10080) loss: 0.015645
# (Iteration 8061 / 10080) loss: 0.016236
# (Epoch 16 / 20) train acc: -0.000560; val_acc: -0.000026
# (Iteration 8081 / 10080) loss: 0.013843
# (Iteration 8101 / 10080) loss: 0.013111
# (Iteration 8121 / 10080) loss: 0.017422
# (Iteration 8141 / 10080) loss: 0.010755
# (Iteration 8161 / 10080) loss: 0.016069
# (Iteration 8181 / 10080) loss: 0.014714
# (Iteration 8201 / 10080) loss: 0.012912
# (Iteration 8221 / 10080) loss: 0.012867
# (Iteration 8241 / 10080) loss: 0.011594
# (Iteration 8261 / 10080) loss: 0.019363
# (Iteration 8281 / 10080) loss: 0.049933
# (Iteration 8301 / 10080) loss: 0.017295
# (Iteration 8321 / 10080) loss: 0.013820
# (Iteration 8341 / 10080) loss: 0.012214
# (Iteration 8361 / 10080) loss: 0.013343
# (Iteration 8381 / 10080) loss: 0.013933
# (Iteration 8401 / 10080) loss: 0.013651
# (Iteration 8421 / 10080) loss: 0.011034
# (Iteration 8441 / 10080) loss: 0.011369
# (Iteration 8461 / 10080) loss: 0.015499
# (Iteration 8481 / 10080) loss: 0.012622
# (Iteration 8501 / 10080) loss: 0.017331
# (Iteration 8521 / 10080) loss: 0.012608
# (Iteration 8541 / 10080) loss: 0.009584
# (Iteration 8561 / 10080) loss: 0.012910
# (Epoch 17 / 20) train acc: -0.000176; val_acc: -0.000026
# (Iteration 8581 / 10080) loss: 0.011519
# (Iteration 8601 / 10080) loss: 0.013698
# (Iteration 8621 / 10080) loss: 0.015863
# (Iteration 8641 / 10080) loss: 0.015172
# (Iteration 8661 / 10080) loss: 0.013416
# (Iteration 8681 / 10080) loss: 0.012964
# (Iteration 8701 / 10080) loss: 0.011814
# (Iteration 8721 / 10080) loss: 0.011809
# (Iteration 8741 / 10080) loss: 0.012683
# (Iteration 8761 / 10080) loss: 0.012026
# (Iteration 8781 / 10080) loss: 0.012497
# (Iteration 8801 / 10080) loss: 0.011007
# (Iteration 8821 / 10080) loss: 0.012664
# (Iteration 8841 / 10080) loss: 0.012777
# (Iteration 8861 / 10080) loss: 0.011899
# (Iteration 8881 / 10080) loss: 0.010960
# (Iteration 8901 / 10080) loss: 0.009840
# (Iteration 8921 / 10080) loss: 0.010288
# (Iteration 8941 / 10080) loss: 0.013084
# (Iteration 8961 / 10080) loss: 0.009756
# (Iteration 8981 / 10080) loss: 0.012026
# (Iteration 9001 / 10080) loss: 0.012084
# (Iteration 9021 / 10080) loss: 0.011877
# (Iteration 9041 / 10080) loss: 0.009847
# (Iteration 9061 / 10080) loss: 0.026064
# (Epoch 18 / 20) train acc: -0.000028; val_acc: -0.000026
# (Iteration 9081 / 10080) loss: 0.012083
# (Iteration 9101 / 10080) loss: 0.011800
# (Iteration 9121 / 10080) loss: 0.009409
# (Iteration 9141 / 10080) loss: 0.010995
# (Iteration 9161 / 10080) loss: 0.013439
# (Iteration 9181 / 10080) loss: 0.010821
# (Iteration 9201 / 10080) loss: 0.015134
# (Iteration 9221 / 10080) loss: 0.013894
# (Iteration 9241 / 10080) loss: 0.013679
# (Iteration 9261 / 10080) loss: 0.009282
# (Iteration 9281 / 10080) loss: 0.009793
# (Iteration 9301 / 10080) loss: 0.010525
# (Iteration 9321 / 10080) loss: 0.012152
# (Iteration 9341 / 10080) loss: 0.009573
# (Iteration 9361 / 10080) loss: 0.008998
# (Iteration 9381 / 10080) loss: 0.011502
# (Iteration 9401 / 10080) loss: 0.009567
# (Iteration 9421 / 10080) loss: 0.011899
# (Iteration 9441 / 10080) loss: 0.007849
# (Iteration 9461 / 10080) loss: 0.010198
# (Iteration 9481 / 10080) loss: 0.012023
# (Iteration 9501 / 10080) loss: 0.011149
# (Iteration 9521 / 10080) loss: 0.008474
# (Iteration 9541 / 10080) loss: 0.012073
# (Iteration 9561 / 10080) loss: 0.012210
# (Epoch 19 / 20) train acc: -0.000494; val_acc: -0.000026
# (Iteration 9581 / 10080) loss: 0.010444
# (Iteration 9601 / 10080) loss: 0.009186
# (Iteration 9621 / 10080) loss: 0.008701
# (Iteration 9641 / 10080) loss: 0.011940
# (Iteration 9661 / 10080) loss: 0.008642
# (Iteration 9681 / 10080) loss: 0.011396
# (Iteration 9701 / 10080) loss: 0.010202
# (Iteration 9721 / 10080) loss: 0.009973
# (Iteration 9741 / 10080) loss: 0.013960
# (Iteration 9761 / 10080) loss: 0.009105
# (Iteration 9781 / 10080) loss: 0.012564
# (Iteration 9801 / 10080) loss: 0.007302
# (Iteration 9821 / 10080) loss: 0.013258
# (Iteration 9841 / 10080) loss: 0.007636
# (Iteration 9861 / 10080) loss: 0.009875
# (Iteration 9881 / 10080) loss: 0.011504
# (Iteration 9901 / 10080) loss: 0.011441
# (Iteration 9921 / 10080) loss: 0.010211
# (Iteration 9941 / 10080) loss: 0.011314
# (Iteration 9961 / 10080) loss: 0.009576
# (Iteration 9981 / 10080) loss: 0.011626
# (Iteration 10001 / 10080) loss: 0.009480
# (Iteration 10021 / 10080) loss: 0.012066
# (Iteration 10041 / 10080) loss: 0.007964
# (Iteration 10061 / 10080) loss: 0.013513
# (Epoch 20 / 20) train acc: -0.000002; val_acc: -0.000026

# %% [markdown]
# ### Linear model and its variants

# %% [markdown]
# Construct the linear regression model, with different regularization method, perform the above prediction task. Compare their results.

# %%
##############################################################################
### TODO: Linear model and its variants.                                   ###
##############################################################################

from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV

## For no regularization
print("No regularization")

lin_reg_model = LinearRegression()
lin_reg_model.fit(full_data_nonlin['X_train'],full_data_nonlin['y_train'])
score = lin_reg_model.score(full_data_nonlin['X_val'],full_data_nonlin['y_val'])

print("Nonlinear")
print(f"Score : {score}")
lin_reg_pred = lin_reg_model.predict(full_data_nonlin['X_val'])
print(f"MSE : {mean_squared_error(lin_reg_pred,full_data_nonlin['y_val'])}")


lin_X_train,lin_X_test,lin_y_train,lin_y_test = train_test_split(factor, linear_ret, test_size = 0.3)


full_data = {
  'X_train': lin_X_train,
  'y_train': lin_y_train,
  'X_val': lin_X_test,
  'y_val': lin_y_test
}


lin_reg_model = LinearRegression()
lin_reg_model.fit(full_data['X_train'],full_data['y_train'])
score = lin_reg_model.score(full_data['X_val'],full_data['y_val'])

print("Linear")
print(f"Score : {score}")
lin_reg_pred = lin_reg_model.predict(full_data['X_val'])
print(f"MSE : {mean_squared_error(lin_reg_pred,full_data['y_val'])}")

# L1 regularization
print("\nL1 regularization linear regression")

model = LassoCV(cv = 5, random_state = 0, max_iter = 10000)
model.fit(full_data_nonlin['X_train'],full_data_nonlin['y_train'].ravel())
alpha_ = model.alpha_

lasso = Lasso(max_iter = 10000)
lasso.set_params(alpha=alpha_).fit(full_data_nonlin['X_train'],full_data_nonlin['y_train'].ravel())
lin_reg_pred = lasso.predict(full_data_nonlin['X_val'])
score = lasso.score(full_data_nonlin['X_val'],full_data_nonlin['y_val'].ravel())

print("Nonlinear")
print(f"Score : {score}")
print(f"MSE : {mean_squared_error(lin_reg_pred,full_data_nonlin['y_val'].ravel())}")


model = LassoCV(cv = 5, random_state = 0, max_iter = 10000)
model.fit(full_data['X_train'],full_data['y_train'].ravel())
alpha_ = model.alpha_

lasso = Lasso(max_iter = 10000)
lasso.set_params(alpha=alpha_).fit(full_data['X_train'],full_data['y_train'].ravel())
lin_reg_pred = lasso.predict(full_data['X_val'])
score = lasso.score(full_data['X_val'],full_data['y_val'].ravel())

print("Linear")
print(f"Score : {score}")
print(f"MSE : {mean_squared_error(lin_reg_pred,full_data['y_val'].ravel())}")

# L2 regularization
print("\nL2 regularization linear regression")

model = RidgeCV(cv = 5)
model.fit(full_data_nonlin['X_train'],full_data_nonlin['y_train'].ravel())
alpha_ = model.alpha_

ridge = Ridge(max_iter = 10000)
ridge.set_params(alpha=alpha_).fit(full_data_nonlin['X_train'],full_data_nonlin['y_train'].ravel())
lin_reg_pred = ridge.predict(full_data_nonlin['X_val'])
score = ridge.score(full_data_nonlin['X_val'],full_data_nonlin['y_val'].ravel())

print("Nonlinear")
print(f"Score : {score}")
print(f"MSE : {mean_squared_error(lin_reg_pred,full_data_nonlin['y_val'].ravel())}")


model = RidgeCV(cv = 5)
model.fit(full_data['X_train'],full_data['y_train'].ravel())
alpha_ = model.alpha_

ridge = Ridge(max_iter = 10000)
ridge.set_params(alpha=alpha_).fit(full_data['X_train'],full_data['y_train'].ravel())
lin_reg_pred = ridge.predict(full_data['X_val'])
score = ridge.score(full_data['X_val'],full_data['y_val'].ravel())

print("Linear")
print(f"Score : {score}")
print(f"MSE : {mean_squared_error(lin_reg_pred,full_data['y_val'].ravel())}")
##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
# Out:
# No regularization
# Nonlinear
# Score : 0.04424544705797184
# MSE : 0.006774905413311183
# Linear
# Score : 0.03921156105783119
# MSE : 0.006898641348430795
#
# L1 regularization linear regression
# Nonlinear
# Score : 0.047079613248045105
# MSE : 0.0067548153098382305
# Linear
# Score : 0.0398286817262381
# MSE : 0.006894210306187271
#
# L2 regularization linear regression
# Nonlinear
# Score : 0.0442495184168783
# MSE : 0.006774876553316313
# Linear
# Score : 0.03922212921558765
# MSE : 0.006898565467074276

# %% [markdown]
# ### Tree based model

# %% [markdown]
# Now construct the tree model (CART, Random Forest) and redo the above exercise. Compare their results.

# %%
##############################################################################
### TODO: Tree based models.                                               ###
##############################################################################
# For the nonlinear ret

from sklearn import tree
from sklearn.ensemble import RandomForestRegressor

# CART using tree

print("CART")
clf_nonlin = tree.DecisionTreeRegressor()
clf_nonlin = clf_nonlin.fit(full_data_nonlin['X_train'],full_data_nonlin['y_train'])

prediction = clf_nonlin.predict(full_data_nonlin['X_val'])

print("Nonlinear")
print(f" R2 score: {r2_score(prediction,full_data_nonlin['y_val'])}")
print(f"MSE : {mean_squared_error(prediction,full_data_nonlin['y_val'])}")



clf_lin = tree.DecisionTreeRegressor()
clf_lin = clf_lin.fit(full_data['X_train'],full_data['y_train'])

prediction = clf_lin.predict(full_data['X_val'])

print("Linear")
print(f" R2 score: {r2_score(prediction,full_data['y_val'])}")
print(f"MSE : {mean_squared_error(prediction,full_data['y_val'])}")

# Random forest regressor

print("\nRF")

rfr = RandomForestRegressor()
rfr = rfr.fit(full_data_nonlin['X_train'],full_data_nonlin['y_train'])

prediction = rfr.predict(full_data_nonlin['X_val'])
print("Nonlinear")
print(f" R2 score: {r2_score(prediction,full_data_nonlin['y_val'])}")
print(f"MSE : {mean_squared_error(prediction,full_data_nonlin['y_val'])}")



rfr2 = RandomForestRegressor()
rfr2 = rfr2.fit(full_data['X_train'],full_data['y_train'])

prediction = rfr2.predict(full_data['X_val'])
print("Linear")
print(f" R2 score: {r2_score(prediction,full_data['y_val'])}")
print(f"MSE : {mean_squared_error(prediction,full_data['y_val'])}")


##############################################################################
#                               END OF YOUR CODE                             #
##############################################################################
# Out:
# CART
# Nonlinear
#  R2 score: -0.7509090024636071
# MSE : 0.014660412057060033
# Linear
#  R2 score: -0.8214891354172216
# MSE : 0.0150380621319141
#
# RF
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Nonlinear
#  R2 score: -10.715117134528498
# MSE : 0.007084530985725938
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:47: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Linear
#  R2 score: -10.714990657312788
# MSE : 0.007206243280671416

# %% [markdown]
# ## Results
#
# Compare the above findings and write your results here.

# %% [markdown]
# **Results**
#
# No regularization
# Nonlinear
# Score : 0.04424544705797184
# MSE : 0.006774905413311183
# Linear
# Score : 0.03921156105783119
# MSE : 0.006898641348430795
#
# L1 regularization linear regression
# Nonlinear
# Score : 0.047079613248045105
# MSE : 0.0067548153098382305
# Linear
# Score : 0.0398286817262381
# MSE : 0.006894210306187271
#
# L2 regularization linear regression
# Nonlinear
# Score : 0.0442495184168783
# MSE : 0.006774876553316313
# Linear
# Score : 0.03922212921558765
# MSE : 0.006898565467074276
#
# CART
# Nonlinear
#  R2 score: -0.7509090024636071
# MSE : 0.014660412057060033
# Linear
#  R2 score: -0.8214891354172216
# MSE : 0.0150380621319141
#
# RF
# Nonlinear
# R2 score: -10.715117134528498
# MSE : 0.007084530985725938
#
# Linear
# R2 score: -10.714990657312788
# MSE : 0.007206243280671416

# %% [markdown]
# First of all, using more data gives better results for the neural network. The validation loss goes down a lot.
#
# Next, the linear model is estimated.
#
# Finally the Tree/cart models give worse results. They are only able to fit the linearities.
